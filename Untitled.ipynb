# %%
import os
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset, random_split
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
import math
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix



# Define paths
eeg_data_dir = r'C:\Users\User\Documents\Lie detect data\AugmentedEEGData'
poly_data_dir = r'C:\Users\User\Documents\Lie detect data\CombinedPolyData'

# Set a fixed length for the polygraph signals
FIXED_LENGTH = 250  # Adjust as needed

# Function to load and preprocess EEG data
def load_eeg_data(data_dir):
    X = []
    y = []
    
    for file_name in os.listdir(data_dir):
        if file_name.endswith('.pkl'):
            file_path = os.path.join(data_dir, file_name)
            data = pd.read_pickle(file_path)
            label = 0 if 'lie' in file_name else 1
            X.append(data)
            y.extend([label] * data.shape[0])
    
    X = np.vstack(X)
    y = np.array(y)
    return X, y

# Function to load and preprocess polygraph data
def load_and_preprocess_poly_data(data_dir):
    X = []
    y = []

    for file_name in os.listdir(data_dir):
        if file_name.endswith('.pkl'):
            file_path = os.path.join(data_dir, file_name)
            data = pd.read_pickle(file_path)
            label = 0 if 'lie' in file_name else 1
            
            # Handle different lengths by truncating or padding
            if data.shape[1] > FIXED_LENGTH:
                data = data[:, :FIXED_LENGTH]  # Truncate
            elif data.shape[1] < FIXED_LENGTH:
                pad_width = FIXED_LENGTH - data.shape[1]
                data = np.pad(data, ((0, 0), (0, pad_width)), mode='constant')  # Pad with zeros
            
            X.append(data)
            y.extend([label] * data.shape[0])

    X = np.array(X)
    y = np.array(y)
    return X, y

# Load and preprocess data
eeg_X, eeg_y = load_eeg_data(eeg_data_dir)
poly_X, poly_y = load_and_preprocess_poly_data(poly_data_dir)

# Ensure both datasets have the same number of samples
n_samples = min(eeg_X.shape[0], poly_X.shape[0])
eeg_X, eeg_y = eeg_X[:n_samples], eeg_y[:n_samples]
poly_X, poly_y = poly_X[:n_samples], poly_y[:n_samples]

# Normalize EEG data
eeg_scaler = StandardScaler()
eeg_X = eeg_X.reshape(eeg_X.shape[0], -1)  # Reshape to (n_samples, n_features)
eeg_X = eeg_scaler.fit_transform(eeg_X)
eeg_X = eeg_X.reshape(-1, 65, 125)  # Reshape back to (n_samples, n_channels, n_times)

# Normalize Polygraph data
poly_scaler = StandardScaler()
poly_X = poly_X.reshape(poly_X.shape[0], -1)  # Reshape to (n_samples, n_features)
poly_X = poly_scaler.fit_transform(poly_X)
poly_X = poly_X.reshape(-1, 4, FIXED_LENGTH)  # Reshape back to (n_samples, n_channels, n_times)

# Shuffle data
eeg_indices = np.random.permutation(eeg_X.shape[0])
eeg_X, eeg_y = eeg_X[eeg_indices], eeg_y[eeg_indices]

poly_indices = np.random.permutation(poly_X.shape[0])
poly_X, poly_y = poly_X[poly_indices], poly_y[poly_indices]

# Define a custom dataset class that handles both EEG and polygraph data
class CombinedDataset(Dataset):
    def __init__(self, eeg_X, eeg_y, poly_X, poly_y):
        self.eeg_X = torch.tensor(eeg_X, dtype=torch.float32)
        self.eeg_y = torch.tensor(eeg_y, dtype=torch.long)
        self.poly_X = torch.tensor(poly_X, dtype=torch.float32)
        self.poly_y = torch.tensor(poly_y, dtype=torch.long)

    def __len__(self):
        return len(self.eeg_X)

    def __getitem__(self, idx):
        return self.eeg_X[idx], self.eeg_y[idx], self.poly_X[idx], self.poly_y[idx]

# Create dataset and data loaders
combined_dataset = CombinedDataset(eeg_X, eeg_y, poly_X, poly_y)
train_size = int(0.7 * len(combined_dataset))
val_size = int(0.15 * len(combined_dataset))
test_size = len(combined_dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(combined_dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)



# Define EEGNet model
class EEGNet(nn.Module):
    def __init__(self, num_classes=2):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, (1, 63), padding='same')
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.depthwiseConv2d = nn.Conv2d(16, 32, (65, 1), groups=16, padding='same')
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.activation = nn.ELU()
        self.pooling = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32 * 65 * 31, num_classes)

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv2d(x)
        x = self.batchnorm2(x)
        x = self.activation(x)
        x = self.pooling(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

# Define PolygraphNet model
class PolygraphNet(nn.Module):
    def __init__(self, num_classes=2):
        super(PolygraphNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, (1, 4), padding='same')
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.depthwiseConv2d = nn.Conv2d(16, 32, (4, 1), groups=16, padding='same')
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.activation = nn.ELU()
        self.pooling = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32 * 4 * 62, num_classes)  # Adjust input size accordingly

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv2d(x)
        x = self.batchnorm2(x)
        x = self.activation(x)
        x = self.pooling(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

# Define Ensemble model
class EnsembleModel(nn.Module):
    def __init__(self, eeg_model, poly_model):
        super(EnsembleModel, self).__init__()
        self.eeg_model = eeg_model
        self.poly_model = poly_model
        self.fc = nn.Linear(4, 2)  # Combine outputs of both models

    def forward(self, eeg_input, poly_input):
        eeg_output = self.eeg_model(eeg_input)
        poly_output = self.poly_model(poly_input)
        combined_output = torch.cat((eeg_output, poly_output), dim=1)
        output = self.fc(combined_output)
        return output

# Initialize the models, loss function, and optimizers
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
eeg_model = EEGNet(num_classes=2).to(device)
poly_model = PolygraphNet(num_classes=2).to(device)
ensemble_model = EnsembleModel(eeg_model, poly_model).to(device)

criterion = nn.CrossEntropyLoss()
ensemble_optimizer = optim.Adam(ensemble_model.parameters(), lr=0.001)

# Training loop
num_epochs = 100
best_val_loss = float('inf')

for epoch in range(num_epochs):
    ensemble_model.train()
    train_loss = 0.0
    for eeg_X_batch, eeg_y_batch, poly_X_batch, poly_y_batch in train_loader:
        eeg_X_batch, eeg_y_batch = eeg_X_batch.to(device), eeg_y_batch.to(device)
        poly_X_batch, poly_y_batch = poly_X_batch.to(device), poly_y_batch.to(device)
        
        ensemble_optimizer.zero_grad()
        outputs = ensemble_model(eeg_X_batch, poly_X_batch)
        loss = criterion(outputs, eeg_y_batch)  # Assuming same labels for both modalities
        loss.backward()
        ensemble_optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {train_loss}')
    
    # Evaluate on validation set
    val_loss, val_accuracy, val_precision, val_recall, val_f1, val_conf_matrix = evaluate_model(ensemble_model, val_loader, criterion)
    print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')
    print(f'Precision: {val_precision}, Recall: {val_recall}, F1-score: {val_f1}')
    print('Confusion Matrix:')
    print(val_conf_matrix)
    
    # Save the best model
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_path = 'best_ensemble_model.pth'
        torch.save(ensemble_model.state_dict(), best_model_path)

# Evaluate on test set
test_loss, test_accuracy, test_precision, test_recall, test_f1, test_conf_matrix = evaluate_model(ensemble_model, test_loader, criterion)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
print(f'Precision: {test_precision}, Recall: {test_recall}, F1-score: {test_f1}')
print('Confusion Matrix:')
print(test_conf_matrix)

def evaluate_model(model, data_loader, criterion):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for eeg_X_batch, eeg_y_batch, poly_X_batch, poly_y_batch in data_loader:
            eeg_X_batch, eeg_y_batch = eeg_X_batch.to(device), eeg_y_batch.to(device)
            poly_X_batch, poly_y_batch = poly_X_batch.to(device), poly_y_batch.to(device)
            
            outputs = model(eeg_X_batch, poly_X_batch)
            loss = criterion(outputs, eeg_y_batch)  # Assuming same labels for both modalities
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += eeg_y_batch.size(0)
            correct += (predicted == eeg_y_batch).sum().item()
            
            all_labels.extend(eeg_y_batch.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    total_loss /= len(data_loader)
    accuracy = correct / total
    precision = precision_score(all_labels, all_predictions, average='binary', zero_division=1)
    recall = recall_score(all_labels, all_predictions, average='binary', zero_division=1)
    f1 = f1_score(all_labels, all_predictions, average='binary', zero_division=1)
    conf_matrix = confusion_matrix(all_labels, all_predictions, labels=[0, 1])

    return total_loss, accuracy, precision, recall, f1, conf_matrix
num_epochs = 100
best_val_loss = float('inf')

for epoch in range(num_epochs):
    ensemble_model.train()
    train_loss = 0.0
    for eeg_X_batch, eeg_y_batch, poly_X_batch, poly_y_batch in train_loader:
        eeg_X_batch, eeg_y_batch = eeg_X_batch.to(device), eeg_y_batch.to(device)
        poly_X_batch, poly_y_batch = poly_X_batch.to(device), poly_y_batch.to(device)
        
        ensemble_optimizer.zero_grad()
        outputs = ensemble_model(eeg_X_batch, poly_X_batch)
        loss = criterion(outputs, eeg_y_batch)  # Assuming same labels for both modalities
        loss.backward()
        ensemble_optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(train_loader)
    print(f'Epoch {epoch+1}/{num_epochs}, Loss: {train_loss}')
    
    # Evaluate on validation set
    val_loss, val_accuracy, val_precision, val_recall, val_f1, val_conf_matrix = evaluate_model(ensemble_model, val_loader, criterion)
    print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')
    print(f'Precision: {val_precision}, Recall: {val_recall}, F1-score: {val_f1}')
    print('Confusion Matrix:')
    print(val_conf_matrix)
    
    # Save the best model
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_path = 'best_ensemble_model.pth'
        torch.save(ensemble_model.state_dict(), best_model_path)

# Evaluate on test set
test_loss, test_accuracy, test_precision, test_recall, test_f1, test_conf_matrix = evaluate_model(ensemble_model, test_loader, criterion)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
print(f'Precision: {test_precision}, Recall: {test_recall}, F1-score: {test_f1}')
print('Confusion Matrix:')
print(test_conf_matrix)
# Out:
# Epoch 1/100, Loss: 0.33768240362405777
# Validation Loss: 0.39915546774864197, Validation Accuracy: 0.9230769230769231
# Precision: 0.0, Recall: 1.0, F1-score: 0.0
# Confusion Matrix:
# [[12  1]
#  [ 0  0]]
# Epoch 2/100, Loss: 0.006093421077821404
# Validation Loss: 0.20346347987651825, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 3/100, Loss: 0.0003505947533994913
# Validation Loss: 0.1051301583647728, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 4/100, Loss: 7.43446325941477e-05
# Validation Loss: 0.05544733256101608, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 5/100, Loss: 2.896267415053444e-05
# Validation Loss: 0.0279568862169981, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 6/100, Loss: 1.8920603906735778e-05
# Validation Loss: 0.013101745396852493, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 7/100, Loss: 1.3646583283843938e-05
# Validation Loss: 0.0057973614893853664, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 8/100, Loss: 4.8102280061357305e-06
# Validation Loss: 0.00246826047077775, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 9/100, Loss: 3.462767267592426e-06
# Validation Loss: 0.0010520321084186435, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 10/100, Loss: 6.621906535997368e-06
# Validation Loss: 0.0004492226871661842, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 11/100, Loss: 3.199086648919547e-06
# Validation Loss: 0.00019744753080885857, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 12/100, Loss: 4.648378080673865e-06
# Validation Loss: 9.42449041758664e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 13/100, Loss: 9.328052783530438e-07
# Validation Loss: 4.839280154556036e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 14/100, Loss: 1.7997384205159506e-06
# Validation Loss: 2.601325286377687e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 15/100, Loss: 9.961294864524461e-07
# Validation Loss: 1.4873007785354275e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 16/100, Loss: 8.876036119431774e-07
# Validation Loss: 9.142183444055263e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 17/100, Loss: 5.402882834459888e-07
# Validation Loss: 5.923676326347049e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 18/100, Loss: 1.2612408681889065e-06
# Validation Loss: 4.098912086192286e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 19/100, Loss: 1.330383469166918e-06
# Validation Loss: 2.9251850719447248e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 20/100, Loss: 1.3620651913015536e-06
# Validation Loss: 2.2282802092377096e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 21/100, Loss: 3.650774758057196e-07
# Validation Loss: 1.705600084278558e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 22/100, Loss: 7.46912949267653e-07
# Validation Loss: 1.412164920111536e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 23/100, Loss: 2.137749207875572e-06
# Validation Loss: 1.1737482736862148e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 24/100, Loss: 7.122688892025053e-07
# Validation Loss: 1.0362001603425597e-06, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 25/100, Loss: 8.656209899982059e-07
# Validation Loss: 9.169916097562236e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 26/100, Loss: 9.617303646791697e-07
# Validation Loss: 8.344625825884577e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 27/100, Loss: 4.3461556487045527e-07
# Validation Loss: 7.702732318648486e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 28/100, Loss: 6.325493870917853e-07
# Validation Loss: 7.244237849590718e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 29/100, Loss: 6.219953760933095e-07
# Validation Loss: 6.785742812098761e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 30/100, Loss: 7.829241326362535e-07
# Validation Loss: 6.510645675916749e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 31/100, Loss: 1.6577515182802927e-07
# Validation Loss: 6.052150638424791e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 32/100, Loss: 4.097799504165778e-07
# Validation Loss: 5.868753305549035e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 33/100, Loss: 2.68344514608998e-07
# Validation Loss: 5.777053502242779e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 34/100, Loss: 1.1641374726423237e-06
# Validation Loss: 5.685354267370712e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 35/100, Loss: 2.3978422092341134e-07
# Validation Loss: 5.685354267370712e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 36/100, Loss: 6.70295307259039e-07
# Validation Loss: 5.501955797626579e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 37/100, Loss: 9.53034771100647e-07
# Validation Loss: 5.4102571311887e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 38/100, Loss: 2.74801692512483e-07
# Validation Loss: 5.226859229878755e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 39/100, Loss: 5.06883097273203e-07
# Validation Loss: 5.226859229878755e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 40/100, Loss: 1.9822909393951704e-06
# Validation Loss: 5.226859229878755e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 41/100, Loss: 3.594886912594575e-07
# Validation Loss: 5.226859229878755e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 42/100, Loss: 3.476922785239367e-07
# Validation Loss: 5.226859229878755e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 43/100, Loss: 1.529547404288678e-06
# Validation Loss: 5.043460760134622e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 44/100, Loss: 1.442927697326013e-07
# Validation Loss: 4.860062858824676e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 45/100, Loss: 2.9615974028729397e-07
# Validation Loss: 4.860062858824676e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 46/100, Loss: 5.082501033371045e-07
# Validation Loss: 4.951761525262555e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 47/100, Loss: 4.277858920431754e-07
# Validation Loss: 4.951761525262555e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 48/100, Loss: 5.247656318374538e-07
# Validation Loss: 4.860062858824676e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 49/100, Loss: 4.3598102905662017e-07
# Validation Loss: 4.860062858824676e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 50/100, Loss: 9.331698080927708e-07
# Validation Loss: 4.951761525262555e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 51/100, Loss: 4.872641667930111e-07
# Validation Loss: 4.951761525262555e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 52/100, Loss: 6.053524970184299e-07
# Validation Loss: 4.951761525262555e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 53/100, Loss: 8.41903535331312e-07
# Validation Loss: 5.043460760134622e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 54/100, Loss: 4.90741840053488e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 55/100, Loss: 8.185570381513685e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 56/100, Loss: 5.825055318098293e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 57/100, Loss: 2.633774371929576e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 58/100, Loss: 1.229568798333247e-06
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 59/100, Loss: 2.166873400710756e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 60/100, Loss: 3.38751711126406e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 61/100, Loss: 4.805593221135496e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 62/100, Loss: 3.607309082553911e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 63/100, Loss: 2.796443894226286e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 64/100, Loss: 4.714947436923467e-07
# Validation Loss: 5.226858661444567e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 65/100, Loss: 3.7501120431215895e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 66/100, Loss: 3.6408345494010064e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 67/100, Loss: 3.710366414111377e-07
# Validation Loss: 5.043460191700433e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 68/100, Loss: 4.84904816744347e-07
# Validation Loss: 5.043460191700433e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 69/100, Loss: 2.5642340695242183e-07
# Validation Loss: 5.043460191700433e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 70/100, Loss: 6.12929111909466e-07
# Validation Loss: 5.043460191700433e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 71/100, Loss: 6.105674152934171e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 72/100, Loss: 3.920226987474962e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 73/100, Loss: 6.484428389796904e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 74/100, Loss: 5.344493949621665e-07
# Validation Loss: 5.043460191700433e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 75/100, Loss: 1.280256647362421e-07
# Validation Loss: 4.951760956828366e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 76/100, Loss: 2.4549606081336606e-07
# Validation Loss: 4.951760956828366e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 77/100, Loss: 3.3949685018797027e-07
# Validation Loss: 4.951760956828366e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 78/100, Loss: 6.98853650504816e-07
# Validation Loss: 5.1351594265725e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 79/100, Loss: 1.040207505909052e-06
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 80/100, Loss: 2.2314419467761581e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 81/100, Loss: 2.0898843899885833e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 82/100, Loss: 2.2662135279460927e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 83/100, Loss: 1.5671027142616367e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 84/100, Loss: 5.196735699541932e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 85/100, Loss: 1.971916958609654e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 86/100, Loss: 1.6788616719054517e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 87/100, Loss: 4.5497925604820466e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 88/100, Loss: 1.8427746795168787e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 89/100, Loss: 3.0522441818447987e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 90/100, Loss: 5.572988754920516e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 91/100, Loss: 2.426397358590293e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 92/100, Loss: 5.23896375170807e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 93/100, Loss: 2.4350925897920206e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 94/100, Loss: 6.034918840214232e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 95/100, Loss: 1.4578289153632795e-07
# Validation Loss: 5.043460191700433e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 96/100, Loss: 4.7596496521862264e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 97/100, Loss: 1.5174330236789046e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 98/100, Loss: 1.642849838390248e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 99/100, Loss: 2.3158825257496574e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 100/100, Loss: 3.84199772440752e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Test Loss: 3.0994354460744944e-07, Test Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[15  0]
#  [ 0  0]]
# Epoch 1/100, Loss: 3.9922418615390143e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 2/100, Loss: 2.949169974897359e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 3/100, Loss: 1.476455366855589e-07
# Validation Loss: 5.135158858138311e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 4/100, Loss: 3.495544973475262e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 5/100, Loss: 3.7215476922369817e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 6/100, Loss: 4.569664753262259e-07
# Validation Loss: 5.226858093010378e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 7/100, Loss: 2.5220141708359733e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 8/100, Loss: 3.469462193095296e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 9/100, Loss: 2.6536400810073246e-07
# Validation Loss: 5.410255994320323e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 10/100, Loss: 2.3183642383628467e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 11/100, Loss: 3.375098955871181e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 12/100, Loss: 1.6155317084098897e-07
# Validation Loss: 5.135158289704123e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 13/100, Loss: 2.7740916408447447e-07
# Validation Loss: 5.135158289704123e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 14/100, Loss: 2.1879831280102735e-07
# Validation Loss: 5.318557327882445e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 15/100, Loss: 2.0364887731716408e-07
# Validation Loss: 5.043459623266244e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 16/100, Loss: 1.3249606922727253e-07
# Validation Loss: 5.226857524576189e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 17/100, Loss: 2.873432825012401e-07
# Validation Loss: 5.318556191014068e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 18/100, Loss: 7.190963593473043e-07
# Validation Loss: 5.318556191014068e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 19/100, Loss: 2.888332772954527e-07
# Validation Loss: 5.318556191014068e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 20/100, Loss: 9.511900955772035e-08
# Validation Loss: 5.50195522919239e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 21/100, Loss: 1.2069555168636725e-06
# Validation Loss: 5.50195522919239e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 22/100, Loss: 3.267067629764142e-07
# Validation Loss: 5.410255425886135e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 23/100, Loss: 1.5733120584116023e-07
# Validation Loss: 5.318556191014068e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 24/100, Loss: 2.4015604616067776e-07
# Validation Loss: 5.318556191014068e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 25/100, Loss: 2.479793721477108e-07
# Validation Loss: 5.410255425886135e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 26/100, Loss: 4.736040111197326e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 27/100, Loss: 5.045226156852323e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 28/100, Loss: 1.8663683221120664e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 29/100, Loss: 1.6453339668487388e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 30/100, Loss: 1.880025966016774e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 31/100, Loss: 3.490580269271959e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 32/100, Loss: 2.77657029812417e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 33/100, Loss: 7.872613370096815e-07
# Validation Loss: 5.59365332719608e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 34/100, Loss: 1.0629484137325562e-07
# Validation Loss: 5.59365332719608e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 35/100, Loss: 7.022059573813522e-07
# Validation Loss: 5.685351993633958e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 36/100, Loss: 9.461995098547504e-07
# Validation Loss: 5.777051228506025e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 37/100, Loss: 3.6358668387137527e-07
# Validation Loss: 5.685351993633958e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 38/100, Loss: 2.3022213824219762e-07
# Validation Loss: 5.59365332719608e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 39/100, Loss: 2.934278882094077e-07
# Validation Loss: 5.59365332719608e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 40/100, Loss: 2.0911225107056453e-07
# Validation Loss: 5.59365332719608e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 41/100, Loss: 4.5559948347317913e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 42/100, Loss: 2.328300290344032e-07
# Validation Loss: 5.410255425886135e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 43/100, Loss: 2.838660293491557e-07
# Validation Loss: 5.410255425886135e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 44/100, Loss: 3.598614597422056e-07
# Validation Loss: 5.410255425886135e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 45/100, Loss: 1.1175858816159234e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 46/100, Loss: 1.8936845158634696e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 47/100, Loss: 2.8883271596669147e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 48/100, Loss: 2.536916170470249e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 49/100, Loss: 1.3299268530886366e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 50/100, Loss: 1.6167728844607154e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 51/100, Loss: 2.082433461225719e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 52/100, Loss: 2.7902301447113587e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 53/100, Loss: 1.7148725106608254e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 54/100, Loss: 2.458682217820751e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 55/100, Loss: 2.7778169453540613e-07
# Validation Loss: 5.410255425886135e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 56/100, Loss: 3.1925594612403074e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 57/100, Loss: 1.7893775527966227e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 58/100, Loss: 1.0095526858933113e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 59/100, Loss: 1.7049374712030385e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 60/100, Loss: 2.1308597819569286e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 61/100, Loss: 1.9234857617789203e-07
# Validation Loss: 5.501954092324013e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 62/100, Loss: 2.0315209425803005e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 63/100, Loss: 1.2641136670765718e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 64/100, Loss: 1.4714884244426685e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 65/100, Loss: 2.68840872230669e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 66/100, Loss: 1.6478166742217581e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 67/100, Loss: 8.543326757148861e-08
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 68/100, Loss: 1.0281791773536497e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 69/100, Loss: 4.634207684262037e-07
# Validation Loss: 5.685351993633958e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 70/100, Loss: 1.861399852032264e-07
# Validation Loss: 5.685351993633958e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 71/100, Loss: 1.210717498478786e-07
# Validation Loss: 5.410254857451946e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 72/100, Loss: 2.6822084997490947e-08
# Validation Loss: 5.410254857451946e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 73/100, Loss: 2.8672161889176095e-07
# Validation Loss: 5.410254857451946e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 74/100, Loss: 2.5555425242629326e-07
# Validation Loss: 5.410254857451946e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 75/100, Loss: 1.4665205583241914e-07
# Validation Loss: 5.410254857451946e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 76/100, Loss: 2.3431976359233886e-07
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 77/100, Loss: 2.6735066427363563e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 78/100, Loss: 3.5638341699950615e-07
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 79/100, Loss: 1.5509601070107237e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 80/100, Loss: 1.226860959491205e-07
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 81/100, Loss: 2.453717957706658e-07
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 82/100, Loss: 3.2000006910948287e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 83/100, Loss: 9.238715747983406e-08
# Validation Loss: 5.685351425199769e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 84/100, Loss: 2.889567696229278e-07
# Validation Loss: 5.685351425199769e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 85/100, Loss: 2.662327140967591e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 86/100, Loss: 1.781927920774251e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 87/100, Loss: 8.481240598712247e-08
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 88/100, Loss: 3.341568044490373e-07
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 89/100, Loss: 1.2864649434618514e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 90/100, Loss: 1.1051666692907247e-07
# Validation Loss: 5.501953523889824e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 91/100, Loss: 1.6875536335003716e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 92/100, Loss: 4.6652768759258834e-07
# Validation Loss: 5.410254857451946e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 93/100, Loss: 2.8100969018396427e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 94/100, Loss: 2.1258934879142544e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 95/100, Loss: 1.434234384589672e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 96/100, Loss: 2.0004761580594277e-07
# Validation Loss: 5.593652758761891e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 97/100, Loss: 1.4031898309951885e-07
# Validation Loss: 5.410254289017757e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 98/100, Loss: 3.021193091257146e-07
# Validation Loss: 5.410254289017757e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 99/100, Loss: 5.07881088296358e-08
# Validation Loss: 5.410254289017757e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Epoch 100/100, Loss: 5.57551587121452e-08
# Validation Loss: 5.226856387707812e-07, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[13  0]
#  [ 0  0]]
# Test Loss: 2.2252365283748077e-07, Test Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[15  0]
#  [ 0  0]]
