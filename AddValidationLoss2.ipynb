# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
import pickle
import numpy as np

# Define constants
DATA_DIR = 'C:/Users/User/Documents/Lie detect data/EEGData'
BATCH_SIZE = 32
EPOCHS = 100  # Increased to allow early stopping
LEARNING_RATE = 0.001
NUM_FOLDS = 5
PATIENCE = 20  # Early stopping patience

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Custom Dataset class for EEG data
class EEGDataset(Dataset):
    def __init__(self, data_dir):
        self.data = []
        self.labels = []
        self.load_data(data_dir)
        self.normalize_data()

    def load_data(self, data_dir):
        max_length = 0
        temp_data = []
        
        for file_name in os.listdir(data_dir):
            file_path = os.path.join(data_dir, file_name)
            with open(file_path, 'rb') as f:
                eeg_data = pickle.load(f)
                label = 1 if 'lie' in file_name else 0  # Assuming file names contain 'lie' or 'truth'
                temp_data.append((eeg_data, label))
                max_length = max(max_length, eeg_data.shape[1])

        for eeg_data, label in temp_data:
            padded_data = np.pad(eeg_data, ((0, 0), (0, max_length - eeg_data.shape[1])), mode='constant')
            self.data.append(padded_data)
            self.labels.append(label)
        
        self.data = [torch.tensor(d, dtype=torch.float32, device=device) for d in self.data]
        self.labels = torch.tensor(self.labels, dtype=torch.long, device=device)
    
    def normalize_data(self):
        all_data = torch.cat([d.unsqueeze(0) for d in self.data], dim=0)
        mean = all_data.mean()
        std = all_data.std()
        self.data = [(d - mean) / std for d in self.data]

    def augment_data(self, data):
        # Advanced augmentations: Gaussian noise, time shift, scaling
        noise = torch.randn_like(data, device=device) * 0.01
        shift = torch.roll(data, shifts=int(data.shape[1] * 0.1), dims=1)
        scale = data * (1 + 0.1 * torch.randn(1, device=device))
        return noise + shift + scale

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data, label = self.data[idx], self.labels[idx]
        data = self.augment_data(data)  # Apply augmentation
        return data, label

# Define the EEGNet model
class EEGNet(nn.Module):
    def __init__(self, output_size):
        super(EEGNet, self).__init__()
        self.firstconv = nn.Sequential(
            nn.Conv2d(1, 16, (1, 51), padding=(0, 25)),
            nn.BatchNorm2d(16)
        )
        self.depthwiseConv = nn.Sequential(
            nn.Conv2d(16, 32, (65, 1), groups=16),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d((1, 4)),
            nn.Dropout(0.5)
        )
        self.separableConv = nn.Sequential(
            nn.Conv2d(32, 32, (1, 15), padding=(0, 7)),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d((1, 8)),
            nn.Dropout(0.5)
        )
        self.classify = nn.Sequential(
            nn.Flatten(),
            nn.Linear(output_size, 2)
        )

    def forward(self, x):
        x = self.firstconv(x)
        x = self.depthwiseConv(x)
        x = self.separableConv(x)
        return self.classify(x)

# Function to determine the output size of the EEGNet model before the linear layer
def get_output_size(model, shape):
    with torch.no_grad():
        x = torch.zeros(shape, device=device)
        x = model.firstconv(x)
        x = model.depthwiseConv(x)
        x = model.separableConv(x)
        return x.view(x.size(0), -1).size(1)

# Load data
dataset = EEGDataset(DATA_DIR)

# Determine the correct input size for the linear layer
dummy_input_shape = (1, 1, 65, max([d.shape[1] for d in dataset.data]))  # (batch_size, channels, height, width)
output_size = get_output_size(EEGNet(output_size=0).to(device), dummy_input_shape)

# K-Fold Cross Validation
kf = KFold(n_splits=NUM_FOLDS, shuffle=True)

accuracies = []
precisions = []
recalls = []
f1s = []
aucs = []
val_losses = []  # New list to store validation losses

for fold, (train_index, val_index) in enumerate(kf.split(dataset)):
    print(f'Fold {fold+1}')
    
    train_subset = Subset(dataset, train_index)
    val_subset = Subset(dataset, val_index)

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

    # Initialize model, loss function, and optimizer
    model = EEGNet(output_size=output_size).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

    best_val_accuracy = 0
    best_val_loss = float('inf')  # Track the best validation loss
    patience_counter = 0

    # Training loop
    for epoch in range(EPOCHS):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs.unsqueeze(1))  # Adding channel dimension
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        scheduler.step()

        # Validation
        model.eval()
        correct = 0
        total = 0
        val_running_loss = 0.0
        all_labels = []
        all_predictions = []
        all_probs = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs.unsqueeze(1))  # Adding channel dimension
                loss = criterion(outputs, labels)
                val_running_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                all_labels.extend(labels.cpu().numpy())
                all_predictions.extend(predicted.cpu().numpy())
                all_probs.extend(torch.softmax(outputs, dim=1)[:, 1].cpu().numpy())

        val_loss = val_running_loss / len(val_loader)
        val_accuracy = 100 * correct / total
        val_precision = precision_score(all_labels, all_predictions, average='macro')
        val_recall = recall_score(all_labels, all_predictions, average='macro')
        val_f1 = f1_score(all_labels, all_predictions, average='macro')
        val_auc = roc_auc_score(all_labels, all_probs)

        print(f"Epoch {epoch+1}/{EPOCHS}, Train Loss: {running_loss/len(train_loader):.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%, AUC: {val_auc:.2f}")

        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_val_accuracy = val_accuracy
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"Early stopping at epoch {epoch+1}")
                break

    # Final validation metrics for the fold
    accuracies.append(best_val_accuracy)
    precisions.append(val_precision)
    recalls.append(val_recall)
    f1s.append(val_f1)
    aucs.append(val_auc)
    val_losses.append(best_val_loss)  # Store the best validation loss
    print(f'Final Accuracy for fold {fold+1}: {best_val_accuracy:.2f}%')
    print(f'Final Validation Loss for fold {fold+1}: {best_val_loss:.4f}')
    print(f'Final Precision for fold {fold+1}: {val_precision:.2f}')
    print(f'Final Recall for fold {fold+1}: {val_recall:.2f}')
    print(f'Final F1-Score for fold {fold+1}: {val_f1:.2f}')
    print(f'Final AUC for fold {fold+1}: {val_auc:.2f}\n')

# Report average performance across all folds
print(f'Average Accuracy: {np.mean(accuracies):.2f}%')
print(f'Average Validation Loss: {np.mean(val_losses):.4f}')
print(f'Average Precision: {np.mean(precisions):.2f}')
print(f'Average Recall: {np.mean(recalls):.2f}')
print(f'Average F1-Score: {np.mean(f1s):.2f}')
print(f'Average AUC: {np.mean(aucs):.2f}')
# Out:
# Using device: cuda
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\torch\nn\init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Fold 1
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/100, Train Loss: 0.6135, Val Loss: 0.6449, Val Accuracy: 66.67%, AUC: 0.88
# Epoch 2/100, Train Loss: 0.5394, Val Loss: 0.6637, Val Accuracy: 77.78%, AUC: 0.82
# Epoch 3/100, Train Loss: 0.4395, Val Loss: 0.6634, Val Accuracy: 66.67%, AUC: 0.78
# Epoch 4/100, Train Loss: 0.4361, Val Loss: 0.6242, Val Accuracy: 77.78%, AUC: 0.83
# Epoch 5/100, Train Loss: 0.3701, Val Loss: 0.6401, Val Accuracy: 66.67%, AUC: 0.88
# Epoch 6/100, Train Loss: 0.2852, Val Loss: 0.5843, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 7/100, Train Loss: 0.2941, Val Loss: 0.5884, Val Accuracy: 77.78%, AUC: 0.85
# Epoch 8/100, Train Loss: 0.3256, Val Loss: 0.5863, Val Accuracy: 77.78%, AUC: 0.85
# Epoch 9/100, Train Loss: 0.4286, Val Loss: 0.6228, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 10/100, Train Loss: 0.2801, Val Loss: 0.7864, Val Accuracy: 77.78%, AUC: 0.76
# Epoch 11/100, Train Loss: 0.3033, Val Loss: 0.7607, Val Accuracy: 77.78%, AUC: 0.79
# Epoch 12/100, Train Loss: 0.2318, Val Loss: 0.7312, Val Accuracy: 77.78%, AUC: 0.81
# Epoch 13/100, Train Loss: 0.2216, Val Loss: 0.6828, Val Accuracy: 77.78%, AUC: 0.76
# Epoch 14/100, Train Loss: 0.2291, Val Loss: 0.6851, Val Accuracy: 77.78%, AUC: 0.76
# Epoch 15/100, Train Loss: 0.2556, Val Loss: 0.6223, Val Accuracy: 77.78%, AUC: 0.76
# Epoch 16/100, Train Loss: 0.2051, Val Loss: 0.5955, Val Accuracy: 77.78%, AUC: 0.82
# Epoch 17/100, Train Loss: 0.2666, Val Loss: 0.5876, Val Accuracy: 77.78%, AUC: 0.82
# Epoch 18/100, Train Loss: 0.1781, Val Loss: 0.5573, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 19/100, Train Loss: 0.2907, Val Loss: 0.5473, Val Accuracy: 83.33%, AUC: 0.83
# Epoch 20/100, Train Loss: 0.1737, Val Loss: 0.5209, Val Accuracy: 83.33%, AUC: 0.85
# Epoch 21/100, Train Loss: 0.2660, Val Loss: 0.5161, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 22/100, Train Loss: 0.1992, Val Loss: 0.5009, Val Accuracy: 83.33%, AUC: 0.85
# Epoch 23/100, Train Loss: 0.2038, Val Loss: 0.4987, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 24/100, Train Loss: 0.2019, Val Loss: 0.4960, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 25/100, Train Loss: 0.1668, Val Loss: 0.5326, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 26/100, Train Loss: 0.2189, Val Loss: 0.5129, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 27/100, Train Loss: 0.1774, Val Loss: 0.5201, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 28/100, Train Loss: 0.2578, Val Loss: 0.5108, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 29/100, Train Loss: 0.2573, Val Loss: 0.5250, Val Accuracy: 83.33%, AUC: 0.85
# Epoch 30/100, Train Loss: 0.1606, Val Loss: 0.5193, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 31/100, Train Loss: 0.1651, Val Loss: 0.5173, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 32/100, Train Loss: 0.4180, Val Loss: 0.5119, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 33/100, Train Loss: 0.2744, Val Loss: 0.4897, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 34/100, Train Loss: 0.2040, Val Loss: 0.5105, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 35/100, Train Loss: 0.1791, Val Loss: 0.5080, Val Accuracy: 83.33%, AUC: 0.85
# Epoch 36/100, Train Loss: 0.2149, Val Loss: 0.5296, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 37/100, Train Loss: 0.1483, Val Loss: 0.5076, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 38/100, Train Loss: 0.1845, Val Loss: 0.5304, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 39/100, Train Loss: 0.1815, Val Loss: 0.5167, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 40/100, Train Loss: 0.2006, Val Loss: 0.5088, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 41/100, Train Loss: 0.2031, Val Loss: 0.5570, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 42/100, Train Loss: 0.1609, Val Loss: 0.5400, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 43/100, Train Loss: 0.2044, Val Loss: 0.5328, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 44/100, Train Loss: 0.1939, Val Loss: 0.5305, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 45/100, Train Loss: 0.2055, Val Loss: 0.5319, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 46/100, Train Loss: 0.2410, Val Loss: 0.5468, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 47/100, Train Loss: 0.2140, Val Loss: 0.5162, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 48/100, Train Loss: 0.1979, Val Loss: 0.5382, Val Accuracy: 83.33%, AUC: 0.85
# Epoch 49/100, Train Loss: 0.2296, Val Loss: 0.5226, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 50/100, Train Loss: 0.1715, Val Loss: 0.5383, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 51/100, Train Loss: 0.2056, Val Loss: 0.5286, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 52/100, Train Loss: 0.2643, Val Loss: 0.5107, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 53/100, Train Loss: 0.2081, Val Loss: 0.5280, Val Accuracy: 83.33%, AUC: 0.86
# Early stopping at epoch 53
# Final Accuracy for fold 1: 83.33%
# Final Validation Loss for fold 1: 0.4897
# Final Precision for fold 1: 0.83
# Final Recall for fold 1: 0.88
# Final F1-Score for fold 1: 0.83
# Final AUC for fold 1: 0.86
#
# Fold 2
# Epoch 1/100, Train Loss: 0.7504, Val Loss: 0.6605, Val Accuracy: 66.67%, AUC: 0.51
# Epoch 2/100, Train Loss: 0.5973, Val Loss: 0.6278, Val Accuracy: 72.22%, AUC: 0.75
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/100, Train Loss: 0.4701, Val Loss: 0.5760, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 4/100, Train Loss: 0.4763, Val Loss: 0.5603, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 5/100, Train Loss: 0.4157, Val Loss: 0.5296, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 6/100, Train Loss: 0.3829, Val Loss: 0.4991, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 7/100, Train Loss: 0.3248, Val Loss: 0.4893, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 8/100, Train Loss: 0.2651, Val Loss: 0.5185, Val Accuracy: 72.22%, AUC: 0.83
# Epoch 9/100, Train Loss: 0.3408, Val Loss: 0.5600, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 10/100, Train Loss: 0.2119, Val Loss: 0.5748, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 11/100, Train Loss: 0.2353, Val Loss: 0.5578, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 12/100, Train Loss: 0.1960, Val Loss: 0.5407, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 13/100, Train Loss: 0.3255, Val Loss: 0.5265, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 14/100, Train Loss: 0.2145, Val Loss: 0.5185, Val Accuracy: 77.78%, AUC: 0.89
# Epoch 15/100, Train Loss: 0.1820, Val Loss: 0.5378, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 16/100, Train Loss: 0.1855, Val Loss: 0.5106, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 17/100, Train Loss: 0.2335, Val Loss: 0.4991, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 18/100, Train Loss: 0.1812, Val Loss: 0.4972, Val Accuracy: 77.78%, AUC: 0.89
# Epoch 19/100, Train Loss: 0.2556, Val Loss: 0.4955, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 20/100, Train Loss: 0.1512, Val Loss: 0.5002, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 21/100, Train Loss: 0.1655, Val Loss: 0.4891, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 22/100, Train Loss: 0.2108, Val Loss: 0.5184, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 23/100, Train Loss: 0.1664, Val Loss: 0.5084, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 24/100, Train Loss: 0.2273, Val Loss: 0.4946, Val Accuracy: 77.78%, AUC: 0.89
# Epoch 25/100, Train Loss: 0.1921, Val Loss: 0.5151, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 26/100, Train Loss: 0.1834, Val Loss: 0.4938, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 27/100, Train Loss: 0.2291, Val Loss: 0.4956, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 28/100, Train Loss: 0.1837, Val Loss: 0.5079, Val Accuracy: 77.78%, AUC: 0.89
# Epoch 29/100, Train Loss: 0.1578, Val Loss: 0.4894, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 30/100, Train Loss: 0.1513, Val Loss: 0.5156, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 31/100, Train Loss: 0.1729, Val Loss: 0.5148, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 32/100, Train Loss: 0.2213, Val Loss: 0.5081, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 33/100, Train Loss: 0.1853, Val Loss: 0.4766, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 34/100, Train Loss: 0.2585, Val Loss: 0.4925, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 35/100, Train Loss: 0.1820, Val Loss: 0.5030, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 36/100, Train Loss: 0.2190, Val Loss: 0.4980, Val Accuracy: 77.78%, AUC: 0.89
# Epoch 37/100, Train Loss: 0.1560, Val Loss: 0.5025, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 38/100, Train Loss: 0.1654, Val Loss: 0.5059, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 39/100, Train Loss: 0.2965, Val Loss: 0.4999, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 40/100, Train Loss: 0.2161, Val Loss: 0.5064, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 41/100, Train Loss: 0.1606, Val Loss: 0.5101, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 42/100, Train Loss: 0.2006, Val Loss: 0.4976, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 43/100, Train Loss: 0.1808, Val Loss: 0.5191, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 44/100, Train Loss: 0.1841, Val Loss: 0.5195, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 45/100, Train Loss: 0.1913, Val Loss: 0.5229, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 46/100, Train Loss: 0.1549, Val Loss: 0.5035, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 47/100, Train Loss: 0.2757, Val Loss: 0.5180, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 48/100, Train Loss: 0.1369, Val Loss: 0.5149, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 49/100, Train Loss: 0.2046, Val Loss: 0.5170, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 50/100, Train Loss: 0.1768, Val Loss: 0.5177, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 51/100, Train Loss: 0.2211, Val Loss: 0.5123, Val Accuracy: 72.22%, AUC: 0.89
# Epoch 52/100, Train Loss: 0.2511, Val Loss: 0.5244, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 53/100, Train Loss: 0.1602, Val Loss: 0.5164, Val Accuracy: 72.22%, AUC: 0.88
# Early stopping at epoch 53
# Final Accuracy for fold 2: 72.22%
# Final Validation Loss for fold 2: 0.4766
# Final Precision for fold 2: 0.72
# Final Recall for fold 2: 0.75
# Final F1-Score for fold 2: 0.71
# Final AUC for fold 2: 0.88
#
# Fold 3
# Epoch 1/100, Train Loss: 0.7134, Val Loss: 0.6291, Val Accuracy: 66.67%, AUC: 0.64
# Epoch 2/100, Train Loss: 0.6007, Val Loss: 0.6579, Val Accuracy: 61.11%, AUC: 0.62
# Epoch 3/100, Train Loss: 0.5651, Val Loss: 0.5966, Val Accuracy: 61.11%, AUC: 0.72
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 4/100, Train Loss: 0.4761, Val Loss: 0.5080, Val Accuracy: 72.22%, AUC: 0.83
# Epoch 5/100, Train Loss: 0.4462, Val Loss: 0.4228, Val Accuracy: 77.78%, AUC: 0.89
# Epoch 6/100, Train Loss: 0.3850, Val Loss: 0.3801, Val Accuracy: 77.78%, AUC: 0.90
# Epoch 7/100, Train Loss: 0.2851, Val Loss: 0.3579, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 8/100, Train Loss: 0.2731, Val Loss: 0.3273, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 9/100, Train Loss: 0.2677, Val Loss: 0.2909, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 10/100, Train Loss: 0.2425, Val Loss: 0.2725, Val Accuracy: 83.33%, AUC: 0.93
# Epoch 11/100, Train Loss: 0.2477, Val Loss: 0.2729, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 12/100, Train Loss: 0.1886, Val Loss: 0.2979, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 13/100, Train Loss: 0.2348, Val Loss: 0.2818, Val Accuracy: 88.89%, AUC: 0.92
# Epoch 14/100, Train Loss: 0.2178, Val Loss: 0.2994, Val Accuracy: 83.33%, AUC: 0.90
# Epoch 15/100, Train Loss: 0.2147, Val Loss: 0.3013, Val Accuracy: 83.33%, AUC: 0.90
# Epoch 16/100, Train Loss: 0.2433, Val Loss: 0.3017, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 17/100, Train Loss: 0.2776, Val Loss: 0.3099, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 18/100, Train Loss: 0.2356, Val Loss: 0.3221, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 19/100, Train Loss: 0.1773, Val Loss: 0.3224, Val Accuracy: 83.33%, AUC: 0.90
# Epoch 20/100, Train Loss: 0.3186, Val Loss: 0.3243, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 21/100, Train Loss: 0.1999, Val Loss: 0.3426, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 22/100, Train Loss: 0.1861, Val Loss: 0.3312, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 23/100, Train Loss: 0.2756, Val Loss: 0.3450, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 24/100, Train Loss: 0.2177, Val Loss: 0.3414, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 25/100, Train Loss: 0.2350, Val Loss: 0.3280, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 26/100, Train Loss: 0.1559, Val Loss: 0.3454, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 27/100, Train Loss: 0.2213, Val Loss: 0.3236, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 28/100, Train Loss: 0.2595, Val Loss: 0.3324, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 29/100, Train Loss: 0.1778, Val Loss: 0.3287, Val Accuracy: 83.33%, AUC: 0.90
# Epoch 30/100, Train Loss: 0.3066, Val Loss: 0.3266, Val Accuracy: 83.33%, AUC: 0.90
# Early stopping at epoch 30
# Final Accuracy for fold 3: 83.33%
# Final Validation Loss for fold 3: 0.2725
# Final Precision for fold 3: 0.81
# Final Recall for fold 3: 0.83
# Final F1-Score for fold 3: 0.82
# Final AUC for fold 3: 0.90
#
# Fold 4
# Epoch 1/100, Train Loss: 0.8220, Val Loss: 0.6401, Val Accuracy: 61.11%, AUC: 0.62
# Epoch 2/100, Train Loss: 0.5448, Val Loss: 0.6635, Val Accuracy: 55.56%, AUC: 0.78
# Epoch 3/100, Train Loss: 0.5408, Val Loss: 0.6483, Val Accuracy: 55.56%, AUC: 0.77
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 4/100, Train Loss: 0.4796, Val Loss: 0.6141, Val Accuracy: 55.56%, AUC: 0.70
# Epoch 5/100, Train Loss: 0.3956, Val Loss: 0.5750, Val Accuracy: 72.22%, AUC: 0.77
# Epoch 6/100, Train Loss: 0.3808, Val Loss: 0.5494, Val Accuracy: 66.67%, AUC: 0.81
# Epoch 7/100, Train Loss: 0.3286, Val Loss: 0.5386, Val Accuracy: 66.67%, AUC: 0.83
# Epoch 8/100, Train Loss: 0.3472, Val Loss: 0.5181, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 9/100, Train Loss: 0.2980, Val Loss: 0.5199, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 10/100, Train Loss: 0.2834, Val Loss: 0.5233, Val Accuracy: 66.67%, AUC: 0.84
# Epoch 11/100, Train Loss: 0.2301, Val Loss: 0.5396, Val Accuracy: 72.22%, AUC: 0.84
# Epoch 12/100, Train Loss: 0.3883, Val Loss: 0.5409, Val Accuracy: 72.22%, AUC: 0.84
# Epoch 13/100, Train Loss: 0.2794, Val Loss: 0.5258, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 14/100, Train Loss: 0.2972, Val Loss: 0.5139, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 15/100, Train Loss: 0.3112, Val Loss: 0.5103, Val Accuracy: 72.22%, AUC: 0.84
# Epoch 16/100, Train Loss: 0.3183, Val Loss: 0.5127, Val Accuracy: 66.67%, AUC: 0.84
# Epoch 17/100, Train Loss: 0.2404, Val Loss: 0.4885, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 18/100, Train Loss: 0.1928, Val Loss: 0.5026, Val Accuracy: 72.22%, AUC: 0.87
# Epoch 19/100, Train Loss: 0.2134, Val Loss: 0.5135, Val Accuracy: 72.22%, AUC: 0.84
# Epoch 20/100, Train Loss: 0.2719, Val Loss: 0.4887, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 21/100, Train Loss: 0.2383, Val Loss: 0.5253, Val Accuracy: 72.22%, AUC: 0.84
# Epoch 22/100, Train Loss: 0.2834, Val Loss: 0.5332, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 23/100, Train Loss: 0.2484, Val Loss: 0.5456, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 24/100, Train Loss: 0.2285, Val Loss: 0.5210, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 25/100, Train Loss: 0.2620, Val Loss: 0.5074, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 26/100, Train Loss: 0.2312, Val Loss: 0.5088, Val Accuracy: 72.22%, AUC: 0.88
# Epoch 27/100, Train Loss: 0.2049, Val Loss: 0.5234, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 28/100, Train Loss: 0.3035, Val Loss: 0.5095, Val Accuracy: 77.78%, AUC: 0.87
# Epoch 29/100, Train Loss: 0.2722, Val Loss: 0.5122, Val Accuracy: 72.22%, AUC: 0.87
# Epoch 30/100, Train Loss: 0.2440, Val Loss: 0.5210, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 31/100, Train Loss: 0.2667, Val Loss: 0.5376, Val Accuracy: 72.22%, AUC: 0.84
# Epoch 32/100, Train Loss: 0.2195, Val Loss: 0.5523, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 33/100, Train Loss: 0.3177, Val Loss: 0.5257, Val Accuracy: 72.22%, AUC: 0.87
# Epoch 34/100, Train Loss: 0.2658, Val Loss: 0.5269, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 35/100, Train Loss: 0.1983, Val Loss: 0.5090, Val Accuracy: 72.22%, AUC: 0.87
# Epoch 36/100, Train Loss: 0.2338, Val Loss: 0.5142, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 37/100, Train Loss: 0.2470, Val Loss: 0.5082, Val Accuracy: 77.78%, AUC: 0.86
# Early stopping at epoch 37
# Final Accuracy for fold 4: 72.22%
# Final Validation Loss for fold 4: 0.4885
# Final Precision for fold 4: 0.82
# Final Recall for fold 4: 0.82
# Final F1-Score for fold 4: 0.78
# Final AUC for fold 4: 0.86
#
# Fold 5
# Epoch 1/100, Train Loss: 0.6731, Val Loss: 0.6416, Val Accuracy: 44.44%, AUC: 0.85
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 2/100, Train Loss: 0.4921, Val Loss: 0.5822, Val Accuracy: 55.56%, AUC: 0.90
# Epoch 3/100, Train Loss: 0.4273, Val Loss: 0.5279, Val Accuracy: 72.22%, AUC: 0.90
# Epoch 4/100, Train Loss: 0.4392, Val Loss: 0.4654, Val Accuracy: 83.33%, AUC: 0.90
# Epoch 5/100, Train Loss: 0.3261, Val Loss: 0.4076, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 6/100, Train Loss: 0.2954, Val Loss: 0.3821, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 7/100, Train Loss: 0.2444, Val Loss: 0.3694, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 8/100, Train Loss: 0.2309, Val Loss: 0.3751, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 9/100, Train Loss: 0.2420, Val Loss: 0.3511, Val Accuracy: 88.89%, AUC: 0.91
# Epoch 10/100, Train Loss: 0.3440, Val Loss: 0.3373, Val Accuracy: 88.89%, AUC: 0.90
# Epoch 11/100, Train Loss: 0.1936, Val Loss: 0.3295, Val Accuracy: 88.89%, AUC: 0.90
# Epoch 12/100, Train Loss: 0.2210, Val Loss: 0.3245, Val Accuracy: 88.89%, AUC: 0.89
# Epoch 13/100, Train Loss: 0.2465, Val Loss: 0.3350, Val Accuracy: 88.89%, AUC: 0.89
# Epoch 14/100, Train Loss: 0.1591, Val Loss: 0.3399, Val Accuracy: 88.89%, AUC: 0.89
# Epoch 15/100, Train Loss: 0.1604, Val Loss: 0.3434, Val Accuracy: 88.89%, AUC: 0.89
# Epoch 16/100, Train Loss: 0.1696, Val Loss: 0.3363, Val Accuracy: 88.89%, AUC: 0.89
# Epoch 17/100, Train Loss: 0.1783, Val Loss: 0.3399, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 18/100, Train Loss: 0.1805, Val Loss: 0.3452, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 19/100, Train Loss: 0.1860, Val Loss: 0.3422, Val Accuracy: 88.89%, AUC: 0.89
# Epoch 20/100, Train Loss: 0.2787, Val Loss: 0.3514, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 21/100, Train Loss: 0.1335, Val Loss: 0.3470, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 22/100, Train Loss: 0.1613, Val Loss: 0.3388, Val Accuracy: 94.44%, AUC: 0.89
# Epoch 23/100, Train Loss: 0.2566, Val Loss: 0.3487, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 24/100, Train Loss: 0.1495, Val Loss: 0.3478, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 25/100, Train Loss: 0.1889, Val Loss: 0.3472, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 26/100, Train Loss: 0.2179, Val Loss: 0.3553, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 27/100, Train Loss: 0.1700, Val Loss: 0.3617, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 28/100, Train Loss: 0.1989, Val Loss: 0.3457, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 29/100, Train Loss: 0.1833, Val Loss: 0.3573, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 30/100, Train Loss: 0.1393, Val Loss: 0.3619, Val Accuracy: 88.89%, AUC: 0.88
# Epoch 31/100, Train Loss: 0.2103, Val Loss: 0.3479, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 32/100, Train Loss: 0.1812, Val Loss: 0.3534, Val Accuracy: 88.89%, AUC: 0.88
# Early stopping at epoch 32
# Final Accuracy for fold 5: 88.89%
# Final Validation Loss for fold 5: 0.3245
# Final Precision for fold 5: 0.89
# Final Recall for fold 5: 0.89
# Final F1-Score for fold 5: 0.89
# Final AUC for fold 5: 0.88
#
# Average Accuracy: 80.00%
# Average Validation Loss: 0.4104
# Average Precision: 0.81
# Average Recall: 0.83
# Average F1-Score: 0.81
# Average AUC: 0.87
