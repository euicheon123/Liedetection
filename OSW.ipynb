# %%
import os
import pickle
import numpy as np

# Function to load the data
def load_eeg_data(file_path):
    with open(file_path, 'rb') as file:
        eeg_data = pickle.load(file)
    return eeg_data

# Function to apply OSW for a single numpy array
def apply_osw(eeg_data, window_size=125, step_size=62):
    n_channels, n_points = eeg_data.shape
    augmented_data = []
    for start in range(0, n_points - window_size + 1, step_size):
        segment = eeg_data[:, start:start + window_size]
        augmented_data.append(segment)
    return np.array(augmented_data)

# Directory paths
input_dir = r'C:\Users\User\Documents\Lie detect data\EEGData'
output_dir = r'C:\Users\User\Documents\Lie detect data\AugmentedEEGData'

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Load, process, and save the EEG data
file_names = [f for f in os.listdir(input_dir) if f.endswith('.pkl')]
for file_name in file_names:
    file_path = os.path.join(input_dir, file_name)
    eeg_data = load_eeg_data(file_path)
    
    # Apply OSW to the dataset
    augmented_data = apply_osw(eeg_data, window_size=125, step_size=62)
    
    # Save augmented data
    augmented_file_path = os.path.join(output_dir, f'augmented_{file_name}')
    with open(augmented_file_path, 'wb') as file:
        pickle.dump(augmented_data, file)
    
    print(f'Processed and saved {file_name} as {augmented_file_path}')

print("All files processed and saved successfully.")
# Out:
# Processed and saved lie_1.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_1.pkl
# Processed and saved lie_10.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_10.pkl
# Processed and saved lie_11.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_11.pkl
# Processed and saved lie_12.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_12.pkl
# Processed and saved lie_13.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_13.pkl
# Processed and saved lie_14.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_14.pkl
# Processed and saved lie_15.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_15.pkl
# Processed and saved lie_16.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_16.pkl
# Processed and saved lie_17.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_17.pkl
# Processed and saved lie_18.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_18.pkl
# Processed and saved lie_19.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_19.pkl
# Processed and saved lie_2.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_2.pkl
# Processed and saved lie_20.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_20.pkl
# Processed and saved lie_21.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_21.pkl
# Processed and saved lie_22.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_22.pkl
# Processed and saved lie_23.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_23.pkl
# Processed and saved lie_24.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_24.pkl
# Processed and saved lie_25.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_25.pkl
# Processed and saved lie_26.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_26.pkl
# Processed and saved lie_27.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_27.pkl
# Processed and saved lie_28.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_28.pkl
# Processed and saved lie_29.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_29.pkl
# Processed and saved lie_3.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_3.pkl
# Processed and saved lie_30.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_30.pkl
# Processed and saved lie_31.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_31.pkl
# Processed and saved lie_32.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_32.pkl
# Processed and saved lie_33.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_33.pkl
# Processed and saved lie_34.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_34.pkl
# Processed and saved lie_35.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_35.pkl
# Processed and saved lie_4.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_4.pkl
# Processed and saved lie_5.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_5.pkl
# Processed and saved lie_6.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_6.pkl
# Processed and saved lie_7.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_7.pkl
# Processed and saved lie_8.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_8.pkl
# Processed and saved lie_9.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_lie_9.pkl
# Processed and saved truth_1.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_1.pkl
# Processed and saved truth_10.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_10.pkl
# Processed and saved truth_11.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_11.pkl
# Processed and saved truth_12.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_12.pkl
# Processed and saved truth_13.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_13.pkl
# Processed and saved truth_14.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_14.pkl
# Processed and saved truth_15.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_15.pkl
# Processed and saved truth_16.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_16.pkl
# Processed and saved truth_17.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_17.pkl
# Processed and saved truth_18.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_18.pkl
# Processed and saved truth_19.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_19.pkl
# Processed and saved truth_2.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_2.pkl
# Processed and saved truth_20.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_20.pkl
# Processed and saved truth_21.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_21.pkl
# Processed and saved truth_22.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_22.pkl
# Processed and saved truth_23.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_23.pkl
# Processed and saved truth_24.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_24.pkl
# Processed and saved truth_25.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_25.pkl
# Processed and saved truth_26.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_26.pkl
# Processed and saved truth_27.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_27.pkl
# Processed and saved truth_28.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_28.pkl
# Processed and saved truth_29.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_29.pkl
# Processed and saved truth_3.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_3.pkl
# Processed and saved truth_30.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_30.pkl
# Processed and saved truth_31.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_31.pkl
# Processed and saved truth_32.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_32.pkl
# Processed and saved truth_33.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_33.pkl
# Processed and saved truth_34.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_34.pkl
# Processed and saved truth_35.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_35.pkl
# Processed and saved truth_36.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_36.pkl
# Processed and saved truth_37.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_37.pkl
# Processed and saved truth_38.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_38.pkl
# Processed and saved truth_39.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_39.pkl
# Processed and saved truth_4.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_4.pkl
# Processed and saved truth_40.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_40.pkl
# Processed and saved truth_41.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_41.pkl
# Processed and saved truth_42.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_42.pkl
# Processed and saved truth_43.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_43.pkl
# Processed and saved truth_44.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_44.pkl
# Processed and saved truth_45.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_45.pkl
# Processed and saved truth_46.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_46.pkl
# Processed and saved truth_47.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_47.pkl
# Processed and saved truth_48.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_48.pkl
# Processed and saved truth_49.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_49.pkl
# Processed and saved truth_5.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_5.pkl
# Processed and saved truth_50.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_50.pkl
# Processed and saved truth_51.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_51.pkl
# Processed and saved truth_52.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_52.pkl
# Processed and saved truth_53.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_53.pkl
# Processed and saved truth_54.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_54.pkl
# Processed and saved truth_55.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_55.pkl
# Processed and saved truth_6.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_6.pkl
# Processed and saved truth_7.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_7.pkl
# Processed and saved truth_8.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_8.pkl
# Processed and saved truth_9.pkl as C:\Users\User\Documents\Lie detect data\AugmentedEEGData\augmented_truth_9.pkl
# All files processed and saved successfully.
