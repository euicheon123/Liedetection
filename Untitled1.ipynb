# %%
import os
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

EEG_DATA_DIR = r'C:\Users\User\Documents\Lie detect data\AugmentedEEGData'
POLY_DATA_DIR = r'C:\Users\User\Documents\Lie detect data\CombinedPolyData'
K_FOLDS = 5  # Number of folds for cross-validation

def pad_sequence(sequence, target_length):
    """Pad the sequence to the target length."""
    pad_length = target_length - sequence.shape[1]
    if pad_length > 0:
        return np.pad(sequence, ((0, 0), (0, pad_length)), mode='constant')
    else:
        return sequence[:, :target_length]

def load_eeg_data(data_dir):
    X, y = [], []
    lie_count, truth_count = 0, 0
    file_sample_counts = []
    for file_name in os.listdir(data_dir):
        if file_name.endswith('.pkl'):
            file_path = os.path.join(data_dir, file_name)
            data = pd.read_pickle(file_path)
            print(f"EEG File: {file_name}, Shape: {data.shape}, Type: {type(data)}")
            label = 0 if 'lie' in file_name.lower() else 1
            X.extend(data)
            y.extend([label] * data.shape[0])
            file_sample_counts.append(data.shape[0])
            if label == 0:
                lie_count += data.shape[0]
            else:
                truth_count += data.shape[0]
    print(f"Loaded from EEG {data_dir}: {lie_count} lie samples, {truth_count} truth samples")
    return np.array(X), np.array(y), file_sample_counts

def load_poly_data(data_dir):
    X, y = [], []
    lie_count, truth_count = 0, 0
    max_length = 0
    for file_name in os.listdir(data_dir):
        if file_name.endswith('.pkl'):
            file_path = os.path.join(data_dir, file_name)
            data = pd.read_pickle(file_path)
            print(f"Poly File: {file_name}, Shape: {data.shape}, Type: {type(data)}")
            max_length = max(max_length, data.shape[1])
            label = 0 if 'lie' in file_name.lower() else 1
            X.append(data)
            y.append(label)
            if label == 0:
                lie_count += 1
            else:
                truth_count += 1
    print(f"Loaded from Poly {data_dir}: {lie_count} lie samples, {truth_count} truth samples")
    
    # Pad all poly samples to the maximum length
    X_padded = np.array([pad_sequence(x, max_length) for x in X])
    return X_padded, np.array(y)

class CombinedDataset(Dataset):
    def __init__(self, eeg_X, eeg_y, poly_X, poly_y, file_sample_counts):
        self.eeg_X = torch.tensor(eeg_X, dtype=torch.float32)
        self.eeg_y = torch.tensor(eeg_y, dtype=torch.long)
        self.poly_X = torch.tensor(poly_X, dtype=torch.float32)
        self.poly_y = torch.tensor(poly_y, dtype=torch.long)
        
        # Create a mapping from EEG sample index to Poly file index
        self.eeg_to_poly_map = []
        poly_index = 0
        for count in file_sample_counts:
            self.eeg_to_poly_map.extend([poly_index] * count)
            poly_index += 1

    def __len__(self):
        return len(self.eeg_X)

    def __getitem__(self, idx):
        eeg_sample = self.eeg_X[idx]
        eeg_label = self.eeg_y[idx]
        poly_idx = self.eeg_to_poly_map[idx]
        poly_sample = self.poly_X[poly_idx]
        poly_label = self.poly_y[poly_idx]
        
        return eeg_sample, eeg_label, poly_sample, poly_label

# ... (keep the data loading and preprocessing code)

# Create full dataset
full_dataset = CombinedDataset(eeg_X, eeg_y, poly_X, poly_y, file_sample_counts)

# Print dataset size and shapes
print("Total number of samples:", len(full_dataset))
print("EEG data shape:", eeg_X.shape)
print("Poly data shape:", poly_X.shape)

# Initialize K-Fold
kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)

# Example of how to use the dataset with DataLoader
train_loader = DataLoader(full_dataset, batch_size=32, shuffle=True)

# Print a sample batch and verify alignment
for eeg_batch, eeg_labels, poly_batch, poly_labels in train_loader:
    print("EEG batch shape:", eeg_batch.shape)
    print("EEG labels shape:", eeg_labels.shape)
    print("Poly batch shape:", poly_batch.shape)
    print("Poly labels shape:", poly_labels.shape)
    
    # Verify label alignment
    print("Labels match:", torch.all(eeg_labels == poly_labels))
    
    # Print a few sample indices and their corresponding data
    for i in range(5):  # Print first 5 samples in the batch
        eeg_sample = eeg_batch[i]
        poly_sample = poly_batch[i]
        print(f"Sample {i}:")
        print(f"  EEG label: {eeg_labels[i].item()}, Poly label: {poly_labels[i].item()}")
        print(f"  EEG data (first 5 values): {eeg_sample[0, :5]}")
        print(f"  Poly data (first 5 values): {poly_sample[0, :5]}")
    
    break  # Just print the first batch
# Out:
# Total number of samples: 935
# EEG data shape: (935, 65, 125)
# Poly data shape: (90, 4, 4475)
# EEG batch shape: torch.Size([32, 65, 125])
# EEG labels shape: torch.Size([32])
# Poly batch shape: torch.Size([32, 4, 4475])
# Poly labels shape: torch.Size([32])
# Labels match: tensor(True)
# Sample 0:
#   EEG label: 1, Poly label: 1
#   EEG data (first 5 values): tensor([-0.1975, -0.1601, -0.1389, -0.1437, -0.1563])
#   Poly data (first 5 values): tensor([-0.1500, -0.1582, -0.1666, -0.1751, -0.1834])
# Sample 1:
#   EEG label: 0, Poly label: 0
#   EEG data (first 5 values): tensor([-0.0554, -0.0628, -0.0727, -0.0840, -0.0956])
#   Poly data (first 5 values): tensor([0.0327, 0.0250, 0.0169, 0.0086, 0.0002])
# Sample 2:
#   EEG label: 0, Poly label: 0
#   EEG data (first 5 values): tensor([0.0052, 0.0109, 0.0121, 0.0067, 0.0043])
#   Poly data (first 5 values): tensor([0.1210, 0.1152, 0.1088, 0.1020, 0.0951])
# Sample 3:
#   EEG label: 0, Poly label: 0
#   EEG data (first 5 values): tensor([-0.0308, -0.0299, -0.0163,  0.0025,  0.0104])
#   Poly data (first 5 values): tensor([0.4107, 0.4042, 0.3968, 0.3886, 0.3800])
# Sample 4:
#   EEG label: 1, Poly label: 1
#   EEG data (first 5 values): tensor([0.3059, 0.3066, 0.2882, 0.2602, 0.2185])
#   Poly data (first 5 values): tensor([-0.2853, -0.2981, -0.3109, -0.3236, -0.3360])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, SubsetRandomSampler
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import numpy as np

class EEGNet(nn.Module):
    def __init__(self, num_classes=2):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, (1, 51), padding='same')
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.depthwiseConv2d = nn.Conv2d(16, 32, (65, 1), groups=16, padding='same')
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.activation = nn.ELU()
        self.pooling = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32 * 65 * 31, num_classes)

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv2d(x)
        x = self.batchnorm2(x)
        x = self.activation(x)
        x = self.pooling(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

class PolygraphNet(nn.Module):
    def __init__(self, num_classes=2):
        super(PolygraphNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, (1, 51), padding='same')
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.depthwiseConv2d = nn.Conv2d(16, 32, (4, 1), groups=16, padding='same')
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.activation = nn.ELU()
        self.pooling = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32 * 4 * 1118, num_classes)

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv2d(x)
        x = self.batchnorm2(x)
        x = self.activation(x)
        x = self.pooling(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

class EnsembleModel(nn.Module):
    def __init__(self, eeg_model, poly_model):
        super(EnsembleModel, self).__init__()
        self.eeg_model = eeg_model
        self.poly_model = poly_model
        self.fc = nn.Linear(4, 2)

    def forward(self, eeg_input, poly_input):
        eeg_output = self.eeg_model(eeg_input)
        poly_output = self.poly_model(poly_input)
        combined_output = torch.cat((eeg_output, poly_output), dim=1)
        output = self.fc(combined_output)
        return output

def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    all_labels, all_predictions = [], []

    with torch.no_grad():
        for eeg_X_batch, eeg_y_batch, poly_X_batch, poly_y_batch in data_loader:
            eeg_X_batch, poly_X_batch = eeg_X_batch.to(device), poly_X_batch.to(device)
            labels = eeg_y_batch.to(device)  # Use EEG labels (they should be the same as Poly labels)
            
            outputs = model(eeg_X_batch, poly_X_batch)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    accuracy = correct / total
    precision = precision_score(all_labels, all_predictions, average='binary', zero_division=1)
    recall = recall_score(all_labels, all_predictions, average='binary', zero_division=1)
    f1 = f1_score(all_labels, all_predictions, average='binary', zero_division=1)
    conf_matrix = confusion_matrix(all_labels, all_predictions, labels=[0, 1])

    return total_loss / len(data_loader), accuracy, precision, recall, f1, conf_matrix

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    best_val_loss = float('inf')
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for eeg_X_batch, eeg_y_batch, poly_X_batch, poly_y_batch in train_loader:
            eeg_X_batch, poly_X_batch = eeg_X_batch.to(device), poly_X_batch.to(device)
            labels = eeg_y_batch.to(device)  # Use EEG labels (they should be the same as Poly labels)
            
            optimizer.zero_grad()
            outputs = model(eeg_X_batch, poly_X_batch)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {train_loss}')
        
        # Evaluate on validation set
        val_loss, val_accuracy, val_precision, val_recall, val_f1, val_conf_matrix = evaluate_model(model, val_loader, criterion, device)
        print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')
        print(f'Precision: {val_precision}, Recall: {val_recall}, F1-score: {val_f1}')
        
        # Save the best model
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()
    
    return best_model_state

# K-Fold Cross-Validation
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_epochs = 100
results = []

for fold, (train_ids, val_ids) in enumerate(kfold.split(full_dataset)):
    print(f'FOLD {fold}')
    print('--------------------------------')

    # Sample elements randomly from a given list of ids, no replacement.
    train_subsampler = SubsetRandomSampler(train_ids)
    val_subsampler = SubsetRandomSampler(val_ids)

    # Define data loaders for training and validation data in this fold
    train_loader = DataLoader(full_dataset, batch_size=32, sampler=train_subsampler)
    val_loader = DataLoader(full_dataset, batch_size=32, sampler=val_subsampler)

    # Initialize models
    eeg_model = EEGNet(num_classes=2).to(device)
    poly_model = PolygraphNet(num_classes=2).to(device)
    ensemble_model = EnsembleModel(eeg_model, poly_model).to(device)
    criterion = nn.CrossEntropyLoss()
    ensemble_optimizer = optim.Adam(ensemble_model.parameters(), lr=0.001)

    # Train the model
    best_model_state = train_model(ensemble_model, train_loader, val_loader, criterion, ensemble_optimizer, num_epochs, device)

    # Load the best model and evaluate on validation set
    ensemble_model.load_state_dict(best_model_state)
    val_loss, val_accuracy, val_precision, val_recall, val_f1, val_conf_matrix = evaluate_model(ensemble_model, val_loader, criterion, device)
    
    print(f'Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')
    print(f'Precision: {val_precision}, Recall: {val_recall}, F1-score: {val_f1}')
    print('Confusion Matrix:')
    print(val_conf_matrix)
    
    results.append({
        'fold': fold,
        'val_loss': val_loss,
        'val_accuracy': val_accuracy,
        'val_precision': val_precision,
        'val_recall': val_recall,
        'val_f1': val_f1
    })

# Print average results
avg_accuracy = np.mean([r['val_accuracy'] for r in results])
avg_precision = np.mean([r['val_precision'] for r in results])
avg_recall = np.mean([r['val_recall'] for r in results])
avg_f1 = np.mean([r['val_f1'] for r in results])

print("\nAverage results across all folds:")
print(f"Accuracy: {avg_accuracy:.4f}")
print(f"Precision: {avg_precision:.4f}")
print(f"Recall: {avg_recall:.4f}")
print(f"F1-score: {avg_f1:.4f}")
# Out:
# FOLD 0
# --------------------------------
# Epoch 1/100, Loss: 0.5202799517816553
# Validation Loss: 0.0633908886811696, Validation Accuracy: 0.9679144385026738
# Precision: 0.9824561403508771, Recall: 0.9655172413793104, F1-score: 0.9739130434782609
# Epoch 2/100, Loss: 0.07112023739076297
# Validation Loss: 0.016409436907755055, Validation Accuracy: 0.9946524064171123
# Precision: 0.9914529914529915, Recall: 1.0, F1-score: 0.9957081545064378
# Epoch 3/100, Loss: 0.02421794292604318
# Validation Loss: 0.011455707989322642, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 4/100, Loss: 0.017079513973537058
# Validation Loss: 0.007598093691437195, Validation Accuracy: 0.9946524064171123
# Precision: 1.0, Recall: 0.9913793103448276, F1-score: 0.9956709956709957
# Epoch 5/100, Loss: 0.009633043012399867
# Validation Loss: 0.003353922327126687, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 6/100, Loss: 0.0025871901602840808
# Validation Loss: 0.001970864577742759, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 7/100, Loss: 0.0015001967182494507
# Validation Loss: 0.001459184485914496, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 8/100, Loss: 0.0013382411584643705
# Validation Loss: 0.0015019694304404159, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 9/100, Loss: 0.0011255484014327521
# Validation Loss: 0.001309583023006174, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 10/100, Loss: 0.0011281679935185214
# Validation Loss: 0.0011379907664377242, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 11/100, Loss: 0.000983244213330181
# Validation Loss: 0.0011030997502530226, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 12/100, Loss: 0.0006430456223398551
# Validation Loss: 0.0010073753116254618, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 13/100, Loss: 0.0012573178077370055
# Validation Loss: 0.0009306324949041785, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 14/100, Loss: 0.0007423487343961218
# Validation Loss: 0.0006714182964060456, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 15/100, Loss: 0.0005580836874988412
# Validation Loss: 0.000638464739798413, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 16/100, Loss: 0.0005438614323717653
# Validation Loss: 0.0006118958729833442, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 17/100, Loss: 0.0005594639398320093
# Validation Loss: 0.0005957792091066949, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 18/100, Loss: 0.000511680913272509
# Validation Loss: 0.0005368655680892213, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 19/100, Loss: 0.0003674015641384661
# Validation Loss: 0.0006226116565812845, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 20/100, Loss: 0.00035221329584089744
# Validation Loss: 0.00048209656112400506, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 21/100, Loss: 0.000387437173969829
# Validation Loss: 0.0004660592614224394, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 22/100, Loss: 0.0003177675794603374
# Validation Loss: 0.0003839130846851428, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 23/100, Loss: 0.0003579911817794823
# Validation Loss: 0.00041891464206855744, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 24/100, Loss: 0.0001942463832544187
# Validation Loss: 0.00031633586331736296, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 25/100, Loss: 0.00021712038623415234
# Validation Loss: 0.00034780821473153384, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 26/100, Loss: 0.0002769091969033373
# Validation Loss: 0.0003494236922657971, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 27/100, Loss: 0.0002217555881240211
# Validation Loss: 0.0003684430400123044, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 28/100, Loss: 0.00014278123455824243
# Validation Loss: 0.0003938806771657255, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 29/100, Loss: 0.00027789838554781454
# Validation Loss: 0.00030029532475358184, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 30/100, Loss: 0.0002689484926108321
# Validation Loss: 0.00026057224386022426, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 31/100, Loss: 0.00021530101582811767
# Validation Loss: 0.0003078352877613118, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 32/100, Loss: 0.00018718163762798667
# Validation Loss: 0.0003004311577872916, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 33/100, Loss: 0.00019078926792322667
# Validation Loss: 0.00025882877055967885, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 34/100, Loss: 0.0001391463231830888
# Validation Loss: 0.00018043989894067636, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 35/100, Loss: 0.00013910084236101738
# Validation Loss: 0.00021611526767628675, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 36/100, Loss: 0.00014824865142297008
# Validation Loss: 0.00022728049149615495, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 37/100, Loss: 0.00018723127288581645
# Validation Loss: 0.00026072643292233505, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 38/100, Loss: 0.00010997462968020955
# Validation Loss: 0.00022312819904376133, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 39/100, Loss: 0.0001672423795753275
# Validation Loss: 0.0002478056333832986, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 40/100, Loss: 0.00013062012760656216
# Validation Loss: 0.0002868626276419188, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 41/100, Loss: 0.00016566182818185857
# Validation Loss: 0.00018028108191477563, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 42/100, Loss: 0.00012018247822235632
# Validation Loss: 0.0001890573342582987, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 43/100, Loss: 0.00013120264831438058
# Validation Loss: 0.00024326669775594686, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 44/100, Loss: 0.00012276783297693328
# Validation Loss: 0.00017315694109735583, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 45/100, Loss: 8.070246773309957e-05
# Validation Loss: 0.0001541996965291522, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 46/100, Loss: 0.00010979781419943417
# Validation Loss: 0.00015714272285549669, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 47/100, Loss: 8.558874066011413e-05
# Validation Loss: 0.00013968592353800582, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 48/100, Loss: 9.55423874936893e-05
# Validation Loss: 0.00012790180062438594, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 49/100, Loss: 6.0338397879888817e-05
# Validation Loss: 0.00010987883464016097, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 50/100, Loss: 0.00010194595325015617
# Validation Loss: 0.00011270024469922646, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 51/100, Loss: 5.451791844753492e-05
# Validation Loss: 0.0001247097772344811, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 52/100, Loss: 5.8758093435547685e-05
# Validation Loss: 0.0001464092157827205, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 53/100, Loss: 0.00010120665298056035
# Validation Loss: 0.0002191530673295953, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 54/100, Loss: 7.646244068245285e-05
# Validation Loss: 0.00012143364710937021, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 55/100, Loss: 8.65795274667865e-05
# Validation Loss: 0.00012502203935582656, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 56/100, Loss: 5.403924436938231e-05
# Validation Loss: 0.00012779329434427686, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 57/100, Loss: 7.802083927307042e-05
# Validation Loss: 0.0001417802635235906, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 58/100, Loss: 7.46628538976779e-05
# Validation Loss: 0.00010043149268312845, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 59/100, Loss: 5.249472145655668e-05
# Validation Loss: 0.00010824793086309607, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 60/100, Loss: 9.296688655998271e-05
# Validation Loss: 8.327852704799928e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 61/100, Loss: 7.05509604870258e-05
# Validation Loss: 0.0001398566679047993, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 62/100, Loss: 5.496017922131576e-05
# Validation Loss: 0.00011750731668295582, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 63/100, Loss: 7.055699609281874e-05
# Validation Loss: 0.00011247202913485428, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 64/100, Loss: 4.8420824880028114e-05
# Validation Loss: 0.00010568898073870514, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 65/100, Loss: 4.628786636355168e-05
# Validation Loss: 0.00011413169905457228, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 66/100, Loss: 7.939855950667152e-05
# Validation Loss: 9.20117853032328e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 67/100, Loss: 4.555074982211712e-05
# Validation Loss: 0.00010627498477333575, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 68/100, Loss: 5.6751706043911554e-05
# Validation Loss: 7.97859331669315e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 69/100, Loss: 0.00024183914947191928
# Validation Loss: 0.00014845764515788082, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 70/100, Loss: 7.915759018987482e-05
# Validation Loss: 9.369080423008806e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 71/100, Loss: 6.459990681643528e-05
# Validation Loss: 0.00010112968023652986, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 72/100, Loss: 4.949149406267376e-05
# Validation Loss: 6.811678698189401e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 73/100, Loss: 3.996479575837005e-05
# Validation Loss: 6.81329015984981e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 74/100, Loss: 5.198641242287749e-05
# Validation Loss: 6.76142595921192e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 75/100, Loss: 3.812318936978013e-05
# Validation Loss: 7.461964852003196e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 76/100, Loss: 4.654134938101665e-05
# Validation Loss: 6.099438405726687e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 77/100, Loss: 3.932461769462492e-05
# Validation Loss: 6.422563880429759e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 78/100, Loss: 0.0001391703705356425
# Validation Loss: 8.518281030471068e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 79/100, Loss: 5.83311222885167e-05
# Validation Loss: 0.0001637542050805981, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 80/100, Loss: 6.201242127209146e-05
# Validation Loss: 4.759865070506445e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 81/100, Loss: 3.8673383819798346e-05
# Validation Loss: 5.251508666030228e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 82/100, Loss: 3.0951369929847296e-05
# Validation Loss: 4.866448178593904e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 83/100, Loss: 6.087733187539376e-05
# Validation Loss: 7.537779993072036e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 84/100, Loss: 2.8893627579407166e-05
# Validation Loss: 5.232562743155237e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 85/100, Loss: 3.365955669920595e-05
# Validation Loss: 4.952986599467598e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 86/100, Loss: 2.6067421361316196e-05
# Validation Loss: 5.080373496942533e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 87/100, Loss: 3.380114328166428e-05
# Validation Loss: 4.5112574639460945e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 88/100, Loss: 2.761002082725857e-05
# Validation Loss: 6.526916611922691e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 89/100, Loss: 3.532482182322383e-05
# Validation Loss: 6.520950027303722e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 90/100, Loss: 5.0101176939006585e-05
# Validation Loss: 4.860052827856028e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 91/100, Loss: 2.035479856132838e-05
# Validation Loss: 4.840508299253088e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 92/100, Loss: 1.8829683047745977e-05
# Validation Loss: 4.913177929211088e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 93/100, Loss: 2.448018209596133e-05
# Validation Loss: 3.413968613585894e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 94/100, Loss: 2.1183160972289745e-05
# Validation Loss: 5.095309052194352e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 95/100, Loss: 2.4601074017027713e-05
# Validation Loss: 3.706424569334862e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 96/100, Loss: 2.8679307317721243e-05
# Validation Loss: 6.034916668795631e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 97/100, Loss: 1.551841285163391e-05
# Validation Loss: 4.4531978801387595e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 98/100, Loss: 1.7239022717478274e-05
# Validation Loss: 4.300866203266196e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 99/100, Loss: 2.7134992704347383e-05
# Validation Loss: 3.2430902782228564e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 100/100, Loss: 2.033848740549497e-05
# Validation Loss: 3.794851723644873e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Validation Loss: 3.7494371857368e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[ 71   0]
#  [  0 116]]
# FOLD 1
# --------------------------------
# Epoch 1/100, Loss: 0.3842413838331898
# Validation Loss: 0.08864121201137702, Validation Accuracy: 0.9679144385026738
# Precision: 1.0, Recall: 0.9487179487179487, F1-score: 0.9736842105263158
# Epoch 2/100, Loss: 0.04352539024936656
# Validation Loss: 0.04165035548309485, Validation Accuracy: 0.9893048128342246
# Precision: 1.0, Recall: 0.9829059829059829, F1-score: 0.9913793103448276
# Epoch 3/100, Loss: 0.02026106923100694
# Validation Loss: 0.05273123873242488, Validation Accuracy: 0.9893048128342246
# Precision: 1.0, Recall: 0.9829059829059829, F1-score: 0.9913793103448276
# Epoch 4/100, Loss: 0.017993323709864246
# Validation Loss: 0.0436332830771183, Validation Accuracy: 0.9893048128342246
# Precision: 1.0, Recall: 0.9829059829059829, F1-score: 0.9913793103448276
# Epoch 5/100, Loss: 0.008080152236592161
# Validation Loss: 0.026141930662561208, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 6/100, Loss: 0.004449486424467371
# Validation Loss: 0.025985130031282704, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 7/100, Loss: 0.002237578013591701
# Validation Loss: 0.017035285922853898, Validation Accuracy: 0.983957219251337
# Precision: 0.9913793103448276, Recall: 0.9829059829059829, F1-score: 0.9871244635193133
# Epoch 8/100, Loss: 0.0024737212670515873
# Validation Loss: 0.01596247897638629, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 9/100, Loss: 0.0016074448852426333
# Validation Loss: 0.012142778713799393, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 10/100, Loss: 0.0016983366676868172
# Validation Loss: 0.010150016508608436, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 11/100, Loss: 0.0008237961178565456
# Validation Loss: 0.009856192560012763, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 12/100, Loss: 0.001027657647682645
# Validation Loss: 0.009800278967304621, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 13/100, Loss: 0.001106160173852307
# Validation Loss: 0.008526810250865916, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 14/100, Loss: 0.0009523359334101164
# Validation Loss: 0.007964295107133998, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 15/100, Loss: 0.0007615167428411951
# Validation Loss: 0.00662744787405245, Validation Accuracy: 0.9946524064171123
# Precision: 0.9915254237288136, Recall: 1.0, F1-score: 0.9957446808510638
# Epoch 16/100, Loss: 0.000571415829047813
# Validation Loss: 0.0057394289469812065, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 17/100, Loss: 0.0004929342515727816
# Validation Loss: 0.005332843747358614, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 18/100, Loss: 0.000404219098224227
# Validation Loss: 0.00598614397070681, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 19/100, Loss: 0.000420904243280044
# Validation Loss: 0.005709538236260414, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 20/100, Loss: 0.00032372455643780995
# Validation Loss: 0.004298953271548574, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 21/100, Loss: 0.0003840682633532803
# Validation Loss: 0.00403341088531306, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 22/100, Loss: 0.0004553618797065913
# Validation Loss: 0.00494525529211387, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 23/100, Loss: 0.00028658951760007767
# Validation Loss: 0.004540644401762013, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 24/100, Loss: 0.000369102225666514
# Validation Loss: 0.0036069108027732, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 25/100, Loss: 0.00023942965655502727
# Validation Loss: 0.0032416411268059164, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 26/100, Loss: 0.00019956235684048806
# Validation Loss: 0.0030680910567753017, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 27/100, Loss: 0.0002523525424512248
# Validation Loss: 0.003196512751552897, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 28/100, Loss: 0.0002623614672453793
# Validation Loss: 0.0034074126621514247, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 29/100, Loss: 0.0003116855549099758
# Validation Loss: 0.003368684689727767, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 30/100, Loss: 0.00019019992494880475
# Validation Loss: 0.003192693940945901, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 31/100, Loss: 0.00019357018716921934
# Validation Loss: 0.0028898553755425382, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 32/100, Loss: 0.00012229313231652364
# Validation Loss: 0.0024045062164077535, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 33/100, Loss: 0.0001803878058505385
# Validation Loss: 0.002442003595206188, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 34/100, Loss: 0.0001771070343844864
# Validation Loss: 0.00245328075713284, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 35/100, Loss: 0.00018172154094979
# Validation Loss: 0.00275879514326031, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 36/100, Loss: 0.00013805696568169878
# Validation Loss: 0.0024112332406123946, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 37/100, Loss: 0.000190849748984571
# Validation Loss: 0.002694888867457242, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 38/100, Loss: 0.0001225208381659589
# Validation Loss: 0.0024717390406294726, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 39/100, Loss: 0.00017478409383405355
# Validation Loss: 0.002168031736194583, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 40/100, Loss: 0.0001502874860458784
# Validation Loss: 0.002472003716926944, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 41/100, Loss: 0.00011639168041691998
# Validation Loss: 0.0020362449298166516, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 42/100, Loss: 0.00011723451969677019
# Validation Loss: 0.001737150750462509, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 43/100, Loss: 9.479671746248641e-05
# Validation Loss: 0.002007267265677607, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 44/100, Loss: 0.0001152401507245789
# Validation Loss: 0.0018165312637089908, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 45/100, Loss: 0.00011597819233581201
# Validation Loss: 0.0018199343843055733, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 46/100, Loss: 7.002906238540163e-05
# Validation Loss: 0.0014174758084664063, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 47/100, Loss: 0.00012741471795152393
# Validation Loss: 0.001977644212577919, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 48/100, Loss: 7.744603168191588e-05
# Validation Loss: 0.0018500642148258823, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 49/100, Loss: 7.703101551470581e-05
# Validation Loss: 0.0013643597341494267, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 50/100, Loss: 8.682078059033908e-05
# Validation Loss: 0.0014367727174734075, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 51/100, Loss: 7.598765672393408e-05
# Validation Loss: 0.0018098382036744927, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 52/100, Loss: 5.506930826489528e-05
# Validation Loss: 0.001406868479231586, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 53/100, Loss: 7.097344034375415e-05
# Validation Loss: 0.0013329740574287523, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 54/100, Loss: 7.035492889310528e-05
# Validation Loss: 0.001307649705267977, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 55/100, Loss: 6.844177623103558e-05
# Validation Loss: 0.001315231521706058, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 56/100, Loss: 6.153195780219296e-05
# Validation Loss: 0.0011401186069027365, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 57/100, Loss: 4.6391543511011456e-05
# Validation Loss: 0.001128764988607145, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 58/100, Loss: 4.3597145856703413e-05
# Validation Loss: 0.0008762599160642518, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 59/100, Loss: 9.139097556953857e-05
# Validation Loss: 0.0011417854748287937, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 60/100, Loss: 4.634836837643282e-05
# Validation Loss: 0.0011220782913975806, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 61/100, Loss: 9.645066332571635e-05
# Validation Loss: 0.0011750634585041553, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 62/100, Loss: 5.7182446937531495e-05
# Validation Loss: 0.0010712914434710303, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 63/100, Loss: 6.011973032382656e-05
# Validation Loss: 0.0008602831803727895, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 64/100, Loss: 3.970894176556309e-05
# Validation Loss: 0.0008962376805357053, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 65/100, Loss: 3.470229749069631e-05
# Validation Loss: 0.0011726308348443126, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 66/100, Loss: 4.655258801733453e-05
# Validation Loss: 0.000986463024673867, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 67/100, Loss: 3.953870886697075e-05
# Validation Loss: 0.0008923604749118871, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 68/100, Loss: 6.635277656859746e-05
# Validation Loss: 0.0011231896278331988, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 69/100, Loss: 3.662147857615613e-05
# Validation Loss: 0.0010317226111358953, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 70/100, Loss: 4.264383490000986e-05
# Validation Loss: 0.0009495650613947267, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 71/100, Loss: 3.544966247185736e-05
# Validation Loss: 0.0010059847584974098, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 72/100, Loss: 3.761772299526456e-05
# Validation Loss: 0.0010436714286091349, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 73/100, Loss: 3.257425317334158e-05
# Validation Loss: 0.0009431516306600921, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 74/100, Loss: 3.623133237814121e-05
# Validation Loss: 0.0007558038669230882, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 75/100, Loss: 4.023808213560187e-05
# Validation Loss: 0.0007089048458510661, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 76/100, Loss: 2.533834970108728e-05
# Validation Loss: 0.0008058576907690925, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 77/100, Loss: 4.218975479375331e-05
# Validation Loss: 0.000617544588749297, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 78/100, Loss: 2.403617328283758e-05
# Validation Loss: 0.0006726074861944653, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 79/100, Loss: 6.618221033249938e-05
# Validation Loss: 0.0008785841728240484, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 80/100, Loss: 3.153320127087985e-05
# Validation Loss: 0.0006854349984071936, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 81/100, Loss: 2.7430673123755394e-05
# Validation Loss: 0.0007385906404427564, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 82/100, Loss: 3.6613761058864234e-05
# Validation Loss: 0.0007854056281454783, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 83/100, Loss: 2.0807527194577347e-05
# Validation Loss: 0.0005624380898249607, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 84/100, Loss: 2.5193825742064746e-05
# Validation Loss: 0.0006764058709147017, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 85/100, Loss: 2.310551174152427e-05
# Validation Loss: 0.0006017494927921992, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 86/100, Loss: 2.6261657100216478e-05
# Validation Loss: 0.000473329532421, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 87/100, Loss: 1.8371245110652506e-05
# Validation Loss: 0.0005228720847298973, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 88/100, Loss: 2.300774679042661e-05
# Validation Loss: 0.0005984817667770889, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 89/100, Loss: 2.838631998732429e-05
# Validation Loss: 0.0005329082347695172, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 90/100, Loss: 2.8102570453825138e-05
# Validation Loss: 0.0003790940866868671, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 91/100, Loss: 2.1111197966661166e-05
# Validation Loss: 0.000596784070845994, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 92/100, Loss: 1.549732720462771e-05
# Validation Loss: 0.00044579867183832295, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 93/100, Loss: 1.7897797628544747e-05
# Validation Loss: 0.00042325303259834374, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 94/100, Loss: 2.0119783824175858e-05
# Validation Loss: 0.0005091593361612468, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 95/100, Loss: 2.313217232341458e-05
# Validation Loss: 0.0006648305513105394, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 96/100, Loss: 1.806397777196859e-05
# Validation Loss: 0.00046392402479492983, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 97/100, Loss: 2.3375342178629428e-05
# Validation Loss: 0.0004300849682294938, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 98/100, Loss: 1.6000892202328032e-05
# Validation Loss: 0.0005031615654237006, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 99/100, Loss: 2.6978030470322285e-05
# Validation Loss: 0.0005071316793419101, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 100/100, Loss: 2.0141895682002087e-05
# Validation Loss: 0.00042046648801867076, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Validation Loss: 0.00043013764206989435, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[ 70   0]
#  [  0 117]]
# FOLD 2
# --------------------------------
# Epoch 1/100, Loss: 0.3988656527362764
# Validation Loss: 0.25618414316947263, Validation Accuracy: 0.9411764705882353
# Precision: 1.0, Recall: 0.9043478260869565, F1-score: 0.9497716894977168
# Epoch 2/100, Loss: 0.13965351811687773
# Validation Loss: 0.22664185910252854, Validation Accuracy: 0.9625668449197861
# Precision: 0.9655172413793104, Recall: 0.9739130434782609, F1-score: 0.9696969696969697
# Epoch 3/100, Loss: 0.07222446563052169
# Validation Loss: 0.04820682364758492, Validation Accuracy: 0.983957219251337
# Precision: 1.0, Recall: 0.9739130434782609, F1-score: 0.986784140969163
# Epoch 4/100, Loss: 0.017938846821228555
# Validation Loss: 0.12666024217226854, Validation Accuracy: 0.983957219251337
# Precision: 0.9827586206896551, Recall: 0.991304347826087, F1-score: 0.987012987012987
# Epoch 5/100, Loss: 0.016356152216758346
# Validation Loss: 0.12126941356594519, Validation Accuracy: 0.983957219251337
# Precision: 0.9827586206896551, Recall: 0.991304347826087, F1-score: 0.987012987012987
# Epoch 6/100, Loss: 0.002332008273356223
# Validation Loss: 0.11623157527841006, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 7/100, Loss: 0.0017556215328416631
# Validation Loss: 0.09154840080979436, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 8/100, Loss: 0.000863482405141743
# Validation Loss: 0.0906117191722539, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 9/100, Loss: 0.0006564234599863994
# Validation Loss: 0.09329290816094726, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 10/100, Loss: 0.0007476747631092925
# Validation Loss: 0.10665601659032593, Validation Accuracy: 0.983957219251337
# Precision: 0.9912280701754386, Recall: 0.9826086956521739, F1-score: 0.9868995633187773
# Epoch 11/100, Loss: 0.0006050622759327476
# Validation Loss: 0.10392842289729742, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 12/100, Loss: 0.0006279645718526202
# Validation Loss: 0.10869989335575762, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 13/100, Loss: 0.0007603556565053774
# Validation Loss: 0.10256375039777292, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 14/100, Loss: 0.001068886076780018
# Validation Loss: 0.09524563580635004, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 15/100, Loss: 0.0004140007035668229
# Validation Loss: 0.09455031595037629, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 16/100, Loss: 0.00027948967241779127
# Validation Loss: 0.0996156357568907, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 17/100, Loss: 0.000389349520939201
# Validation Loss: 0.10055359699375306, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 18/100, Loss: 0.0003681455414910791
# Validation Loss: 0.08947452749271179, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 19/100, Loss: 0.00032198995014217263
# Validation Loss: 0.10302180739987914, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 20/100, Loss: 0.00038678774810800104
# Validation Loss: 0.10266769746885984, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 21/100, Loss: 0.0002488675722863339
# Validation Loss: 0.10893324740512374, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 22/100, Loss: 0.0003387912125466149
# Validation Loss: 0.10896897661859839, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 23/100, Loss: 0.00022773109663935345
# Validation Loss: 0.1075991388543116, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 24/100, Loss: 0.0001792355785852351
# Validation Loss: 0.09747077049663251, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 25/100, Loss: 0.00013156936720785475
# Validation Loss: 0.11141196403332287, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 26/100, Loss: 0.00016785897203893305
# Validation Loss: 0.11107777787954849, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 27/100, Loss: 0.00023355712993596475
# Validation Loss: 0.09423443068196018, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 28/100, Loss: 0.0003647364933812014
# Validation Loss: 0.09675417628811071, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 29/100, Loss: 0.0001665680085996731
# Validation Loss: 0.09269287831133018, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 30/100, Loss: 0.00017657894717378517
# Validation Loss: 0.08837187344943231, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 31/100, Loss: 0.00017791215224368292
# Validation Loss: 0.07389159505146381, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 32/100, Loss: 0.00013951746927887143
# Validation Loss: 0.08303043825738617, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 33/100, Loss: 0.00012012561846101259
# Validation Loss: 0.07758147755885147, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 34/100, Loss: 0.00012892764739487936
# Validation Loss: 0.0870559559192164, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 35/100, Loss: 0.0001407745300999371
# Validation Loss: 0.07737628989343648, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 36/100, Loss: 9.913166543403425e-05
# Validation Loss: 0.07422933093706281, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 37/100, Loss: 0.00011496012788825283
# Validation Loss: 0.09028678442882665, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 38/100, Loss: 6.839784219891953e-05
# Validation Loss: 0.08360982381949118, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 39/100, Loss: 0.00011200636336639036
# Validation Loss: 0.08597778202420159, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 40/100, Loss: 9.730971267648177e-05
# Validation Loss: 0.08859639688004488, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 41/100, Loss: 6.370485228283466e-05
# Validation Loss: 0.081250082407981, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 42/100, Loss: 7.992919654024415e-05
# Validation Loss: 0.07909868665486404, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 43/100, Loss: 6.351298061701982e-05
# Validation Loss: 0.07934955817048224, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 44/100, Loss: 6.626638984090032e-05
# Validation Loss: 0.07375624376557728, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 45/100, Loss: 0.00010108954127000895
# Validation Loss: 0.0798701354806326, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 46/100, Loss: 6.683419791405261e-05
# Validation Loss: 0.08752591865239386, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 47/100, Loss: 6.398780832720756e-05
# Validation Loss: 0.08121379315889499, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 48/100, Loss: 0.00013441801444476673
# Validation Loss: 0.08119823642224826, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 49/100, Loss: 7.400269634653493e-05
# Validation Loss: 0.0845260264340671, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 50/100, Loss: 8.058013505518602e-05
# Validation Loss: 0.08814457933294761, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 51/100, Loss: 5.9773251185409514e-05
# Validation Loss: 0.08595614434307208, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 52/100, Loss: 7.231903138441946e-05
# Validation Loss: 0.08805086447288583, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 53/100, Loss: 6.43326493919479e-05
# Validation Loss: 0.09299078700526782, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 54/100, Loss: 4.458658297797532e-05
# Validation Loss: 0.09199157737900047, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 55/100, Loss: 6.272672335475941e-05
# Validation Loss: 0.0847391208189947, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 56/100, Loss: 5.2402991177776435e-05
# Validation Loss: 0.08588994837570378, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 57/100, Loss: 6.841781132512399e-05
# Validation Loss: 0.08867680389933714, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 58/100, Loss: 5.834340567408466e-05
# Validation Loss: 0.09057006479391323, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 59/100, Loss: 4.078101404540272e-05
# Validation Loss: 0.09336266119915611, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 60/100, Loss: 3.915044185968478e-05
# Validation Loss: 0.09610657106524438, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 61/100, Loss: 5.9023485697196065e-05
# Validation Loss: 0.09983265929622576, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 62/100, Loss: 3.811994263536178e-05
# Validation Loss: 0.10020155042737618, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 63/100, Loss: 5.1622671865795645e-05
# Validation Loss: 0.09997214747333298, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 64/100, Loss: 5.615171205638111e-05
# Validation Loss: 0.11490262122363977, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 65/100, Loss: 6.0166064893489114e-05
# Validation Loss: 0.08788767608185329, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 66/100, Loss: 8.648462979958065e-05
# Validation Loss: 0.09618812146194007, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 67/100, Loss: 3.594104827205532e-05
# Validation Loss: 0.09463448919692989, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 68/100, Loss: 5.641136357326104e-05
# Validation Loss: 0.11196396281718535, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 69/100, Loss: 4.6750700883298656e-05
# Validation Loss: 0.09507990686264141, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 70/100, Loss: 4.806040755530224e-05
# Validation Loss: 0.08871579802871565, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 71/100, Loss: 2.739349976721428e-05
# Validation Loss: 0.08829544509596114, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 72/100, Loss: 4.7218979808860695e-05
# Validation Loss: 0.09399074564074301, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 73/100, Loss: 4.604273661653243e-05
# Validation Loss: 0.08981710953654935, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 74/100, Loss: 2.521385982727035e-05
# Validation Loss: 0.08760769013800503, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 75/100, Loss: 3.625952292433491e-05
# Validation Loss: 0.09266824634240341, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 76/100, Loss: 3.625913841768617e-05
# Validation Loss: 0.08691895209735397, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 77/100, Loss: 2.620505784515596e-05
# Validation Loss: 0.08506693621651114, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 78/100, Loss: 2.5451561197561052e-05
# Validation Loss: 0.09711257246757062, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 79/100, Loss: 2.256848159021274e-05
# Validation Loss: 0.0838592674241454, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 80/100, Loss: 2.2916441645648433e-05
# Validation Loss: 0.09664110403021671, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 81/100, Loss: 3.550075713102766e-05
# Validation Loss: 0.0932848484517308, Validation Accuracy: 0.9893048128342246
# Precision: 0.991304347826087, Recall: 0.991304347826087, F1-score: 0.991304347826087
# Epoch 82/100, Loss: 2.174497584609784e-05
# Validation Loss: 0.1049987567399171, Validation Accuracy: 0.9893048128342246
# ...
# Epoch 99/100, Loss: 1.4491924602566542e-05
# Validation Loss: 0.00010097793186029473, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 100/100, Loss: 1.841610994250213e-05
# Validation Loss: 0.0001062280805778452, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Validation Loss: 0.00010700065039751887, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[ 55   0]
#  [  0 132]]
# FOLD 4
# --------------------------------
# Epoch 1/100, Loss: 0.2780353139775495
# Validation Loss: 0.14265238990386328, Validation Accuracy: 0.9358288770053476
# Precision: 0.9508196721311475, Recall: 0.9508196721311475, F1-score: 0.9508196721311475
# Epoch 2/100, Loss: 0.07070528412865922
# Validation Loss: 0.029218449567755062, Validation Accuracy: 0.9946524064171123
# Precision: 1.0, Recall: 0.9918032786885246, F1-score: 0.9958847736625515
# Epoch 3/100, Loss: 0.02626218165217627
# Validation Loss: 0.033962641357599445, Validation Accuracy: 0.9946524064171123
# Precision: 1.0, Recall: 0.9918032786885246, F1-score: 0.9958847736625515
# Epoch 4/100, Loss: 0.014255847859506806
# Validation Loss: 0.015465204060698548, Validation Accuracy: 0.9946524064171123
# Precision: 1.0, Recall: 0.9918032786885246, F1-score: 0.9958847736625515
# Epoch 5/100, Loss: 0.02402770770246813
# Validation Loss: 0.00861477250388513, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 6/100, Loss: 0.0052410811379862325
# Validation Loss: 0.008455851736168066, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 7/100, Loss: 0.002097940179453417
# Validation Loss: 0.0031550259542806693, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 8/100, Loss: 0.001352165508554511
# Validation Loss: 0.0033880535484058782, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 9/100, Loss: 0.001252157625003747
# Validation Loss: 0.002485612715342237, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 10/100, Loss: 0.00127762629025104
# Validation Loss: 0.00401992709763969, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 11/100, Loss: 0.0025310747381202723
# Validation Loss: 0.004182704375125468, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 12/100, Loss: 0.0010278011723130476
# Validation Loss: 0.002460390591295436, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 13/100, Loss: 0.0006553349777126035
# Validation Loss: 0.0021063934837002307, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 14/100, Loss: 0.0005032661993027432
# Validation Loss: 0.0017605086104595102, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 15/100, Loss: 0.0005166463967422411
# Validation Loss: 0.001470721330406377, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 16/100, Loss: 0.0003730022119725618
# Validation Loss: 0.0016154925027270413, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 17/100, Loss: 0.0003774063961827778
# Validation Loss: 0.0015689721913076937, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 18/100, Loss: 0.0003850557914878057
# Validation Loss: 0.0012199553554334368, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 19/100, Loss: 0.00030212216347536014
# Validation Loss: 0.0009807187719464612, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 20/100, Loss: 0.0003170425877290957
# Validation Loss: 0.0008574673532469509, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 21/100, Loss: 0.00027544187709812223
# Validation Loss: 0.0006484278856078163, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 22/100, Loss: 0.00022920081685621577
# Validation Loss: 0.0006919838197063655, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 23/100, Loss: 0.0002283736985949266
# Validation Loss: 0.000749828563129995, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 24/100, Loss: 0.00017207657646167718
# Validation Loss: 0.000527094170441463, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 25/100, Loss: 0.00016919753454658348
# Validation Loss: 0.0005004183728184822, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 26/100, Loss: 0.00013489341442133687
# Validation Loss: 0.00042923992562767427, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 27/100, Loss: 0.00013643674708418985
# Validation Loss: 0.00038827035799234483, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 28/100, Loss: 0.00014563997838952977
# Validation Loss: 0.0006138682510936633, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 29/100, Loss: 0.00010415563620351047
# Validation Loss: 0.0006394189780015344, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 30/100, Loss: 0.0001393246118842247
# Validation Loss: 0.0005167120471014641, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 31/100, Loss: 0.00010018311062746459
# Validation Loss: 0.0004115648941175702, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 32/100, Loss: 7.766661345461519e-05
# Validation Loss: 0.0004064115564688109, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 33/100, Loss: 9.923872674259353e-05
# Validation Loss: 0.0003705146470262359, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 34/100, Loss: 9.396820812964297e-05
# Validation Loss: 0.0002975242935766194, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 35/100, Loss: 9.722097895329777e-05
# Validation Loss: 0.0003983783547785909, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 36/100, Loss: 9.612615055469102e-05
# Validation Loss: 0.0002671165266292519, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 37/100, Loss: 0.0001171261009792109
# Validation Loss: 0.00022021390729302462, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 38/100, Loss: 5.7711492682225675e-05
# Validation Loss: 0.0003259279476424126, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 39/100, Loss: 0.00011848819440274383
# Validation Loss: 0.00024345545413477035, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 40/100, Loss: 5.462406216831065e-05
# Validation Loss: 0.00019625334122489826, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 41/100, Loss: 9.624012730095426e-05
# Validation Loss: 0.00021314502525153026, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 42/100, Loss: 5.5305772121982955e-05
# Validation Loss: 0.00025716489835758694, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 43/100, Loss: 7.398843376904551e-05
# Validation Loss: 0.000272229392673277, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 44/100, Loss: 4.886282575474373e-05
# Validation Loss: 0.0003059178249410858, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 45/100, Loss: 5.61451638058467e-05
# Validation Loss: 0.00022920196594592804, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 46/100, Loss: 6.147581424838695e-05
# Validation Loss: 0.00015637604762256765, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 47/100, Loss: 4.467116456415473e-05
# Validation Loss: 0.0002072673870922396, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 48/100, Loss: 4.988289594602217e-05
# Validation Loss: 0.0002613354954519309, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 49/100, Loss: 3.859090756937652e-05
# Validation Loss: 0.00024073342016587654, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 50/100, Loss: 3.2226527489835156e-05
# Validation Loss: 0.00016567625607422087, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 51/100, Loss: 3.732364449623068e-05
# Validation Loss: 0.00018343272131460253, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 52/100, Loss: 4.219221635537451e-05
# Validation Loss: 0.00017013668669581725, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 53/100, Loss: 3.8588814902595914e-05
# Validation Loss: 0.00013370408578339266, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 54/100, Loss: 3.406387133016627e-05
# Validation Loss: 0.00014991108158331676, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 55/100, Loss: 3.4016889356299394e-05
# Validation Loss: 0.00013153843004450513, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 56/100, Loss: 3.752882619778575e-05
# Validation Loss: 0.00019892636919394135, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 57/100, Loss: 3.241903630168963e-05
# Validation Loss: 0.00012728158799291123, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 58/100, Loss: 2.666004839439277e-05
# Validation Loss: 0.00012932703005693233, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 59/100, Loss: 4.2320246116389626e-05
# Validation Loss: 9.414019344452147e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 60/100, Loss: 4.375354646294719e-05
# Validation Loss: 0.00011763903072884811, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 61/100, Loss: 3.521946444070186e-05
# Validation Loss: 9.052830425086238e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 62/100, Loss: 1.9340905803725644e-05
# Validation Loss: 9.244700777344406e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 63/100, Loss: 2.444370807452856e-05
# Validation Loss: 8.323617733670592e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 64/100, Loss: 3.7898010267175174e-05
# Validation Loss: 9.180446045320423e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 65/100, Loss: 2.682756428799375e-05
# Validation Loss: 0.00010120199794982909, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 66/100, Loss: 2.3601896825672004e-05
# Validation Loss: 7.39278504700754e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 67/100, Loss: 2.3784839887260507e-05
# Validation Loss: 0.00011125286338635003, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 68/100, Loss: 2.637647898969438e-05
# Validation Loss: 9.711166361133412e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 69/100, Loss: 4.7126820452566186e-05
# Validation Loss: 7.9305361320318e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 70/100, Loss: 2.0809270618353064e-05
# Validation Loss: 7.659101735650135e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 71/100, Loss: 1.777623943629199e-05
# Validation Loss: 7.703109713474987e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 72/100, Loss: 2.2583949775167866e-05
# Validation Loss: 5.7200623283885456e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 73/100, Loss: 2.054592136365348e-05
# Validation Loss: 7.544194227193657e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 74/100, Loss: 2.658740153075693e-05
# Validation Loss: 6.895791420902242e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 75/100, Loss: 1.6877364640066617e-05
# Validation Loss: 6.904821232941079e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 76/100, Loss: 2.1519436588531466e-05
# Validation Loss: 5.649172832515129e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 77/100, Loss: 1.2592617302686904e-05
# Validation Loss: 7.490029474865878e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 78/100, Loss: 1.646209315235107e-05
# Validation Loss: 6.314050673002687e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 79/100, Loss: 1.597422775508524e-05
# Validation Loss: 7.309242857900244e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 80/100, Loss: 2.172032270427356e-05
# Validation Loss: 7.564613899072962e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 81/100, Loss: 1.7957918196032097e-05
# Validation Loss: 5.962069614421731e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 82/100, Loss: 2.175028420895823e-05
# Validation Loss: 5.2698927523427606e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 83/100, Loss: 1.329744741696004e-05
# Validation Loss: 5.848056052097187e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 84/100, Loss: 1.4867214852554156e-05
# Validation Loss: 4.953458248261692e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 85/100, Loss: 1.4810745730879185e-05
# Validation Loss: 5.943881857698822e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 86/100, Loss: 2.2907046529259862e-05
# Validation Loss: 8.366329484488233e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 87/100, Loss: 1.3071647371039793e-05
# Validation Loss: 4.902998080069665e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 88/100, Loss: 1.835601361932504e-05
# Validation Loss: 6.458742094158272e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 89/100, Loss: 1.0931247805009056e-05
# Validation Loss: 5.8051804141238485e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 90/100, Loss: 1.3316072387858924e-05
# Validation Loss: 3.720106102870583e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 91/100, Loss: 1.5288800171949408e-05
# Validation Loss: 4.0483422026227345e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 92/100, Loss: 1.4735554509925919e-05
# Validation Loss: 3.40380756824743e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 93/100, Loss: 9.580221805786474e-06
# Validation Loss: 3.726997268434692e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 94/100, Loss: 9.004540513520473e-06
# Validation Loss: 4.267724019276405e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 95/100, Loss: 1.0090201311522643e-05
# Validation Loss: 4.03955868932826e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 96/100, Loss: 1.755093554341632e-05
# Validation Loss: 4.0750635956025384e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 97/100, Loss: 1.0518970992023924e-05
# Validation Loss: 3.9907235228990125e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 98/100, Loss: 9.676644258623432e-06
# Validation Loss: 2.9809854216485594e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 99/100, Loss: 1.296825715139486e-05
# Validation Loss: 3.9287940353460726e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Epoch 100/100, Loss: 1.030038769892864e-05
# Validation Loss: 3.287758816365264e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Validation Loss: 3.311543756960115e-05, Validation Accuracy: 1.0
# Precision: 1.0, Recall: 1.0, F1-score: 1.0
# Confusion Matrix:
# [[ 65   0]
#  [  0 122]]
#
# Average results across all folds:
# Accuracy: 0.9979
# Precision: 0.9983
# Recall: 0.9983
# F1-score: 0.9983
