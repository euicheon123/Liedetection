# %%
import os
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset, Subset
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingWarmRestarts
from sklearn.model_selection import GroupKFold, StratifiedKFold
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# Directory containing data files
data_dir = r'C:\Users\User\Documents\Lie detect data\AugmentedEEGData'
model_save_dir = r'C:\Users\User\Documents\Lie detect data\Model'
os.makedirs(model_save_dir, exist_ok=True)

# Function to load and label data
def load_data(data_dir):
    X = []
    y = []
    groups = []
    
    for idx, file_name in enumerate(os.listdir(data_dir)):
        if file_name.endswith('.pkl'):
            file_path = os.path.join(data_dir, file_name)
            data = pd.read_pickle(file_path)
            label = 0 if 'lie' in file_name else 1
            X.append(data)
            y.extend([label] * data.shape[0])
            groups.extend([idx] * data.shape[0])  # Use file index as group label
    
    X = np.vstack(X)
    y = np.array(y)
    groups = np.array(groups)
    return X, y, groups

# Load and label data
X, y, groups = load_data(data_dir)

# Define dataset class
class EEGDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Define EEGNet model
class EEGNet(nn.Module):
    def __init__(self, num_classes=2):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, (1, 63), padding='same')
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.depthwiseConv2d = nn.Conv2d(16, 32, (65, 1), groups=16, padding='same')
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.activation = nn.ELU()
        self.pooling = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32 * 65 * 62, num_classes)

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv2d(x)
        x = self.batchnorm2(x)
        x = self.activation(x)
        x = self.pooling(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

# Initialize model, loss function, and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def train_and_evaluate(train_loader, val_loader, fold_idx):
    model = EEGNet(num_classes=2).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)
    scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1)

    num_epochs = 100
    best_val_loss = float('inf')
    patience = 20
    trigger_times = 0

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total += y_batch.size(0)
                correct += (predicted == y_batch).sum().item()

        val_loss /= len(val_loader)
        val_accuracy = correct / total
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {train_loss}, Validation Loss: {val_loss}, Validation Accuracy: {val_accuracy}')
        
        scheduler.step()

        
        # Early Stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            trigger_times = 0
            fold_model_path = os.path.join(model_save_dir, f'model_fold_{fold_idx}.pth')
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'epoch': epoch,
                'val_loss': best_val_loss,
            }, fold_model_path)
        else:
            trigger_times += 1
            if trigger_times >= patience:
                print('Early stopping!')
                break

    return model

# K-Fold Cross Validation
kf = GroupKFold(n_splits=5)
all_labels = []
all_predictions = []
fold_idx = 1

for train_index, val_index in kf.split(X, y, groups):
    print(f'Fold {fold_idx}')

    # Split data
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Normalize data
    scaler = MinMaxScaler()
    X_train = X_train.reshape(X_train.shape[0], -1)
    X_train = scaler.fit_transform(X_train)
    X_train = X_train.reshape(-1, 65, 250)

    X_val = X_val.reshape(X_val.shape[0], -1)
    X_val = scaler.transform(X_val)
    X_val = X_val.reshape(-1, 65, 250)

    # Create datasets
    train_dataset = EEGDataset(X_train, y_train)
    val_dataset = EEGDataset(X_val, y_val)

    train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

    model = train_and_evaluate(train_loader, val_loader, fold_idx)

    model.eval()
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            _, predicted = torch.max(outputs, 1)
            all_labels.extend(y_batch.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    fold_idx += 1

# Calculate additional metrics
accuracy = accuracy_score(all_labels, all_predictions)
precision = precision_score(all_labels, all_predictions)
recall = recall_score(all_labels, all_predictions)
f1 = f1_score(all_labels, all_predictions)
auc = roc_auc_score(all_labels, all_predictions)
conf_matrix = confusion_matrix(all_labels, all_predictions)

print(f'Accuracy: {accuracy},Precision: {precision}, Recall: {recall}, F1-score: {f1}, AUC: {auc}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Fold 1
# Epoch 1/100, Loss: 2.123185694217682, Validation Loss: 0.7722445726394653, Validation Accuracy: 0.325
# Epoch 2/100, Loss: 0.99955948193868, Validation Loss: 0.6529796719551086, Validation Accuracy: 0.7
# Epoch 3/100, Loss: 0.8567648927370707, Validation Loss: 0.6374073624610901, Validation Accuracy: 0.6875
# Epoch 4/100, Loss: 0.5302015344301859, Validation Loss: 0.6999939680099487, Validation Accuracy: 0.5
# Epoch 5/100, Loss: 0.5107347269852957, Validation Loss: 0.5754024386405945, Validation Accuracy: 0.725
# Epoch 6/100, Loss: 0.4832168221473694, Validation Loss: 0.558261513710022, Validation Accuracy: 0.7125
# Epoch 7/100, Loss: 0.41979337731997174, Validation Loss: 0.5974608659744263, Validation Accuracy: 0.575
# Epoch 8/100, Loss: 0.3887985646724701, Validation Loss: 0.5964470505714417, Validation Accuracy: 0.55
# Epoch 9/100, Loss: 0.3667447865009308, Validation Loss: 0.5557472705841064, Validation Accuracy: 0.6375
# Epoch 10/100, Loss: 0.3778728246688843, Validation Loss: 0.5300074219703674, Validation Accuracy: 0.7
# Epoch 11/100, Loss: 0.5217023293177286, Validation Loss: 0.42108625173568726, Validation Accuracy: 0.7875
# Epoch 12/100, Loss: 0.49679460128148395, Validation Loss: 0.6531314849853516, Validation Accuracy: 0.575
# Epoch 13/100, Loss: 0.3888178567091624, Validation Loss: 0.3845333755016327, Validation Accuracy: 0.8125
# Epoch 14/100, Loss: 0.35873497525850934, Validation Loss: 0.546512246131897, Validation Accuracy: 0.65
# Epoch 15/100, Loss: 0.3453143040339152, Validation Loss: 0.41436824202537537, Validation Accuracy: 0.7625
# Epoch 16/100, Loss: 0.2956545849641164, Validation Loss: 0.34276872873306274, Validation Accuracy: 0.8625
# Epoch 17/100, Loss: 0.2984331548213959, Validation Loss: 0.39462462067604065, Validation Accuracy: 0.775
# Epoch 18/100, Loss: 0.2521667331457138, Validation Loss: 0.4190402030944824, Validation Accuracy: 0.7625
# Epoch 19/100, Loss: 0.27852746844291687, Validation Loss: 0.39957812428474426, Validation Accuracy: 0.775
# Epoch 20/100, Loss: 0.3019800732533137, Validation Loss: 0.3833780586719513, Validation Accuracy: 0.8
# Epoch 21/100, Loss: 0.32292801638444263, Validation Loss: 0.330027312040329, Validation Accuracy: 0.8875
# Epoch 22/100, Loss: 0.312884400288264, Validation Loss: 0.4917152523994446, Validation Accuracy: 0.7
# Epoch 23/100, Loss: 0.26082363228003186, Validation Loss: 0.32464319467544556, Validation Accuracy: 0.8
# Epoch 24/100, Loss: 0.2799624800682068, Validation Loss: 0.46355360746383667, Validation Accuracy: 0.7
# Epoch 25/100, Loss: 0.2712529997030894, Validation Loss: 0.33731895685195923, Validation Accuracy: 0.825
# Epoch 26/100, Loss: 0.23365549246470133, Validation Loss: 0.3023865520954132, Validation Accuracy: 0.9
# Epoch 27/100, Loss: 0.22364495694637299, Validation Loss: 0.3269420564174652, Validation Accuracy: 0.85
# Epoch 28/100, Loss: 0.2479229917128881, Validation Loss: 0.3563118278980255, Validation Accuracy: 0.8
# Epoch 29/100, Loss: 0.22636479139328003, Validation Loss: 0.340730756521225, Validation Accuracy: 0.8375
# Epoch 30/100, Loss: 0.2101899137099584, Validation Loss: 0.3312778174877167, Validation Accuracy: 0.8375
# Epoch 31/100, Loss: 0.24828563133875528, Validation Loss: 0.31607329845428467, Validation Accuracy: 0.8625
# Epoch 32/100, Loss: 0.2402527928352356, Validation Loss: 0.3911537230014801, Validation Accuracy: 0.75
# Epoch 33/100, Loss: 0.2243520418802897, Validation Loss: 0.28655633330345154, Validation Accuracy: 0.9
# Epoch 34/100, Loss: 0.21506920953591666, Validation Loss: 0.403658002614975, Validation Accuracy: 0.725
# Epoch 35/100, Loss: 0.23601768910884857, Validation Loss: 0.29581692814826965, Validation Accuracy: 0.8875
# Epoch 36/100, Loss: 0.2245806356271108, Validation Loss: 0.27676206827163696, Validation Accuracy: 0.925
# Epoch 37/100, Loss: 0.20694965620835623, Validation Loss: 0.3267284631729126, Validation Accuracy: 0.8375
# Epoch 38/100, Loss: 0.2128224621216456, Validation Loss: 0.3178512454032898, Validation Accuracy: 0.8375
# Epoch 39/100, Loss: 0.21606593330701193, Validation Loss: 0.2916369140148163, Validation Accuracy: 0.8875
# Epoch 40/100, Loss: 0.20535832146803537, Validation Loss: 0.28576940298080444, Validation Accuracy: 0.9
# Epoch 41/100, Loss: 0.21486950914065042, Validation Loss: 0.28264936804771423, Validation Accuracy: 0.9
# Epoch 42/100, Loss: 0.2084273248910904, Validation Loss: 0.3157309889793396, Validation Accuracy: 0.85
# Epoch 43/100, Loss: 0.21642547845840454, Validation Loss: 0.2835659384727478, Validation Accuracy: 0.9125
# Epoch 44/100, Loss: 0.1865562448898951, Validation Loss: 0.400312602519989, Validation Accuracy: 0.7375
# Epoch 45/100, Loss: 0.18364607791105905, Validation Loss: 0.2782878279685974, Validation Accuracy: 0.9125
# Epoch 46/100, Loss: 0.19966664413611093, Validation Loss: 0.29001715779304504, Validation Accuracy: 0.8875
# Epoch 47/100, Loss: 0.18435888489087424, Validation Loss: 0.30325010418891907, Validation Accuracy: 0.8875
# Epoch 48/100, Loss: 0.18880103528499603, Validation Loss: 0.2795563340187073, Validation Accuracy: 0.9125
# Epoch 49/100, Loss: 0.16028892497221628, Validation Loss: 0.2743837237358093, Validation Accuracy: 0.9125
# Epoch 50/100, Loss: 0.17463283240795135, Validation Loss: 0.27382612228393555, Validation Accuracy: 0.925
# Epoch 51/100, Loss: 0.17315098146597543, Validation Loss: 0.3357256054878235, Validation Accuracy: 0.825
# Epoch 52/100, Loss: 0.190150777498881, Validation Loss: 0.3161100745201111, Validation Accuracy: 0.8375
# Epoch 53/100, Loss: 0.1721853862206141, Validation Loss: 0.2853259742259979, Validation Accuracy: 0.9
# Epoch 54/100, Loss: 0.19006326297918955, Validation Loss: 0.2664712071418762, Validation Accuracy: 0.9125
# Epoch 55/100, Loss: 0.14874094227949777, Validation Loss: 0.327717125415802, Validation Accuracy: 0.8375
# Epoch 56/100, Loss: 0.17208474377791086, Validation Loss: 0.2506871223449707, Validation Accuracy: 0.9375
# Epoch 57/100, Loss: 0.15419394026199976, Validation Loss: 0.25082212686538696, Validation Accuracy: 0.925
# Epoch 58/100, Loss: 0.16633977989355722, Validation Loss: 0.26575663685798645, Validation Accuracy: 0.9125
# Epoch 59/100, Loss: 0.15014381210009256, Validation Loss: 0.27688711881637573, Validation Accuracy: 0.9125
# Epoch 60/100, Loss: 0.16312766075134277, Validation Loss: 0.27702265977859497, Validation Accuracy: 0.9125
# Epoch 61/100, Loss: 0.1710562805334727, Validation Loss: 0.27642616629600525, Validation Accuracy: 0.9
# Epoch 62/100, Loss: 0.1764338860909144, Validation Loss: 0.280592143535614, Validation Accuracy: 0.875
# Epoch 63/100, Loss: 0.20186093946297964, Validation Loss: 0.2500038743019104, Validation Accuracy: 0.9125
# Epoch 64/100, Loss: 0.20048473278681436, Validation Loss: 0.25739142298698425, Validation Accuracy: 0.9125
# Epoch 65/100, Loss: 0.1963347146908442, Validation Loss: 0.35275623202323914, Validation Accuracy: 0.825
# Epoch 66/100, Loss: 0.16870132088661194, Validation Loss: 0.2526663839817047, Validation Accuracy: 0.85
# Epoch 67/100, Loss: 0.1905786097049713, Validation Loss: 0.2708284556865692, Validation Accuracy: 0.9125
# Epoch 68/100, Loss: 0.1563171794017156, Validation Loss: 0.33801162242889404, Validation Accuracy: 0.8125
# Epoch 69/100, Loss: 0.1689186990261078, Validation Loss: 0.3034735321998596, Validation Accuracy: 0.85
# Epoch 70/100, Loss: 0.16082856555779776, Validation Loss: 0.28622350096702576, Validation Accuracy: 0.875
# Epoch 71/100, Loss: 0.22263979415098825, Validation Loss: 0.25225648283958435, Validation Accuracy: 0.85
# Epoch 72/100, Loss: 0.1796383336186409, Validation Loss: 0.5612809658050537, Validation Accuracy: 0.7
# Epoch 73/100, Loss: 0.1842322697242101, Validation Loss: 0.2736314833164215, Validation Accuracy: 0.825
# Epoch 74/100, Loss: 0.19861904780069986, Validation Loss: 0.43376436829566956, Validation Accuracy: 0.7625
# Epoch 75/100, Loss: 0.17183123777310053, Validation Loss: 0.240402489900589, Validation Accuracy: 0.9125
# Epoch 76/100, Loss: 0.13308586180210114, Validation Loss: 0.22345080971717834, Validation Accuracy: 0.9375
# Epoch 77/100, Loss: 0.13766368478536606, Validation Loss: 0.280355304479599, Validation Accuracy: 0.875
# Epoch 78/100, Loss: 0.15117953221003214, Validation Loss: 0.29497283697128296, Validation Accuracy: 0.875
# Epoch 79/100, Loss: 0.1307451253135999, Validation Loss: 0.2651614546775818, Validation Accuracy: 0.875
# Epoch 80/100, Loss: 0.12649224450190863, Validation Loss: 0.2514847218990326, Validation Accuracy: 0.875
# Epoch 81/100, Loss: 0.19557411968708038, Validation Loss: 0.22572019696235657, Validation Accuracy: 0.925
# Epoch 82/100, Loss: 0.21374754110972086, Validation Loss: 0.2924844026565552, Validation Accuracy: 0.8875
# Epoch 83/100, Loss: 0.16958079238732657, Validation Loss: 0.23518776893615723, Validation Accuracy: 0.925
# Epoch 84/100, Loss: 0.1579743673404058, Validation Loss: 0.5176616907119751, Validation Accuracy: 0.725
# Epoch 85/100, Loss: 0.1661628931760788, Validation Loss: 0.22754931449890137, Validation Accuracy: 0.9125
# Epoch 86/100, Loss: 0.16030988097190857, Validation Loss: 0.23192238807678223, Validation Accuracy: 0.9
# Epoch 87/100, Loss: 0.11750095834334691, Validation Loss: 0.3436269164085388, Validation Accuracy: 0.85
# Epoch 88/100, Loss: 0.14332645138104758, Validation Loss: 0.290787935256958, Validation Accuracy: 0.8875
# Epoch 89/100, Loss: 0.11491257448991139, Validation Loss: 0.2444543093442917, Validation Accuracy: 0.8875
# Epoch 90/100, Loss: 0.12089002132415771, Validation Loss: 0.23546604812145233, Validation Accuracy: 0.9
# Epoch 91/100, Loss: 0.17165985455115637, Validation Loss: 0.22304470837116241, Validation Accuracy: 0.9
# Epoch 92/100, Loss: 0.2210199385881424, Validation Loss: 0.26433882117271423, Validation Accuracy: 0.875
# Epoch 93/100, Loss: 0.1705223247408867, Validation Loss: 0.21721947193145752, Validation Accuracy: 0.925
# Epoch 94/100, Loss: 0.15835108359654745, Validation Loss: 0.4641095697879791, Validation Accuracy: 0.775
# Epoch 95/100, Loss: 0.15462094048659006, Validation Loss: 0.21050259470939636, Validation Accuracy: 0.925
# Epoch 96/100, Loss: 0.11686700334151585, Validation Loss: 0.22778764367103577, Validation Accuracy: 0.8875
# Epoch 97/100, Loss: 0.09505579248070717, Validation Loss: 0.2815229594707489, Validation Accuracy: 0.875
# Epoch 98/100, Loss: 0.11144338796536128, Validation Loss: 0.2551063299179077, Validation Accuracy: 0.875
# Epoch 99/100, Loss: 0.09740865727265675, Validation Loss: 0.2354343831539154, Validation Accuracy: 0.875
# Epoch 100/100, Loss: 0.10776888579130173, Validation Loss: 0.22924990952014923, Validation Accuracy: 0.8875
# Fold 2
# Epoch 1/100, Loss: 2.452078342437744, Validation Loss: 0.6953959465026855, Validation Accuracy: 0.4691358024691358
# Epoch 2/100, Loss: 1.290405551592509, Validation Loss: 0.6648818254470825, Validation Accuracy: 0.7901234567901234
# Epoch 3/100, Loss: 0.7849036157131195, Validation Loss: 0.6634072661399841, Validation Accuracy: 0.49382716049382713
# Epoch 4/100, Loss: 0.5610076685746511, Validation Loss: 0.6675731539726257, Validation Accuracy: 0.6049382716049383
# Epoch 5/100, Loss: 0.6395424008369446, Validation Loss: 0.6395972967147827, Validation Accuracy: 0.5802469135802469
# Epoch 6/100, Loss: 0.5974537134170532, Validation Loss: 0.6406364440917969, Validation Accuracy: 0.5925925925925926
# Epoch 7/100, Loss: 0.4658270577589671, Validation Loss: 0.6121537685394287, Validation Accuracy: 0.7530864197530864
# Epoch 8/100, Loss: 0.40922631820042926, Validation Loss: 0.6157750487327576, Validation Accuracy: 0.7530864197530864
# Epoch 9/100, Loss: 0.4408812125523885, Validation Loss: 0.5968851447105408, Validation Accuracy: 0.8024691358024691
# Epoch 10/100, Loss: 0.44238361716270447, Validation Loss: 0.5849876999855042, Validation Accuracy: 0.7654320987654321
# Epoch 11/100, Loss: 0.7991690834363302, Validation Loss: 0.9742966890335083, Validation Accuracy: 0.5061728395061729
# Epoch 12/100, Loss: 0.7046667536099752, Validation Loss: 0.8024701476097107, Validation Accuracy: 0.6419753086419753
# Epoch 13/100, Loss: 0.5789940853913625, Validation Loss: 0.6773915886878967, Validation Accuracy: 0.5925925925925926
# Epoch 14/100, Loss: 0.5657115876674652, Validation Loss: 0.7721296548843384, Validation Accuracy: 0.5925925925925926
# Epoch 15/100, Loss: 0.3916583259900411, Validation Loss: 0.6829023361206055, Validation Accuracy: 0.8148148148148148
# Epoch 16/100, Loss: 0.45116689801216125, Validation Loss: 0.6034682393074036, Validation Accuracy: 0.8024691358024691
# Epoch 17/100, Loss: 0.31094558040301007, Validation Loss: 0.6521880626678467, Validation Accuracy: 0.654320987654321
# Epoch 18/100, Loss: 0.35677457849184674, Validation Loss: 0.6742566227912903, Validation Accuracy: 0.6296296296296297
# Epoch 19/100, Loss: 0.3884481390317281, Validation Loss: 0.6427995562553406, Validation Accuracy: 0.654320987654321
# Epoch 20/100, Loss: 0.34197281797726947, Validation Loss: 0.634411633014679, Validation Accuracy: 0.6666666666666666
# Epoch 21/100, Loss: 0.579424113035202, Validation Loss: 0.5997809171676636, Validation Accuracy: 0.8518518518518519
# Epoch 22/100, Loss: 0.34054599205652875, Validation Loss: 1.0348857641220093, Validation Accuracy: 0.5679012345679012
# Epoch 23/100, Loss: 0.41371514399846393, Validation Loss: 0.6079733967781067, Validation Accuracy: 0.8395061728395061
# Epoch 24/100, Loss: 0.44777541359265643, Validation Loss: 0.5209954977035522, Validation Accuracy: 0.7283950617283951
# Epoch 25/100, Loss: 0.3271789352099101, Validation Loss: 0.7746842503547668, Validation Accuracy: 0.6049382716049383
# Epoch 26/100, Loss: 0.3487321386734645, Validation Loss: 0.520470380783081, Validation Accuracy: 0.8641975308641975
# Epoch 27/100, Loss: 0.3366605540116628, Validation Loss: 0.5477098226547241, Validation Accuracy: 0.8765432098765432
# Epoch 28/100, Loss: 0.31488852699597675, Validation Loss: 0.5339841246604919, Validation Accuracy: 0.7283950617283951
# Epoch 29/100, Loss: 0.27492111921310425, Validation Loss: 0.5599362254142761, Validation Accuracy: 0.691358024691358
# Epoch 30/100, Loss: 0.286179855465889, Validation Loss: 0.5670268535614014, Validation Accuracy: 0.654320987654321
# Epoch 31/100, Loss: 0.3008838693300883, Validation Loss: 0.5602829456329346, Validation Accuracy: 0.7160493827160493
# Epoch 32/100, Loss: 0.2586527069409688, Validation Loss: 0.5454590320587158, Validation Accuracy: 0.8518518518518519
# Epoch 33/100, Loss: 0.25717903176943463, Validation Loss: 0.5414341688156128, Validation Accuracy: 0.7407407407407407
# Epoch 34/100, Loss: 0.2680671711762746, Validation Loss: 0.5225345492362976, Validation Accuracy: 0.8395061728395061
# Epoch 35/100, Loss: 0.25146427750587463, Validation Loss: 0.5268272161483765, Validation Accuracy: 0.7654320987654321
# Epoch 36/100, Loss: 0.27022326985994977, Validation Loss: 0.5364430546760559, Validation Accuracy: 0.7160493827160493
# Epoch 37/100, Loss: 0.23209938406944275, Validation Loss: 0.5347484946250916, Validation Accuracy: 0.8024691358024691
# Epoch 38/100, Loss: 0.2449225684007009, Validation Loss: 0.5373680591583252, Validation Accuracy: 0.8024691358024691
# Epoch 39/100, Loss: 0.23573186000188193, Validation Loss: 0.5395941138267517, Validation Accuracy: 0.8024691358024691
# Epoch 40/100, Loss: 0.2467852085828781, Validation Loss: 0.5403867363929749, Validation Accuracy: 0.7654320987654321
# Epoch 41/100, Loss: 0.2486825535694758, Validation Loss: 0.5696441531181335, Validation Accuracy: 0.7160493827160493
# Epoch 42/100, Loss: 0.3111635198195775, Validation Loss: 0.5721793174743652, Validation Accuracy: 0.7283950617283951
# Epoch 43/100, Loss: 0.2505420446395874, Validation Loss: 0.5959455966949463, Validation Accuracy: 0.7037037037037037
# Epoch 44/100, Loss: 0.2599428544441859, Validation Loss: 0.5751672387123108, Validation Accuracy: 0.8518518518518519
# Epoch 45/100, Loss: 0.23715092738469443, Validation Loss: 0.6313924193382263, Validation Accuracy: 0.654320987654321
# Epoch 46/100, Loss: 0.2472171187400818, Validation Loss: 0.5762664675712585, Validation Accuracy: 0.8395061728395061
# Early stopping!
# Fold 3
# Epoch 1/100, Loss: 1.405681073665619, Validation Loss: 0.6703656911849976, Validation Accuracy: 0.6375
# Epoch 2/100, Loss: 1.4612455368041992, Validation Loss: 0.7180070877075195, Validation Accuracy: 0.45
# Epoch 3/100, Loss: 1.0160372257232666, Validation Loss: 0.635351300239563, Validation Accuracy: 0.6375
# Epoch 4/100, Loss: 0.9921790162722269, Validation Loss: 0.6179524064064026, Validation Accuracy: 0.575
# Epoch 5/100, Loss: 0.5197088023026785, Validation Loss: 0.7009942531585693, Validation Accuracy: 0.5
# Epoch 6/100, Loss: 0.6357058684031168, Validation Loss: 0.6060280203819275, Validation Accuracy: 0.7875
# Epoch 7/100, Loss: 0.42688611149787903, Validation Loss: 0.5656605362892151, Validation Accuracy: 0.75
# Epoch 8/100, Loss: 0.4800841609636943, Validation Loss: 0.5622211694717407, Validation Accuracy: 0.8125
# Epoch 9/100, Loss: 0.4043958783149719, Validation Loss: 0.5794438123703003, Validation Accuracy: 0.7875
# Epoch 10/100, Loss: 0.3606935242811839, Validation Loss: 0.5830205678939819, Validation Accuracy: 0.775
# Epoch 11/100, Loss: 0.7065218190352122, Validation Loss: 0.8022401928901672, Validation Accuracy: 0.55
# Epoch 12/100, Loss: 0.5751660466194153, Validation Loss: 0.5980163216590881, Validation Accuracy: 0.7
# Epoch 13/100, Loss: 0.5006483495235443, Validation Loss: 0.7981170415878296, Validation Accuracy: 0.6
# Epoch 14/100, Loss: 0.5351386268933614, Validation Loss: 0.7182896733283997, Validation Accuracy: 0.675
# Epoch 15/100, Loss: 0.3284052014350891, Validation Loss: 0.5763919949531555, Validation Accuracy: 0.7375
# Epoch 16/100, Loss: 0.4262444277604421, Validation Loss: 0.5657680034637451, Validation Accuracy: 0.775
# Epoch 17/100, Loss: 0.29752769072850543, Validation Loss: 0.7293724417686462, Validation Accuracy: 0.775
# Epoch 18/100, Loss: 0.302821879585584, Validation Loss: 0.6861042380332947, Validation Accuracy: 0.775
# Epoch 19/100, Loss: 0.28940897186597186, Validation Loss: 0.6390186548233032, Validation Accuracy: 0.7625
# Epoch 20/100, Loss: 0.2686701864004135, Validation Loss: 0.6271448135375977, Validation Accuracy: 0.75
# Epoch 21/100, Loss: 0.42211457590262097, Validation Loss: 0.6830758452415466, Validation Accuracy: 0.7375
# Epoch 22/100, Loss: 0.2908797562122345, Validation Loss: 0.9414219856262207, Validation Accuracy: 0.7
# Epoch 23/100, Loss: 0.335866779088974, Validation Loss: 0.6936577558517456, Validation Accuracy: 0.7375
# Epoch 24/100, Loss: 0.3598733643690745, Validation Loss: 0.672063946723938, Validation Accuracy: 0.7625
# Epoch 25/100, Loss: 0.23211653033892313, Validation Loss: 0.8302381634712219, Validation Accuracy: 0.7625
# Epoch 26/100, Loss: 0.30774269501368207, Validation Loss: 0.6849727630615234, Validation Accuracy: 0.75
# Epoch 27/100, Loss: 0.21796097854773203, Validation Loss: 0.673109233379364, Validation Accuracy: 0.7625
# Epoch 28/100, Loss: 0.2402737389008204, Validation Loss: 0.6764043569564819, Validation Accuracy: 0.7375
# Early stopping!
# Fold 4
# Epoch 1/100, Loss: 2.1402265230814614, Validation Loss: 0.7654361724853516, Validation Accuracy: 0.25
# Epoch 2/100, Loss: 1.0966443220774333, Validation Loss: 0.6552451252937317, Validation Accuracy: 0.7625
# Epoch 3/100, Loss: 0.7713954448699951, Validation Loss: 0.7252349257469177, Validation Accuracy: 0.3125
# Epoch 4/100, Loss: 0.6082486212253571, Validation Loss: 0.6575417518615723, Validation Accuracy: 0.5625
# Epoch 5/100, Loss: 0.49057692289352417, Validation Loss: 0.6411227583885193, Validation Accuracy: 0.675
# Epoch 6/100, Loss: 0.43306275208791095, Validation Loss: 0.6760403513908386, Validation Accuracy: 0.5125
# Epoch 7/100, Loss: 0.4358445902665456, Validation Loss: 0.6222418546676636, Validation Accuracy: 0.7875
# Epoch 8/100, Loss: 0.41238824526468915, Validation Loss: 0.5877516865730286, Validation Accuracy: 0.8
# Epoch 9/100, Loss: 0.4131927688916524, Validation Loss: 0.5799797177314758, Validation Accuracy: 0.8125
# Epoch 10/100, Loss: 0.41088148951530457, Validation Loss: 0.5673626065254211, Validation Accuracy: 0.8125
# Epoch 11/100, Loss: 0.4505181113878886, Validation Loss: 0.5745260715484619, Validation Accuracy: 0.8
# Epoch 12/100, Loss: 0.3764882783095042, Validation Loss: 0.47301846742630005, Validation Accuracy: 0.8
# Epoch 13/100, Loss: 0.3994717101256053, Validation Loss: 0.5684658288955688, Validation Accuracy: 0.8
# Epoch 14/100, Loss: 0.3521456718444824, Validation Loss: 0.42367738485336304, Validation Accuracy: 0.8
# Epoch 15/100, Loss: 0.35588906208674115, Validation Loss: 0.5152493715286255, Validation Accuracy: 0.8125
# Epoch 16/100, Loss: 0.32852614919344586, Validation Loss: 0.5224310755729675, Validation Accuracy: 0.825
# Epoch 17/100, Loss: 0.31616315245628357, Validation Loss: 0.4192642271518707, Validation Accuracy: 0.8
# Epoch 18/100, Loss: 0.31934720277786255, Validation Loss: 0.40342164039611816, Validation Accuracy: 0.8125
# Epoch 19/100, Loss: 0.30792375405629474, Validation Loss: 0.40742072463035583, Validation Accuracy: 0.8
# Epoch 20/100, Loss: 0.3313290774822235, Validation Loss: 0.40368813276290894, Validation Accuracy: 0.8
# Epoch 21/100, Loss: 0.36443711320559186, Validation Loss: 0.3886754810810089, Validation Accuracy: 0.8
# Epoch 22/100, Loss: 0.33267022172609967, Validation Loss: 0.40342140197753906, Validation Accuracy: 0.8375
# Epoch 23/100, Loss: 0.28497130672136944, Validation Loss: 0.40968331694602966, Validation Accuracy: 0.825
# Epoch 24/100, Loss: 0.2663908302783966, Validation Loss: 0.40487247705459595, Validation Accuracy: 0.775
# Epoch 25/100, Loss: 0.2713175614674886, Validation Loss: 0.4323594570159912, Validation Accuracy: 0.825
# Epoch 26/100, Loss: 0.2499405195315679, Validation Loss: 0.4161911606788635, Validation Accuracy: 0.775
# Epoch 27/100, Loss: 0.2376252015431722, Validation Loss: 0.4196373522281647, Validation Accuracy: 0.8
# Epoch 28/100, Loss: 0.24424284199873605, Validation Loss: 0.42145976424217224, Validation Accuracy: 0.825
# Epoch 29/100, Loss: 0.25146694481372833, Validation Loss: 0.42065006494522095, Validation Accuracy: 0.825
# Epoch 30/100, Loss: 0.2542106459538142, Validation Loss: 0.41858023405075073, Validation Accuracy: 0.825
# Epoch 31/100, Loss: 0.2501537352800369, Validation Loss: 0.38921475410461426, Validation Accuracy: 0.7875
# Epoch 32/100, Loss: 0.25318557024002075, Validation Loss: 0.43217238783836365, Validation Accuracy: 0.8375
# Epoch 33/100, Loss: 0.22926073769728342, Validation Loss: 0.3980097472667694, Validation Accuracy: 0.8125
# Epoch 34/100, Loss: 0.23471624155839285, Validation Loss: 0.43746843934059143, Validation Accuracy: 0.85
# Epoch 35/100, Loss: 0.24350319802761078, Validation Loss: 0.4299717843532562, Validation Accuracy: 0.8125
# Epoch 36/100, Loss: 0.24238714575767517, Validation Loss: 0.44945472478866577, Validation Accuracy: 0.8375
# Epoch 37/100, Loss: 0.20998701453208923, Validation Loss: 0.4219534397125244, Validation Accuracy: 0.775
# Epoch 38/100, Loss: 0.2244653950134913, Validation Loss: 0.4184038043022156, Validation Accuracy: 0.8
# Epoch 39/100, Loss: 0.2153476228316625, Validation Loss: 0.43544310331344604, Validation Accuracy: 0.85
# Epoch 40/100, Loss: 0.204867551724116, Validation Loss: 0.4384681284427643, Validation Accuracy: 0.85
# Epoch 41/100, Loss: 0.2055239180723826, Validation Loss: 0.402653306722641, Validation Accuracy: 0.8375
# Early stopping!
# Fold 5
# Epoch 1/100, Loss: 1.2140933871269226, Validation Loss: 0.8573251366615295, Validation Accuracy: 0.2911392405063291
# Epoch 2/100, Loss: 0.9557354052861532, Validation Loss: 0.6894265413284302, Validation Accuracy: 0.5822784810126582
# Epoch 3/100, Loss: 0.7185823718706766, Validation Loss: 0.7457289695739746, Validation Accuracy: 0.3291139240506329
# Epoch 4/100, Loss: 0.5915018121401469, Validation Loss: 0.6416019797325134, Validation Accuracy: 0.6708860759493671
# Epoch 5/100, Loss: 0.42449456453323364, Validation Loss: 0.7432636022567749, Validation Accuracy: 0.46835443037974683
# Epoch 6/100, Loss: 0.43513285120328266, Validation Loss: 0.6393765807151794, Validation Accuracy: 0.6708860759493671
# Epoch 7/100, Loss: 0.4220974842707316, Validation Loss: 0.6221930384635925, Validation Accuracy: 0.6835443037974683
# Epoch 8/100, Loss: 0.39562268058458966, Validation Loss: 0.6696663498878479, Validation Accuracy: 0.6329113924050633
# Epoch 9/100, Loss: 0.3557523687680562, Validation Loss: 0.6657891869544983, Validation Accuracy: 0.6329113924050633
# Epoch 10/100, Loss: 0.3781009217103322, Validation Loss: 0.6458497643470764, Validation Accuracy: 0.6962025316455697
# Epoch 11/100, Loss: 0.44082707166671753, Validation Loss: 0.6158130764961243, Validation Accuracy: 0.6962025316455697
# Epoch 12/100, Loss: 0.39192916949590045, Validation Loss: 0.5840742588043213, Validation Accuracy: 0.7215189873417721
# Epoch 13/100, Loss: 0.3873744507630666, Validation Loss: 0.5696089863777161, Validation Accuracy: 0.7215189873417721
# Epoch 14/100, Loss: 0.39864035447438556, Validation Loss: 0.518619179725647, Validation Accuracy: 0.7468354430379747
# Epoch 15/100, Loss: 0.33798883358637494, Validation Loss: 0.4955945909023285, Validation Accuracy: 0.7341772151898734
# Epoch 16/100, Loss: 0.3425796528657277, Validation Loss: 0.5672194361686707, Validation Accuracy: 0.7088607594936709
# Epoch 17/100, Loss: 0.29039061069488525, Validation Loss: 0.42888814210891724, Validation Accuracy: 0.759493670886076
# Epoch 18/100, Loss: 0.3166420062383016, Validation Loss: 0.4267628490924835, Validation Accuracy: 0.759493670886076
# Epoch 19/100, Loss: 0.30022071798642475, Validation Loss: 0.45907872915267944, Validation Accuracy: 0.7215189873417721
# Epoch 20/100, Loss: 0.2791897654533386, Validation Loss: 0.460401713848114, Validation Accuracy: 0.7215189873417721
# Epoch 21/100, Loss: 0.31141161918640137, Validation Loss: 0.4656732380390167, Validation Accuracy: 0.7088607594936709
# Epoch 22/100, Loss: 0.32689083615938824, Validation Loss: 0.4598589539527893, Validation Accuracy: 0.6962025316455697
# Epoch 23/100, Loss: 0.32303063074747723, Validation Loss: 0.4306710660457611, Validation Accuracy: 0.7215189873417721
# Epoch 24/100, Loss: 0.3340783913930257, Validation Loss: 0.4819626212120056, Validation Accuracy: 0.759493670886076
# Epoch 25/100, Loss: 0.29707716902097064, Validation Loss: 0.4819784462451935, Validation Accuracy: 0.759493670886076
# Epoch 26/100, Loss: 0.2911231070756912, Validation Loss: 0.4079500436782837, Validation Accuracy: 0.7468354430379747
# Epoch 27/100, Loss: 0.29211856921513873, Validation Loss: 0.46842971444129944, Validation Accuracy: 0.7215189873417721
# Epoch 28/100, Loss: 0.25872749586900073, Validation Loss: 0.5447698831558228, Validation Accuracy: 0.759493670886076
# Epoch 29/100, Loss: 0.26938878496487934, Validation Loss: 0.4981779158115387, Validation Accuracy: 0.759493670886076
# Epoch 30/100, Loss: 0.24893146256605783, Validation Loss: 0.48190027475357056, Validation Accuracy: 0.759493670886076
# Epoch 31/100, Loss: 0.36365316808223724, Validation Loss: 0.5560912489891052, Validation Accuracy: 0.7468354430379747
# Epoch 32/100, Loss: 0.30682919422785443, Validation Loss: 0.45553913712501526, Validation Accuracy: 0.7088607594936709
# Epoch 33/100, Loss: 0.28853514790534973, Validation Loss: 0.5482640266418457, Validation Accuracy: 0.759493670886076
# Epoch 34/100, Loss: 0.27466962734858197, Validation Loss: 0.4771708846092224, Validation Accuracy: 0.7215189873417721
# Epoch 35/100, Loss: 0.24256365497907004, Validation Loss: 0.44666555523872375, Validation Accuracy: 0.6708860759493671
# Epoch 36/100, Loss: 0.26071372131506604, Validation Loss: 0.5631849765777588, Validation Accuracy: 0.759493670886076
# Epoch 37/100, Loss: 0.22909976045290628, Validation Loss: 0.4603777527809143, Validation Accuracy: 0.6962025316455697
# Epoch 38/100, Loss: 0.2220988223950068, Validation Loss: 0.46790066361427307, Validation Accuracy: 0.7088607594936709
# Epoch 39/100, Loss: 0.2185476173957189, Validation Loss: 0.49287188053131104, Validation Accuracy: 0.7468354430379747
# Epoch 40/100, Loss: 0.20954436560471854, Validation Loss: 0.49876031279563904, Validation Accuracy: 0.7468354430379747
# Epoch 41/100, Loss: 0.21793060501416525, Validation Loss: 0.4589400887489319, Validation Accuracy: 0.7088607594936709
# Epoch 42/100, Loss: 0.2501922796169917, Validation Loss: 0.5685506463050842, Validation Accuracy: 0.759493670886076
# Epoch 43/100, Loss: 0.24498927096525827, Validation Loss: 0.4533267021179199, Validation Accuracy: 0.7215189873417721
# Epoch 44/100, Loss: 0.22152631481488547, Validation Loss: 0.517727255821228, Validation Accuracy: 0.759493670886076
# Epoch 45/100, Loss: 0.21477654576301575, Validation Loss: 0.5078876614570618, Validation Accuracy: 0.7468354430379747
# Epoch 46/100, Loss: 0.18932742873827615, Validation Loss: 0.46178391575813293, Validation Accuracy: 0.6835443037974683
# Early stopping!
# Accuracy: 0.7975,Precision: 0.8641975308641975, Recall: 0.813953488372093, F1-score: 0.8383233532934131, AUC: 0.7907795610874551
# Confusion Matrix:
# [[109  33]
#  [ 48 210]]
