# %%
import os
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler
import torch.nn.functional as F 

# Constants
EEG_DATA_DIR = r'C:\Users\User\Documents\Lie detect data\6M_AugmentedEEGData'
POLY_DATA_DIR = r'C:\Users\User\Documents\Lie detect data\6M_CombinedPolyData'

def pad_sequence(sequence, target_length):
    """Pad the sequence to the target length."""
    pad_length = target_length - sequence.shape[1]
    if pad_length > 0:
        return np.pad(sequence, ((0, 0), (0, pad_length)), mode='constant')
    else:
        return sequence[:, :target_length]

def load_eeg_data(data_dir):
    X, y = [], []
    lie_count, truth_count = 0, 0
    file_sample_counts = []
    for file_name in os.listdir(data_dir):
        if file_name.endswith('.pkl'):
            file_path = os.path.join(data_dir, file_name)
            try:
                data = pd.read_pickle(file_path)
                print(f"EEG File: {file_name}, Shape: {data.shape}, Type: {type(data)}")
                label = 0 if 'lie' in file_name.lower() else 1
                X.extend(data)
                y.extend([label] * data.shape[0])
                file_sample_counts.append(data.shape[0])
                if label == 0:
                    lie_count += data.shape[0]
                else:
                    truth_count += data.shape[0]
            except Exception as e:
                print(f"Error loading EEG file {file_name}: {str(e)}")
    print(f"Loaded from EEG {data_dir}: {lie_count} lie samples, {truth_count} truth samples")
    return np.array(X), np.array(y), file_sample_counts

def load_poly_data(data_dir):
    X, y = [], []
    lie_count, truth_count = 0, 0
    max_length = 0
    for file_name in os.listdir(data_dir):
        if file_name.endswith('.pkl'):
            file_path = os.path.join(data_dir, file_name)
            try:
                data = pd.read_pickle(file_path)
                print(f"Poly File: {file_name}, Shape: {data.shape}, Type: {type(data)}")
                max_length = max(max_length, data.shape[1])
                label = 0 if 'lie' in file_name.lower() else 1
                X.append(data)
                y.append(label)
                if label == 0:
                    lie_count += 1
                else:
                    truth_count += 1
            except Exception as e:
                print(f"Error loading Poly file {file_name}: {str(e)}")
    print(f"Loaded from Poly {data_dir}: {lie_count} lie samples, {truth_count} truth samples")
    
    # Pad all poly samples to the maximum length
    X_padded = np.array([pad_sequence(x, max_length) for x in X])
    return X_padded, np.array(y)

class CombinedDataset(Dataset):
    def __init__(self, eeg_X, eeg_y, poly_X, poly_y, file_sample_counts):
        self.eeg_X = torch.tensor(eeg_X, dtype=torch.float32)
        self.eeg_y = torch.tensor(eeg_y, dtype=torch.long)
        self.poly_X = torch.tensor(poly_X, dtype=torch.float32)
        self.poly_y = torch.tensor(poly_y, dtype=torch.long)
        
        # Create a mapping from EEG sample index to Poly file index
        self.eeg_to_poly_map = []
        poly_index = 0
        for count in file_sample_counts:
            self.eeg_to_poly_map.extend([poly_index] * count)
            poly_index += 1

    def __len__(self):
        return len(self.eeg_X)

    def __getitem__(self, idx):
        eeg_sample = self.eeg_X[idx]
        eeg_label = self.eeg_y[idx]
        poly_idx = self.eeg_to_poly_map[idx]
        poly_sample = self.poly_X[poly_idx]
        
        # Pad the poly sample to 4475 time steps if it's shorter
        if poly_sample.shape[1] < 4475:
            poly_sample = F.pad(poly_sample, (0, 4475 - poly_sample.shape[1]))
        
        poly_label = self.poly_y[poly_idx]
        
        return eeg_sample, eeg_label, poly_sample, poly_label

# Load data
print("Loading EEG data...")
eeg_X, eeg_y, file_sample_counts = load_eeg_data(EEG_DATA_DIR)
print("Loading Poly data...")
poly_X, poly_y = load_poly_data(POLY_DATA_DIR)

# Check for class imbalance
unique, counts = np.unique(eeg_y, return_counts=True)
print("EEG Class distribution:", dict(zip(unique, counts)))
unique, counts = np.unique(poly_y, return_counts=True)
print("Poly Class distribution:", dict(zip(unique, counts)))

# Normalize EEG data
eeg_scaler = StandardScaler()
eeg_X = eeg_scaler.fit_transform(eeg_X.reshape(-1, eeg_X.shape[-1])).reshape(eeg_X.shape)

# Normalize Poly data
poly_scaler = StandardScaler()
poly_X = poly_scaler.fit_transform(poly_X.reshape(-1, poly_X.shape[-1])).reshape(poly_X.shape)

# Create full dataset
full_dataset = CombinedDataset(eeg_X, eeg_y, poly_X, poly_y, file_sample_counts)

# Print dataset size and shapes
print("Total number of samples:", len(full_dataset))
print("EEG data shape:", eeg_X.shape)
print("Poly data shape:", poly_X.shape)


# Example of how to use the dataset with DataLoader
train_loader = DataLoader(full_dataset, batch_size=32, shuffle=True)

# Print a sample batch and verify alignment
for eeg_batch, eeg_labels, poly_batch, poly_labels in train_loader:
    print("EEG batch shape:", eeg_batch.shape)
    print("EEG labels shape:", eeg_labels.shape)
    print("Poly batch shape:", poly_batch.shape)
    print("Poly labels shape:", poly_labels.shape)
        
    # Verify label alignment
    print("Labels match:", torch.all(eeg_labels == poly_labels))
        
    # Print a few sample indices and their corresponding data
    for i in range(5):  # Print first 5 samples in the batch
        eeg_sample = eeg_batch[i]
        poly_sample = poly_batch[i]
        print(f"Sample {i}:")
        print(f"  EEG label: {eeg_labels[i].item()}, Poly label: {poly_labels[i].item()}")
        print(f"  EEG data (first 5 values): {eeg_sample[0, :5]}")
        print(f"  Poly data (first 5 values): {poly_sample[0, :5]}")
        
    break  # Just print the first batch
# Out:
# Loading EEG data...
# EEG File: augmented_lie_1.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_10.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_11.pkl, Shape: (17, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_12.pkl, Shape: (13, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_13.pkl, Shape: (13, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_14.pkl, Shape: (15, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_15.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_16.pkl, Shape: (4, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_17.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_18.pkl, Shape: (4, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_19.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_2.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_20.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_21.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_22.pkl, Shape: (4, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_23.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_24.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_25.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_26.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_27.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_28.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_29.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_3.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_30.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_31.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_32.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_33.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_34.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_35.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_36.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_37.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_38.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_39.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_4.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_40.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_41.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_42.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_43.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_44.pkl, Shape: (10, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_45.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_46.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_47.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_48.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_49.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_5.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_6.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_7.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_8.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_lie_9.pkl, Shape: (14, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_1.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_10.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_100.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_101.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_11.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_12.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_13.pkl, Shape: (10, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_14.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_15.pkl, Shape: (14, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_16.pkl, Shape: (10, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_17.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_18.pkl, Shape: (12, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_19.pkl, Shape: (13, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_2.pkl, Shape: (13, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_20.pkl, Shape: (12, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_21.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_22.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_23.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_24.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_25.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_26.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_27.pkl, Shape: (13, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_28.pkl, Shape: (12, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_29.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_3.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_30.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_31.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_32.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_33.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_34.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_35.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_36.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_37.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_38.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_39.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_4.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_40.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_41.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_42.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_43.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_44.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_45.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_46.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_47.pkl, Shape: (15, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_48.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_49.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_5.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_50.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_51.pkl, Shape: (15, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_52.pkl, Shape: (14, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_53.pkl, Shape: (17, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_54.pkl, Shape: (10, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_55.pkl, Shape: (12, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_56.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_57.pkl, Shape: (14, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_58.pkl, Shape: (20, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_59.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_6.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_60.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_61.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_62.pkl, Shape: (11, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_63.pkl, Shape: (9, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_64.pkl, Shape: (10, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_65.pkl, Shape: (14, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_66.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_67.pkl, Shape: (12, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_68.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_69.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_7.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_70.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_71.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_72.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_73.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_74.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_75.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_76.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_77.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_78.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_79.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_8.pkl, Shape: (10, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_80.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_81.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_82.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_83.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_84.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_85.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_86.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_87.pkl, Shape: (10, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_88.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_89.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_9.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_90.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_91.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_92.pkl, Shape: (6, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_93.pkl, Shape: (4, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_94.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_95.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_96.pkl, Shape: (8, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_97.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_98.pkl, Shape: (7, 65, 125), Type: <class 'numpy.ndarray'>
# EEG File: augmented_truth_99.pkl, Shape: (5, 65, 125), Type: <class 'numpy.ndarray'>
# Loaded from EEG C:\Users\User\Documents\Lie detect data\6M_AugmentedEEGData: 370 lie samples, 847 truth samples
# Loading Poly data...
# Poly File: poly_lie_1.pkl, Shape: (4, 2970), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_10.pkl, Shape: (4, 3283), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_11.pkl, Shape: (4, 3621), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_12.pkl, Shape: (4, 3375), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_13.pkl, Shape: (4, 3421), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_14.pkl, Shape: (4, 3508), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_15.pkl, Shape: (4, 2933), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_16.pkl, Shape: (4, 2858), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_17.pkl, Shape: (4, 2942), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_18.pkl, Shape: (4, 2854), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_19.pkl, Shape: (4, 2892), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_2.pkl, Shape: (4, 2954), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_20.pkl, Shape: (4, 2913), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_21.pkl, Shape: (4, 3009), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_22.pkl, Shape: (4, 2866), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_23.pkl, Shape: (4, 2970), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_24.pkl, Shape: (4, 3062), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_25.pkl, Shape: (4, 3050), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_26.pkl, Shape: (4, 3091), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_27.pkl, Shape: (4, 2917), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_28.pkl, Shape: (4, 2974), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_29.pkl, Shape: (4, 2992), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_3.pkl, Shape: (4, 2979), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_30.pkl, Shape: (4, 2892), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_31.pkl, Shape: (4, 3030), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_32.pkl, Shape: (4, 2958), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_33.pkl, Shape: (4, 2950), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_34.pkl, Shape: (4, 3134), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_35.pkl, Shape: (4, 2933), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_36.pkl, Shape: (4, 2992), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_37.pkl, Shape: (4, 2979), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_38.pkl, Shape: (4, 2979), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_39.pkl, Shape: (4, 3024), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_4.pkl, Shape: (4, 3025), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_40.pkl, Shape: (4, 3041), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_41.pkl, Shape: (4, 3066), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_42.pkl, Shape: (4, 2954), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_43.pkl, Shape: (4, 3004), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_44.pkl, Shape: (4, 3191), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_45.pkl, Shape: (4, 3108), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_46.pkl, Shape: (4, 3008), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_47.pkl, Shape: (4, 3016), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_48.pkl, Shape: (4, 3004), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_49.pkl, Shape: (4, 3246), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_5.pkl, Shape: (4, 2942), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_6.pkl, Shape: (4, 3279), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_7.pkl, Shape: (4, 3125), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_8.pkl, Shape: (4, 3146), Type: <class 'numpy.ndarray'>
# Poly File: poly_lie_9.pkl, Shape: (4, 3467), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_1.pkl, Shape: (4, 3255), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_10.pkl, Shape: (4, 3074), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_100.pkl, Shape: (4, 3050), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_101.pkl, Shape: (4, 3020), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_11.pkl, Shape: (4, 3121), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_12.pkl, Shape: (4, 3125), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_13.pkl, Shape: (4, 3229), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_14.pkl, Shape: (4, 3163), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_15.pkl, Shape: (4, 3433), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_16.pkl, Shape: (4, 3229), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_17.pkl, Shape: (4, 3304), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_18.pkl, Shape: (4, 3320), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_19.pkl, Shape: (4, 3379), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_2.pkl, Shape: (4, 3384), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_20.pkl, Shape: (4, 3363), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_21.pkl, Shape: (4, 2987), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_22.pkl, Shape: (4, 2992), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_23.pkl, Shape: (4, 3046), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_24.pkl, Shape: (4, 3037), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_25.pkl, Shape: (4, 3034), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_26.pkl, Shape: (4, 2912), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_27.pkl, Shape: (4, 3396), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_28.pkl, Shape: (4, 3334), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_29.pkl, Shape: (4, 3146), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_3.pkl, Shape: (4, 3029), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_30.pkl, Shape: (4, 3013), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_31.pkl, Shape: (4, 3021), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_32.pkl, Shape: (4, 2983), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_33.pkl, Shape: (4, 3046), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_34.pkl, Shape: (4, 3008), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_35.pkl, Shape: (4, 3096), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_36.pkl, Shape: (4, 3012), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_37.pkl, Shape: (4, 3033), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_38.pkl, Shape: (4, 2908), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_39.pkl, Shape: (4, 3017), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_4.pkl, Shape: (4, 3075), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_40.pkl, Shape: (4, 3050), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_41.pkl, Shape: (4, 2950), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_42.pkl, Shape: (4, 3025), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_43.pkl, Shape: (4, 2929), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_44.pkl, Shape: (4, 2896), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_45.pkl, Shape: (4, 2950), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_46.pkl, Shape: (4, 3004), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_47.pkl, Shape: (4, 3509), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_48.pkl, Shape: (4, 3108), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_49.pkl, Shape: (4, 3175), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_5.pkl, Shape: (4, 3125), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_50.pkl, Shape: (4, 3250), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_51.pkl, Shape: (4, 3520), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_52.pkl, Shape: (4, 3487), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_53.pkl, Shape: (4, 3658), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_54.pkl, Shape: (4, 3187), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_55.pkl, Shape: (4, 3308), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_56.pkl, Shape: (4, 3275), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_57.pkl, Shape: (4, 3450), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_58.pkl, Shape: (4, 3833), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_59.pkl, Shape: (4, 2946), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_6.pkl, Shape: (4, 3008), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_60.pkl, Shape: (4, 2954), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_61.pkl, Shape: (4, 2921), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_62.pkl, Shape: (4, 3254), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_63.pkl, Shape: (4, 3134), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_64.pkl, Shape: (4, 3237), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_65.pkl, Shape: (4, 3446), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_66.pkl, Shape: (4, 3084), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_67.pkl, Shape: (4, 3329), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_68.pkl, Shape: (4, 3008), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_69.pkl, Shape: (4, 3004), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_7.pkl, Shape: (4, 2945), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_70.pkl, Shape: (4, 3071), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_71.pkl, Shape: (4, 2970), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_72.pkl, Shape: (4, 2954), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_73.pkl, Shape: (4, 2979), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_74.pkl, Shape: (4, 2945), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_75.pkl, Shape: (4, 3025), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_76.pkl, Shape: (4, 2942), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_77.pkl, Shape: (4, 3029), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_78.pkl, Shape: (4, 3100), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_79.pkl, Shape: (4, 3104), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_8.pkl, Shape: (4, 3191), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_80.pkl, Shape: (4, 2941), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_81.pkl, Shape: (4, 3055), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_82.pkl, Shape: (4, 2987), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_83.pkl, Shape: (4, 3080), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_84.pkl, Shape: (4, 2967), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_85.pkl, Shape: (4, 2967), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_86.pkl, Shape: (4, 2942), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_87.pkl, Shape: (4, 3192), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_88.pkl, Shape: (4, 3037), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_89.pkl, Shape: (4, 3025), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_9.pkl, Shape: (4, 3112), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_90.pkl, Shape: (4, 3113), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_91.pkl, Shape: (4, 2950), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_92.pkl, Shape: (4, 2975), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_93.pkl, Shape: (4, 2854), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_94.pkl, Shape: (4, 3063), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_95.pkl, Shape: (4, 3012), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_96.pkl, Shape: (4, 3104), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_97.pkl, Shape: (4, 3000), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_98.pkl, Shape: (4, 3008), Type: <class 'numpy.ndarray'>
# Poly File: poly_truth_99.pkl, Shape: (4, 2912), Type: <class 'numpy.ndarray'>
# Loaded from Poly C:\Users\User\Documents\Lie detect data\6M_CombinedPolyData: 49 lie samples, 101 truth samples
# EEG Class distribution: {0: 370, 1: 847}
# Poly Class distribution: {0: 49, 1: 101}
# Total number of samples: 1217
# EEG data shape: (1217, 65, 125)
# Poly data shape: (150, 4, 3833)
# EEG batch shape: torch.Size([32, 65, 125])
# EEG labels shape: torch.Size([32])
# Poly batch shape: torch.Size([32, 4, 4475])
# Poly labels shape: torch.Size([32])
# Labels match: tensor(True)
# Sample 0:
#   EEG label: 1, Poly label: 1
#   EEG data (first 5 values): tensor([-0.2443, -0.2328, -0.2429, -0.2732, -0.3056])
#   Poly data (first 5 values): tensor([0.5527, 0.5467, 0.5400, 0.5328, 0.5253])
# Sample 1:
#   EEG label: 1, Poly label: 1
#   EEG data (first 5 values): tensor([5.2722, 5.2564, 5.3157, 5.3729, 5.3512])
#   Poly data (first 5 values): tensor([0.3833, 0.3837, 0.3836, 0.3830, 0.3822])
# Sample 2:
#   EEG label: 1, Poly label: 1
#   EEG data (first 5 values): tensor([-0.2044, -0.1922, -0.1761, -0.1832, -0.2060])
#   Poly data (first 5 values): tensor([0.0606, 0.0627, 0.0648, 0.0667, 0.0688])
# Sample 3:
#   EEG label: 1, Poly label: 1
#   EEG data (first 5 values): tensor([-0.0356,  0.0079,  0.0299,  0.0426,  0.0606])
#   Poly data (first 5 values): tensor([0.1761, 0.1772, 0.1782, 0.1789, 0.1796])
# Sample 4:
#   EEG label: 1, Poly label: 1
#   EEG data (first 5 values): tensor([-0.3244, -0.3355, -0.3369, -0.3398, -0.3456])
#   Poly data (first 5 values): tensor([0.8842, 0.8695, 0.8537, 0.8370, 0.8199])

# %%
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

# Define the model architectures (these should be identical to your training code)
class EEGNet(nn.Module):
    def __init__(self, num_classes=2):
        super(EEGNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, (1, 51), padding='same')
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.depthwiseConv2d = nn.Conv2d(16, 32, (65, 1), groups=16, padding='same')
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.activation = nn.ELU()
        self.pooling = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32 * 65 * 31, num_classes)

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv2d(x)
        x = self.batchnorm2(x)
        x = self.activation(x)
        x = self.pooling(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

class PolygraphNet(nn.Module):
    def __init__(self, num_classes=2):
        super(PolygraphNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, (1, 51), padding='same')
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.depthwiseConv2d = nn.Conv2d(16, 32, (4, 1), groups=16, padding='same')
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.activation = nn.ELU()
        self.pooling = nn.AvgPool2d((1, 4))
        self.dropout = nn.Dropout(0.5)
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(32 * 4 * 1118, num_classes)

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.depthwiseConv2d(x)
        x = self.batchnorm2(x)
        x = self.activation(x)
        x = self.pooling(x)
        x = self.dropout(x)
        x = self.flatten(x)
        x = self.fc(x)
        return x

class EnsembleModel(nn.Module):
    def __init__(self, eeg_model, poly_model):
        super(EnsembleModel, self).__init__()
        self.eeg_model = eeg_model
        self.poly_model = poly_model
        self.fc = nn.Linear(4, 2)

    def forward(self, eeg_input, poly_input):
        eeg_output = self.eeg_model(eeg_input)
        poly_output = self.poly_model(poly_input)
        combined_output = torch.cat((eeg_output, poly_output), dim=1)
        output = self.fc(combined_output)
        return output

# Load the state dictionary
model_path = r'C:\Users\User\Documents\Lie detect data\Ipynb\ensemble_model_fold_3.pth'
loaded_dict = torch.load(model_path, map_location=torch.device('cpu'))

# Instantiate the models
eeg_model = EEGNet()
poly_model = PolygraphNet()
ensemble_model = EnsembleModel(eeg_model, poly_model)

# Load state dictionaries
ensemble_model.load_state_dict(loaded_dict['model_state_dict'])
ensemble_model.eval()

# Move the model to the appropriate device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
ensemble_model.to(device)

# Create the dataset and DataLoader (assuming CombinedDataset is defined somewhere)
test_dataset = CombinedDataset(eeg_X, eeg_y, poly_X, poly_y, file_sample_counts)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

all_labels = []
all_predictions = []

with torch.no_grad():
    for eeg_X_batch, eeg_y_batch, poly_X_batch, poly_y_batch in test_loader:
        print(f"EEG batch shape: {eeg_X_batch.shape}")
        print(f"Poly batch shape: {poly_X_batch.shape}")
        
        eeg_X_batch, poly_X_batch = eeg_X_batch.to(device), poly_X_batch.to(device)
        labels = eeg_y_batch.to(device)
        
        outputs = ensemble_model(eeg_X_batch, poly_X_batch)
        _, predicted = torch.max(outputs.data, 1)
        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays for metric calculations
all_labels = np.array(all_labels)
all_predictions = np.array(all_predictions)

# Calculate metrics
accuracy = accuracy_score(all_labels, all_predictions)
precision = precision_score(all_labels, all_predictions, average='binary')
recall = recall_score(all_labels, all_predictions, average='binary')
f1 = f1_score(all_labels, all_predictions, average='binary')
conf_matrix = confusion_matrix(all_labels, all_predictions)


# Print the metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 78
#      76 # Load the state dictionary
#      77 model_path = r'C:\Users\User\Documents\Lie detect data\Ipynb\ensemble_model_fold_1.pth'
# ---> 78 loaded_dict = torch.load(model_path, map_location=torch.device('cpu'))
#      80 # Instantiate the models
#      81 eeg_model = EEGNet()
#
# File ~\anaconda3\envs\detectlie\Lib\site-packages\torch\serialization.py:997, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     994 if 'encoding' not in pickle_load_args.keys():
#     995     pickle_load_args['encoding'] = 'utf-8'
# --> 997 with _open_file_like(f, 'rb') as opened_file:
#     998     if _is_zipfile(opened_file):
#     999         # The zipfile reader is going to advance the current file position.
#    1000         # If we want to actually tail call to torch.jit.load, we need to
#    1001         # reset back to the original position.
#    1002         orig_position = opened_file.tell()
#
# File ~\anaconda3\envs\detectlie\Lib\site-packages\torch\serialization.py:444, in _open_file_like(name_or_buffer, mode)
#     442 def _open_file_like(name_or_buffer, mode):
#     443     if _is_path(name_or_buffer):
# --> 444         return _open_file(name_or_buffer, mode)
#     445     else:
#     446         if 'w' in mode:
#
# File ~\anaconda3\envs\detectlie\Lib\site-packages\torch\serialization.py:425, in _open_file.__init__(self, name, mode)
#     424 def __init__(self, name, mode):
# --> 425     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\User\\Documents\\Lie detect data\\Ipynb\\ensemble_model_fold_1.pth'
