# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
import pickle
import numpy as np

# Define constants
DATA_DIR = 'C:/Users/User/Documents/Lie detect data/EEGData'
BATCH_SIZE = 32
EPOCHS = 100  # Increased to allow early stopping
LEARNING_RATE = 0.001
NUM_FOLDS = 5
PATIENCE = 20  # Early stopping patience

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Custom Dataset class for EEG data
class EEGDataset(Dataset):
    def __init__(self, data_dir):
        self.data = []
        self.labels = []
        self.load_data(data_dir)
        self.normalize_data()

    def load_data(self, data_dir):
        max_length = 0
        temp_data = []
        
        for file_name in os.listdir(data_dir):
            file_path = os.path.join(data_dir, file_name)
            with open(file_path, 'rb') as f:
                eeg_data = pickle.load(f)
                label = 1 if 'lie' in file_name else 0  # Assuming file names contain 'lie' or 'truth'
                temp_data.append((eeg_data, label))
                max_length = max(max_length, eeg_data.shape[1])

        for eeg_data, label in temp_data:
            padded_data = np.pad(eeg_data, ((0, 0), (0, max_length - eeg_data.shape[1])), mode='constant')
            self.data.append(padded_data)
            self.labels.append(label)
        
        self.data = [torch.tensor(d, dtype=torch.float32, device=device) for d in self.data]
        self.labels = torch.tensor(self.labels, dtype=torch.long, device=device)
    
    def normalize_data(self):
        all_data = torch.cat([d.unsqueeze(0) for d in self.data], dim=0)
        mean = all_data.mean()
        std = all_data.std()
        self.data = [(d - mean) / std for d in self.data]

    def augment_data(self, data):
        # Advanced augmentations: Gaussian noise, time shift, scaling
        noise = torch.randn_like(data, device=device) * 0.01
        shift = torch.roll(data, shifts=int(data.shape[1] * 0.1), dims=1)
        scale = data * (1 + 0.1 * torch.randn(1, device=device))
        return noise + shift + scale

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data, label = self.data[idx], self.labels[idx]
        data = self.augment_data(data)  # Apply augmentation
        return data, label

# Define the EEGNet model
class EEGNet(nn.Module):
    def __init__(self, output_size):
        super(EEGNet, self).__init__()
        self.firstconv = nn.Sequential(
            nn.Conv2d(1, 16, (1, 51), padding=(0, 25)),
            nn.BatchNorm2d(16)
        )
        self.depthwiseConv = nn.Sequential(
            nn.Conv2d(16, 32, (65, 1), groups=16),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d((1, 4)),
            nn.Dropout(0.5)
        )
        self.separableConv = nn.Sequential(
            nn.Conv2d(32, 32, (1, 15), padding=(0, 7)),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d((1, 8)),
            nn.Dropout(0.5)
        )
        self.classify = nn.Sequential(
            nn.Flatten(),
            nn.Linear(output_size, 2)
        )

    def forward(self, x):
        x = self.firstconv(x)
        x = self.depthwiseConv(x)
        x = self.separableConv(x)
        return self.classify(x)

# Function to determine the output size of the EEGNet model before the linear layer
def get_output_size(model, shape):
    with torch.no_grad():
        x = torch.zeros(shape, device=device)
        x = model.firstconv(x)
        x = model.depthwiseConv(x)
        x = model.separableConv(x)
        return x.view(x.size(0), -1).size(1)

# Load data
dataset = EEGDataset(DATA_DIR)

# Determine the correct input size for the linear layer
dummy_input_shape = (1, 1, 65, max([d.shape[1] for d in dataset.data]))  # (batch_size, channels, height, width)
output_size = get_output_size(EEGNet(output_size=0).to(device), dummy_input_shape)

# K-Fold Cross Validation
kf = KFold(n_splits=NUM_FOLDS, shuffle=True)

accuracies = []
precisions = []
recalls = []
f1s = []
aucs = []
val_losses = []  # New list to store validation losses

for fold, (train_index, val_index) in enumerate(kf.split(dataset)):
    print(f'Fold {fold+1}')
    
    train_subset = Subset(dataset, train_index)
    val_subset = Subset(dataset, val_index)

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

    # Initialize model, loss function, and optimizer
    model = EEGNet(output_size=output_size).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

    best_val_accuracy = 0
    best_val_loss = float('inf')  # Track the best validation loss
    patience_counter = 0

    # Training loop
    for epoch in range(EPOCHS):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs.unsqueeze(1))  # Adding channel dimension
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        scheduler.step()

        # Validation
        model.eval()
        correct = 0
        total = 0
        val_running_loss = 0.0
        all_labels = []
        all_predictions = []
        all_probs = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs.unsqueeze(1))  # Adding channel dimension
                loss = criterion(outputs, labels)
                val_running_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                all_labels.extend(labels.cpu().numpy())
                all_predictions.extend(predicted.cpu().numpy())
                all_probs.extend(torch.softmax(outputs, dim=1)[:, 1].cpu().numpy())

        val_loss = val_running_loss / len(val_loader)
        val_accuracy = 100 * correct / total
        val_precision = precision_score(all_labels, all_predictions, average='macro')
        val_recall = recall_score(all_labels, all_predictions, average='macro')
        val_f1 = f1_score(all_labels, all_predictions, average='macro')
        val_auc = roc_auc_score(all_labels, all_probs)

        print(f"Epoch {epoch+1}/{EPOCHS}, Train Loss: {running_loss/len(train_loader):.4f}, "
              f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%, AUC: {val_auc:.2f}")

        # Early stopping based on validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_val_accuracy = val_accuracy
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"Early stopping at epoch {epoch+1}")
                break

    # Final validation metrics for the fold
    accuracies.append(best_val_accuracy)
    precisions.append(val_precision)
    recalls.append(val_recall)
    f1s.append(val_f1)
    aucs.append(val_auc)
    val_losses.append(best_val_loss)  # Store the best validation loss
    print(f'Final Accuracy for fold {fold+1}: {best_val_accuracy:.2f}%')
    print(f'Final Validation Loss for fold {fold+1}: {best_val_loss:.4f}')
    print(f'Final Precision for fold {fold+1}: {val_precision:.2f}')
    print(f'Final Recall for fold {fold+1}: {val_recall:.2f}')
    print(f'Final F1-Score for fold {fold+1}: {val_f1:.2f}')
    print(f'Final AUC for fold {fold+1}: {val_auc:.2f}\n')

# Report average performance across all folds
print(f'Average Accuracy: {np.mean(accuracies):.2f}%')
print(f'Average Validation Loss: {np.mean(val_losses):.4f}')
print(f'Average Precision: {np.mean(precisions):.2f}')
print(f'Average Recall: {np.mean(recalls):.2f}')
print(f'Average F1-Score: {np.mean(f1s):.2f}')
print(f'Average AUC: {np.mean(aucs):.2f}')
# Out:
# Using device: cuda
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\torch\nn\init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Fold 1
# Epoch 1/100, Train Loss: 0.7821, Val Loss: 0.6662, Val Accuracy: 61.11%, AUC: 0.71
# Epoch 2/100, Train Loss: 0.5991, Val Loss: 0.6670, Val Accuracy: 61.11%, AUC: 0.74
# Epoch 3/100, Train Loss: 0.4773, Val Loss: 0.6340, Val Accuracy: 66.67%, AUC: 0.78
# Epoch 4/100, Train Loss: 0.4318, Val Loss: 0.6007, Val Accuracy: 66.67%, AUC: 0.82
# Epoch 5/100, Train Loss: 0.4350, Val Loss: 0.5880, Val Accuracy: 66.67%, AUC: 0.84
# Epoch 6/100, Train Loss: 0.3702, Val Loss: 0.6068, Val Accuracy: 61.11%, AUC: 0.84
# Epoch 7/100, Train Loss: 0.3324, Val Loss: 0.6213, Val Accuracy: 61.11%, AUC: 0.86
# Epoch 8/100, Train Loss: 0.2775, Val Loss: 0.6084, Val Accuracy: 61.11%, AUC: 0.89
# Epoch 9/100, Train Loss: 0.2109, Val Loss: 0.5728, Val Accuracy: 66.67%, AUC: 0.91
# Epoch 10/100, Train Loss: 0.2226, Val Loss: 0.5043, Val Accuracy: 72.22%, AUC: 0.93
# Epoch 11/100, Train Loss: 0.2687, Val Loss: 0.4819, Val Accuracy: 72.22%, AUC: 0.93
# Epoch 12/100, Train Loss: 0.2611, Val Loss: 0.4803, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 13/100, Train Loss: 0.3515, Val Loss: 0.4802, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 14/100, Train Loss: 0.1977, Val Loss: 0.4696, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 15/100, Train Loss: 0.1779, Val Loss: 0.4495, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 16/100, Train Loss: 0.2305, Val Loss: 0.4591, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 17/100, Train Loss: 0.2917, Val Loss: 0.4158, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 18/100, Train Loss: 0.2395, Val Loss: 0.4105, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 19/100, Train Loss: 0.2546, Val Loss: 0.4203, Val Accuracy: 83.33%, AUC: 0.93
# Epoch 20/100, Train Loss: 0.1772, Val Loss: 0.4093, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 21/100, Train Loss: 0.1808, Val Loss: 0.4304, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 22/100, Train Loss: 0.1804, Val Loss: 0.4255, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 23/100, Train Loss: 0.2273, Val Loss: 0.4155, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 24/100, Train Loss: 0.2073, Val Loss: 0.4153, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 25/100, Train Loss: 0.2812, Val Loss: 0.4447, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 26/100, Train Loss: 0.2555, Val Loss: 0.4327, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 27/100, Train Loss: 0.1917, Val Loss: 0.4246, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 28/100, Train Loss: 0.1796, Val Loss: 0.4363, Val Accuracy: 77.78%, AUC: 0.93
# Epoch 29/100, Train Loss: 0.1784, Val Loss: 0.4419, Val Accuracy: 77.78%, AUC: 0.93
# Epoch 30/100, Train Loss: 0.2566, Val Loss: 0.4201, Val Accuracy: 77.78%, AUC: 0.93
# Epoch 31/100, Train Loss: 0.1725, Val Loss: 0.4232, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 32/100, Train Loss: 0.2321, Val Loss: 0.4026, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 33/100, Train Loss: 0.2005, Val Loss: 0.3948, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 34/100, Train Loss: 0.1799, Val Loss: 0.4030, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 35/100, Train Loss: 0.1707, Val Loss: 0.3966, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 36/100, Train Loss: 0.1970, Val Loss: 0.3820, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 37/100, Train Loss: 0.2083, Val Loss: 0.3908, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 38/100, Train Loss: 0.2230, Val Loss: 0.3885, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 39/100, Train Loss: 0.1780, Val Loss: 0.4049, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 40/100, Train Loss: 0.1549, Val Loss: 0.4113, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 41/100, Train Loss: 0.2144, Val Loss: 0.4098, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 42/100, Train Loss: 0.2015, Val Loss: 0.4065, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 43/100, Train Loss: 0.2489, Val Loss: 0.4497, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 44/100, Train Loss: 0.1848, Val Loss: 0.4533, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 45/100, Train Loss: 0.1827, Val Loss: 0.4401, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 46/100, Train Loss: 0.1840, Val Loss: 0.4341, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 47/100, Train Loss: 0.2887, Val Loss: 0.4225, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 48/100, Train Loss: 0.1936, Val Loss: 0.4656, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 49/100, Train Loss: 0.2207, Val Loss: 0.4468, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 50/100, Train Loss: 0.2250, Val Loss: 0.4270, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 51/100, Train Loss: 0.1713, Val Loss: 0.4230, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 52/100, Train Loss: 0.2206, Val Loss: 0.4207, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 53/100, Train Loss: 0.1688, Val Loss: 0.4410, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 54/100, Train Loss: 0.2093, Val Loss: 0.4366, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 55/100, Train Loss: 0.1982, Val Loss: 0.4370, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 56/100, Train Loss: 0.1838, Val Loss: 0.4371, Val Accuracy: 77.78%, AUC: 0.94
# Early stopping at epoch 56
# Final Accuracy for fold 1: 83.33%
# Final Validation Loss for fold 1: 0.3820
# Final Precision for fold 1: 0.83
# Final Recall for fold 1: 0.80
# Final F1-Score for fold 1: 0.78
# Final AUC for fold 1: 0.94
#
# Fold 2
# Epoch 1/100, Train Loss: 0.8668, Val Loss: 0.6175, Val Accuracy: 72.22%, AUC: 0.80
# Epoch 2/100, Train Loss: 0.5868, Val Loss: 0.6609, Val Accuracy: 66.67%, AUC: 0.77
# Epoch 3/100, Train Loss: 0.6043, Val Loss: 0.6438, Val Accuracy: 61.11%, AUC: 0.80
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 4/100, Train Loss: 0.5020, Val Loss: 0.5789, Val Accuracy: 77.78%, AUC: 0.88
# Epoch 5/100, Train Loss: 0.3993, Val Loss: 0.4917, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 6/100, Train Loss: 0.4130, Val Loss: 0.4336, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 7/100, Train Loss: 0.3645, Val Loss: 0.4088, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 8/100, Train Loss: 0.3310, Val Loss: 0.4340, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 9/100, Train Loss: 0.3021, Val Loss: 0.4356, Val Accuracy: 77.78%, AUC: 0.98
# Epoch 10/100, Train Loss: 0.3036, Val Loss: 0.4181, Val Accuracy: 77.78%, AUC: 0.98
# Epoch 11/100, Train Loss: 0.2595, Val Loss: 0.4307, Val Accuracy: 77.78%, AUC: 0.98
# Epoch 12/100, Train Loss: 0.2697, Val Loss: 0.4410, Val Accuracy: 77.78%, AUC: 1.00
# Epoch 13/100, Train Loss: 0.3288, Val Loss: 0.4498, Val Accuracy: 77.78%, AUC: 0.97
# Epoch 14/100, Train Loss: 0.2457, Val Loss: 0.4386, Val Accuracy: 83.33%, AUC: 0.98
# Epoch 15/100, Train Loss: 0.3215, Val Loss: 0.4307, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 16/100, Train Loss: 0.2310, Val Loss: 0.4048, Val Accuracy: 83.33%, AUC: 1.00
# Epoch 17/100, Train Loss: 0.2594, Val Loss: 0.3899, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 18/100, Train Loss: 0.3026, Val Loss: 0.3992, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 19/100, Train Loss: 0.2447, Val Loss: 0.3827, Val Accuracy: 83.33%, AUC: 0.98
# Epoch 20/100, Train Loss: 0.2818, Val Loss: 0.3748, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 21/100, Train Loss: 0.2332, Val Loss: 0.3674, Val Accuracy: 83.33%, AUC: 0.98
# Epoch 22/100, Train Loss: 0.2142, Val Loss: 0.3862, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 23/100, Train Loss: 0.2729, Val Loss: 0.3706, Val Accuracy: 83.33%, AUC: 0.97
# Epoch 24/100, Train Loss: 0.2654, Val Loss: 0.3820, Val Accuracy: 83.33%, AUC: 0.98
# Epoch 25/100, Train Loss: 0.2261, Val Loss: 0.3866, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 26/100, Train Loss: 0.2329, Val Loss: 0.3954, Val Accuracy: 83.33%, AUC: 0.98
# Epoch 27/100, Train Loss: 0.2578, Val Loss: 0.4128, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 28/100, Train Loss: 0.4352, Val Loss: 0.3804, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 29/100, Train Loss: 0.1843, Val Loss: 0.4002, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 30/100, Train Loss: 0.2259, Val Loss: 0.4025, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 31/100, Train Loss: 0.2814, Val Loss: 0.3922, Val Accuracy: 83.33%, AUC: 1.00
# Epoch 32/100, Train Loss: 0.2483, Val Loss: 0.3756, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 33/100, Train Loss: 0.2305, Val Loss: 0.3725, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 34/100, Train Loss: 0.2445, Val Loss: 0.3672, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 35/100, Train Loss: 0.2414, Val Loss: 0.3507, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 36/100, Train Loss: 0.2317, Val Loss: 0.3642, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 37/100, Train Loss: 0.2472, Val Loss: 0.3540, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 38/100, Train Loss: 0.2148, Val Loss: 0.3758, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 39/100, Train Loss: 0.1962, Val Loss: 0.3703, Val Accuracy: 83.33%, AUC: 0.98
# Epoch 40/100, Train Loss: 0.2416, Val Loss: 0.3853, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 41/100, Train Loss: 0.2541, Val Loss: 0.3672, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 42/100, Train Loss: 0.2258, Val Loss: 0.3773, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 43/100, Train Loss: 0.2906, Val Loss: 0.3615, Val Accuracy: 83.33%, AUC: 0.97
# Epoch 44/100, Train Loss: 0.2020, Val Loss: 0.3694, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 45/100, Train Loss: 0.2555, Val Loss: 0.3665, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 46/100, Train Loss: 0.2154, Val Loss: 0.3814, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 47/100, Train Loss: 0.2217, Val Loss: 0.3707, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 48/100, Train Loss: 0.1967, Val Loss: 0.3591, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 49/100, Train Loss: 0.2670, Val Loss: 0.3645, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 50/100, Train Loss: 0.2246, Val Loss: 0.3598, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 51/100, Train Loss: 0.2992, Val Loss: 0.3713, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 52/100, Train Loss: 0.2289, Val Loss: 0.3850, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 53/100, Train Loss: 0.2012, Val Loss: 0.4049, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 54/100, Train Loss: 0.2563, Val Loss: 0.3809, Val Accuracy: 83.33%, AUC: 0.92
# Epoch 55/100, Train Loss: 0.2032, Val Loss: 0.3851, Val Accuracy: 83.33%, AUC: 0.94
# Early stopping at epoch 55
# Final Accuracy for fold 2: 83.33%
# Final Validation Loss for fold 2: 0.3507
# Final Precision for fold 2: 0.81
# Final Recall for fold 2: 0.88
# Final F1-Score for fold 2: 0.82
# Final AUC for fold 2: 0.94
#
# Fold 3
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/100, Train Loss: 0.7287, Val Loss: 0.7664, Val Accuracy: 50.00%, AUC: 0.58
# Epoch 2/100, Train Loss: 0.6196, Val Loss: 0.7516, Val Accuracy: 55.56%, AUC: 0.64
# Epoch 3/100, Train Loss: 0.5495, Val Loss: 0.6886, Val Accuracy: 77.78%, AUC: 0.68
# Epoch 4/100, Train Loss: 0.5503, Val Loss: 0.6238, Val Accuracy: 66.67%, AUC: 0.78
# Epoch 5/100, Train Loss: 0.4810, Val Loss: 0.5995, Val Accuracy: 66.67%, AUC: 0.80
# Epoch 6/100, Train Loss: 0.4350, Val Loss: 0.5483, Val Accuracy: 77.78%, AUC: 0.85
# Epoch 7/100, Train Loss: 0.4502, Val Loss: 0.5177, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 8/100, Train Loss: 0.3751, Val Loss: 0.5133, Val Accuracy: 83.33%, AUC: 0.89
# Epoch 9/100, Train Loss: 0.3290, Val Loss: 0.4927, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 10/100, Train Loss: 0.3137, Val Loss: 0.4460, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 11/100, Train Loss: 0.2765, Val Loss: 0.4344, Val Accuracy: 83.33%, AUC: 0.91
# Epoch 12/100, Train Loss: 0.3143, Val Loss: 0.4326, Val Accuracy: 83.33%, AUC: 0.95
# Epoch 13/100, Train Loss: 0.2581, Val Loss: 0.4222, Val Accuracy: 83.33%, AUC: 0.93
# Epoch 14/100, Train Loss: 0.2849, Val Loss: 0.4241, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 15/100, Train Loss: 0.3115, Val Loss: 0.4046, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 16/100, Train Loss: 0.2569, Val Loss: 0.3873, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 17/100, Train Loss: 0.2845, Val Loss: 0.3739, Val Accuracy: 83.33%, AUC: 0.94
# Epoch 18/100, Train Loss: 0.2880, Val Loss: 0.3810, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 19/100, Train Loss: 0.3131, Val Loss: 0.3745, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 20/100, Train Loss: 0.2970, Val Loss: 0.3747, Val Accuracy: 77.78%, AUC: 0.94
# Epoch 21/100, Train Loss: 0.2534, Val Loss: 0.3779, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 22/100, Train Loss: 0.2363, Val Loss: 0.3752, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 23/100, Train Loss: 0.2760, Val Loss: 0.3804, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 24/100, Train Loss: 0.2300, Val Loss: 0.3836, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 25/100, Train Loss: 0.2336, Val Loss: 0.3844, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 26/100, Train Loss: 0.2480, Val Loss: 0.3823, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 27/100, Train Loss: 0.2353, Val Loss: 0.3908, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 28/100, Train Loss: 0.2803, Val Loss: 0.3856, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 29/100, Train Loss: 0.2953, Val Loss: 0.3758, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 30/100, Train Loss: 0.2381, Val Loss: 0.3853, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 31/100, Train Loss: 0.3204, Val Loss: 0.3863, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 32/100, Train Loss: 0.3670, Val Loss: 0.3789, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 33/100, Train Loss: 0.2862, Val Loss: 0.3815, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 34/100, Train Loss: 0.3185, Val Loss: 0.3899, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 35/100, Train Loss: 0.2977, Val Loss: 0.3932, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 36/100, Train Loss: 0.2233, Val Loss: 0.3902, Val Accuracy: 77.78%, AUC: 0.95
# Epoch 37/100, Train Loss: 0.2912, Val Loss: 0.3764, Val Accuracy: 77.78%, AUC: 0.95
# Early stopping at epoch 37
# Final Accuracy for fold 3: 83.33%
# Final Validation Loss for fold 3: 0.3739
# Final Precision for fold 3: 0.78
# Final Recall for fold 3: 0.78
# Final F1-Score for fold 3: 0.78
# Final AUC for fold 3: 0.95
#
# Fold 4
# Epoch 1/100, Train Loss: 0.7527, Val Loss: 0.6306, Val Accuracy: 55.56%, AUC: 0.75
# Epoch 2/100, Train Loss: 0.5002, Val Loss: 0.5910, Val Accuracy: 83.33%, AUC: 0.84
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/100, Train Loss: 0.4518, Val Loss: 0.5437, Val Accuracy: 83.33%, AUC: 0.88
# Epoch 4/100, Train Loss: 0.3849, Val Loss: 0.5046, Val Accuracy: 88.89%, AUC: 0.90
# Epoch 5/100, Train Loss: 0.4158, Val Loss: 0.4424, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 6/100, Train Loss: 0.3526, Val Loss: 0.3789, Val Accuracy: 88.89%, AUC: 0.96
# Epoch 7/100, Train Loss: 0.3881, Val Loss: 0.3423, Val Accuracy: 88.89%, AUC: 0.96
# Epoch 8/100, Train Loss: 0.3237, Val Loss: 0.3260, Val Accuracy: 88.89%, AUC: 0.95
# Epoch 9/100, Train Loss: 0.3129, Val Loss: 0.2883, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 10/100, Train Loss: 0.2368, Val Loss: 0.3893, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 11/100, Train Loss: 0.3117, Val Loss: 0.3362, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 12/100, Train Loss: 0.3288, Val Loss: 0.3061, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 13/100, Train Loss: 0.3516, Val Loss: 0.3039, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 14/100, Train Loss: 0.2168, Val Loss: 0.3374, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 15/100, Train Loss: 0.3272, Val Loss: 0.3063, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 16/100, Train Loss: 0.3239, Val Loss: 0.3278, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 17/100, Train Loss: 0.2282, Val Loss: 0.3197, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 18/100, Train Loss: 0.1963, Val Loss: 0.3253, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 19/100, Train Loss: 0.2822, Val Loss: 0.2781, Val Accuracy: 94.44%, AUC: 0.98
# Epoch 20/100, Train Loss: 0.2468, Val Loss: 0.2768, Val Accuracy: 94.44%, AUC: 0.98
# Epoch 21/100, Train Loss: 0.2433, Val Loss: 0.2966, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 22/100, Train Loss: 0.2878, Val Loss: 0.2903, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 23/100, Train Loss: 0.2661, Val Loss: 0.2941, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 24/100, Train Loss: 0.3479, Val Loss: 0.3114, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 25/100, Train Loss: 0.2371, Val Loss: 0.2939, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 26/100, Train Loss: 0.1953, Val Loss: 0.2944, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 27/100, Train Loss: 0.3032, Val Loss: 0.2749, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 28/100, Train Loss: 0.2975, Val Loss: 0.3029, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 29/100, Train Loss: 0.2417, Val Loss: 0.2648, Val Accuracy: 94.44%, AUC: 0.98
# Epoch 30/100, Train Loss: 0.4338, Val Loss: 0.3000, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 31/100, Train Loss: 0.2968, Val Loss: 0.3184, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 32/100, Train Loss: 0.2695, Val Loss: 0.2851, Val Accuracy: 94.44%, AUC: 0.98
# Epoch 33/100, Train Loss: 0.2061, Val Loss: 0.3123, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 34/100, Train Loss: 0.2652, Val Loss: 0.3240, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 35/100, Train Loss: 0.2596, Val Loss: 0.3318, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 36/100, Train Loss: 0.2885, Val Loss: 0.3206, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 37/100, Train Loss: 0.2796, Val Loss: 0.2942, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 38/100, Train Loss: 0.2371, Val Loss: 0.2964, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 39/100, Train Loss: 0.2034, Val Loss: 0.2891, Val Accuracy: 94.44%, AUC: 0.96
# Epoch 40/100, Train Loss: 0.3106, Val Loss: 0.3279, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 41/100, Train Loss: 0.2711, Val Loss: 0.3179, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 42/100, Train Loss: 0.2199, Val Loss: 0.3264, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 43/100, Train Loss: 0.2779, Val Loss: 0.3072, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 44/100, Train Loss: 0.2901, Val Loss: 0.3122, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 45/100, Train Loss: 0.2685, Val Loss: 0.3010, Val Accuracy: 94.44%, AUC: 0.95
# Epoch 46/100, Train Loss: 0.2213, Val Loss: 0.2710, Val Accuracy: 94.44%, AUC: 0.98
# Epoch 47/100, Train Loss: 0.2527, Val Loss: 0.2681, Val Accuracy: 94.44%, AUC: 0.98
# Epoch 48/100, Train Loss: 0.2969, Val Loss: 0.2741, Val Accuracy: 94.44%, AUC: 0.98
# Epoch 49/100, Train Loss: 0.3590, Val Loss: 0.2757, Val Accuracy: 94.44%, AUC: 0.96
# Early stopping at epoch 49
# Final Accuracy for fold 4: 94.44%
# Final Validation Loss for fold 4: 0.2648
# Final Precision for fold 4: 0.95
# Final Recall for fold 4: 0.94
# Final F1-Score for fold 4: 0.94
# Final AUC for fold 4: 0.96
#
# Fold 5
# Epoch 1/100, Train Loss: 0.6656, Val Loss: 0.6063, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 2/100, Train Loss: 0.6510, Val Loss: 0.6357, Val Accuracy: 66.67%, AUC: 0.83
# Epoch 3/100, Train Loss: 0.5138, Val Loss: 0.7638, Val Accuracy: 66.67%, AUC: 0.78
# Epoch 4/100, Train Loss: 0.4758, Val Loss: 0.7332, Val Accuracy: 72.22%, AUC: 0.80
# Epoch 5/100, Train Loss: 0.3854, Val Loss: 0.6050, Val Accuracy: 72.22%, AUC: 0.80
# Epoch 6/100, Train Loss: 0.3348, Val Loss: 0.5374, Val Accuracy: 72.22%, AUC: 0.82
# Epoch 7/100, Train Loss: 0.3290, Val Loss: 0.5605, Val Accuracy: 72.22%, AUC: 0.83
# Epoch 8/100, Train Loss: 0.3315, Val Loss: 0.6586, Val Accuracy: 72.22%, AUC: 0.80
# Epoch 9/100, Train Loss: 0.2570, Val Loss: 0.7068, Val Accuracy: 72.22%, AUC: 0.80
# Epoch 10/100, Train Loss: 0.2481, Val Loss: 0.7492, Val Accuracy: 72.22%, AUC: 0.83
# Epoch 11/100, Train Loss: 0.2574, Val Loss: 0.7432, Val Accuracy: 72.22%, AUC: 0.85
# Epoch 12/100, Train Loss: 0.2616, Val Loss: 0.7220, Val Accuracy: 72.22%, AUC: 0.86
# Epoch 13/100, Train Loss: 0.3579, Val Loss: 0.7432, Val Accuracy: 77.78%, AUC: 0.85
# Epoch 14/100, Train Loss: 0.2161, Val Loss: 0.7551, Val Accuracy: 72.22%, AUC: 0.85
# Epoch 15/100, Train Loss: 0.3432, Val Loss: 0.8041, Val Accuracy: 72.22%, AUC: 0.82
# Epoch 16/100, Train Loss: 0.2034, Val Loss: 0.7767, Val Accuracy: 77.78%, AUC: 0.82
# Epoch 17/100, Train Loss: 0.2566, Val Loss: 0.7079, Val Accuracy: 77.78%, AUC: 0.85
# Epoch 18/100, Train Loss: 0.2586, Val Loss: 0.7373, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 19/100, Train Loss: 0.2121, Val Loss: 0.6951, Val Accuracy: 83.33%, AUC: 0.86
# Epoch 20/100, Train Loss: 0.2264, Val Loss: 0.6895, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 21/100, Train Loss: 0.2258, Val Loss: 0.6553, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 22/100, Train Loss: 0.2468, Val Loss: 0.6780, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 23/100, Train Loss: 0.1997, Val Loss: 0.6615, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 24/100, Train Loss: 0.2234, Val Loss: 0.6462, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 25/100, Train Loss: 0.2119, Val Loss: 0.6857, Val Accuracy: 77.78%, AUC: 0.86
# Epoch 26/100, Train Loss: 0.2693, Val Loss: 0.6729, Val Accuracy: 77.78%, AUC: 0.86
# Early stopping at epoch 26
# Final Accuracy for fold 5: 72.22%
# Final Validation Loss for fold 5: 0.5374
# Final Precision for fold 5: 0.74
# Final Recall for fold 5: 0.78
# Final F1-Score for fold 5: 0.75
# Final AUC for fold 5: 0.86
#
# Average Accuracy: 83.33%
# Average Validation Loss: 0.3818
# Average Precision: 0.82
# Average Recall: 0.84
# Average F1-Score: 0.81
# Average AUC: 0.93
