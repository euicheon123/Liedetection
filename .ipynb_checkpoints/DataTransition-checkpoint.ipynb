# %%
import os
import pickle

# Path to the directory containing the combined poly data files
data_dir = r'C:\Users\User\Documents\Lie detect data\npy 데이터2'

# Ensure the output directory exists
output_dir = r'C:\Users\User\Documents\Lie detect data\5M_EEGData'
os.makedirs(output_dir, exist_ok=True)

# Initialize counters for naming
truth_counter = 1
lie_counter = 1

# Iterate through all files in the data directory
for file_name in os.listdir(data_dir):
    if file_name.endswith('.pkl'):
        file_path = os.path.join(data_dir, file_name)

        # Load the combined Poly data file
        with open(file_path, 'rb') as file:
            combined_data = pickle.load(file)

        # Debug: Print the file being processed
        print(f"Processing file: {file_name}, Number of epochs: {len(combined_data)}")

        # Determine if the file contains truth or lie data based on the filename
        if 'truth' in file_name and 'quer' in file_name and 'eeg' in file_name:
            label = 'truth'
            counter = truth_counter
        elif 'lie' in file_name and 'quer' in file_name and 'eeg' in file_name:
            label = 'lie'
            counter = lie_counter
        else:
            continue

        # Split and save individual epochs
        for i, epoch in enumerate(combined_data):
            individual_file_path = os.path.join(output_dir, f'{label}_{counter}.pkl')
            with open(individual_file_path, 'wb') as individual_file:
                pickle.dump(epoch, individual_file)
                
            # Debug: Print each file being saved
            print(f"Saved {label} epoch {i+1} as {individual_file_path}")
            
            counter += 1

        # Update the respective counter
        if label == 'truth':
            truth_counter = counter
        elif label == 'lie':
            lie_counter = counter

print(f"Saved {truth_counter - 1} truth epochs and {lie_counter - 1} lie epochs.")
# Out:
# Processing file: eeg_ansc_1_01.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_02.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_03.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_04.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_05.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_06.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_07.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_09.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_10.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_12.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_13.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_14.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_15.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_16.pkl, Number of epochs: 6
# Processing file: eeg_ansc_1_18.pkl, Number of epochs: 6
# Processing file: eeg_ansg_1_01.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_02.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_03.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_04.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_05.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_06.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_07.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_09.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_10.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_12.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_13.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_14.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_15.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_16.pkl, Number of epochs: 4
# Processing file: eeg_ansg_1_18.pkl, Number of epochs: 4
# Processing file: eeg_ansr_lie_1_01.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_1_02.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_1_05.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_1_06.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_1_13.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_1_15.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_1_16.pkl, Number of epochs: 5
# Processing file: eeg_ansr_truth_1_01.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_1_02.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_1_03.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_1_04.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_1_05.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_1_06.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_1_07.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_1_09.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_1_10.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_1_12.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_1_13.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_1_14.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_1_15.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_1_16.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_1_18.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_01.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_02.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_03.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_04.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_05.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_06.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_07.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_09.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_10.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_12.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_13.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_14.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_15.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_16.pkl, Number of epochs: 6
# Processing file: eeg_quec_1_18.pkl, Number of epochs: 6
# Processing file: eeg_queg_1_01.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_02.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_03.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_04.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_05.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_06.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_07.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_09.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_10.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_12.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_13.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_14.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_15.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_16.pkl, Number of epochs: 4
# Processing file: eeg_queg_1_18.pkl, Number of epochs: 4
# Processing file: eeg_quer_lie_1_01.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_1.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_2.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_3.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_4.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_5.pkl
# Processing file: eeg_quer_lie_1_02.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_6.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_7.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_8.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_9.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_10.pkl
# Processing file: eeg_quer_lie_1_05.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_11.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_12.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_13.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_14.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_15.pkl
# Processing file: eeg_quer_lie_1_06.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_16.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_17.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_18.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_19.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_20.pkl
# Processing file: eeg_quer_lie_1_13.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_21.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_22.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_23.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_24.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_25.pkl
# Processing file: eeg_quer_lie_1_15.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_26.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_27.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_28.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_29.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_30.pkl
# Processing file: eeg_quer_lie_1_16.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_31.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_32.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_33.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_34.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\lie_35.pkl
# Processing file: eeg_quer_truth_1_01.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_1.pkl
# Processing file: eeg_quer_truth_1_02.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_2.pkl
# Processing file: eeg_quer_truth_1_03.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_3.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_4.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_5.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_6.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_7.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_8.pkl
# Processing file: eeg_quer_truth_1_04.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_9.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_10.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_11.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_12.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_13.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_14.pkl
# Processing file: eeg_quer_truth_1_05.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_15.pkl
# Processing file: eeg_quer_truth_1_06.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_16.pkl
# Processing file: eeg_quer_truth_1_07.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_17.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_18.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_19.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_20.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_21.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_22.pkl
# Processing file: eeg_quer_truth_1_09.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_23.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_24.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_25.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_26.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_27.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_28.pkl
# Processing file: eeg_quer_truth_1_10.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_29.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_30.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_31.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_32.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_33.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_34.pkl
# Processing file: eeg_quer_truth_1_12.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_35.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_36.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_37.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_38.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_39.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_40.pkl
# Processing file: eeg_quer_truth_1_13.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_41.pkl
# Processing file: eeg_quer_truth_1_14.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_42.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_43.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_44.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_45.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_46.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_47.pkl
# Processing file: eeg_quer_truth_1_15.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_48.pkl
# Processing file: eeg_quer_truth_1_16.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_49.pkl
# Processing file: eeg_quer_truth_1_18.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_50.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_51.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_52.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_53.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_54.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\5M_EEGData\truth_55.pkl
# Processing file: poly_ansc_1_01.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_02.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_03.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_04.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_05.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_06.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_07.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_09.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_10.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_12.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_13.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_14.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_15.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_16.pkl, Number of epochs: 6
# Processing file: poly_ansc_1_18.pkl, Number of epochs: 6
# Processing file: poly_ansg_1_01.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_02.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_03.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_04.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_05.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_06.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_07.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_09.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_10.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_12.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_13.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_14.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_15.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_16.pkl, Number of epochs: 4
# Processing file: poly_ansg_1_18.pkl, Number of epochs: 4
# Processing file: poly_ansr_lie_1_01.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_1_02.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_1_05.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_1_06.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_1_13.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_1_15.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_1_16.pkl, Number of epochs: 5
# Processing file: poly_ansr_truth_1_01.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_1_02.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_1_03.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_1_04.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_1_05.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_1_06.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_1_07.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_1_09.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_1_10.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_1_12.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_1_13.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_1_14.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_1_15.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_1_16.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_1_18.pkl, Number of epochs: 6
# Processing file: poly_quec_1_01.pkl, Number of epochs: 6
# Processing file: poly_quec_1_02.pkl, Number of epochs: 6
# Processing file: poly_quec_1_03.pkl, Number of epochs: 6
# Processing file: poly_quec_1_04.pkl, Number of epochs: 6
# Processing file: poly_quec_1_05.pkl, Number of epochs: 6
# Processing file: poly_quec_1_06.pkl, Number of epochs: 6
# Processing file: poly_quec_1_07.pkl, Number of epochs: 6
# Processing file: poly_quec_1_09.pkl, Number of epochs: 6
# Processing file: poly_quec_1_10.pkl, Number of epochs: 6
# Processing file: poly_quec_1_12.pkl, Number of epochs: 6
# Processing file: poly_quec_1_13.pkl, Number of epochs: 6
# Processing file: poly_quec_1_14.pkl, Number of epochs: 6
# Processing file: poly_quec_1_15.pkl, Number of epochs: 6
# Processing file: poly_quec_1_16.pkl, Number of epochs: 6
# Processing file: poly_quec_1_18.pkl, Number of epochs: 6
# Processing file: poly_queg_1_01.pkl, Number of epochs: 4
# Processing file: poly_queg_1_02.pkl, Number of epochs: 4
# Processing file: poly_queg_1_03.pkl, Number of epochs: 4
# Processing file: poly_queg_1_04.pkl, Number of epochs: 4
# Processing file: poly_queg_1_05.pkl, Number of epochs: 4
# Processing file: poly_queg_1_06.pkl, Number of epochs: 4
# Processing file: poly_queg_1_07.pkl, Number of epochs: 4
# Processing file: poly_queg_1_09.pkl, Number of epochs: 4
# Processing file: poly_queg_1_10.pkl, Number of epochs: 4
# Processing file: poly_queg_1_12.pkl, Number of epochs: 4
# Processing file: poly_queg_1_13.pkl, Number of epochs: 4
# Processing file: poly_queg_1_14.pkl, Number of epochs: 4
# Processing file: poly_queg_1_15.pkl, Number of epochs: 4
# Processing file: poly_queg_1_16.pkl, Number of epochs: 4
# Processing file: poly_queg_1_18.pkl, Number of epochs: 4
# Processing file: poly_quer_lie_1_01.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_1_02.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_1_05.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_1_06.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_1_13.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_1_15.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_1_16.pkl, Number of epochs: 5
# Processing file: poly_quer_truth_1_01.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_1_02.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_1_03.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_1_04.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_1_05.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_1_06.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_1_07.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_1_09.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_1_10.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_1_12.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_1_13.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_1_14.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_1_15.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_1_16.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_1_18.pkl, Number of epochs: 6
# Saved 55 truth epochs and 35 lie epochs.
