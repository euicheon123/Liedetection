# %% [markdown]
# # EEGNet

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
import pickle
import numpy as np

# Define constants
DATA_DIR = 'C:/Users/User/Documents/Lie detect data/EEGData'
BATCH_SIZE = 32
EPOCHS = 100  # Increased to allow early stopping
LEARNING_RATE = 0.001
NUM_FOLDS = 5
PATIENCE = 20  # Early stopping patience

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Custom Dataset class for EEG data
class EEGDataset(Dataset):
    def __init__(self, data_dir):
        self.data = []
        self.labels = []
        self.load_data(data_dir)
        self.normalize_data()

    def load_data(self, data_dir):
        max_length = 0
        temp_data = []
        
        for file_name in os.listdir(data_dir):
            file_path = os.path.join(data_dir, file_name)
            with open(file_path, 'rb') as f:
                eeg_data = pickle.load(f)
                label = 1 if 'lie' in file_name else 0  # Assuming file names contain 'lie' or 'truth'
                temp_data.append((eeg_data, label))
                max_length = max(max_length, eeg_data.shape[1])

        for eeg_data, label in temp_data:
            padded_data = np.pad(eeg_data, ((0, 0), (0, max_length - eeg_data.shape[1])), mode='constant')
            self.data.append(padded_data)
            self.labels.append(label)
        
        self.data = [torch.tensor(d, dtype=torch.float32, device=device) for d in self.data]
        self.labels = torch.tensor(self.labels, dtype=torch.long, device=device)
    
    def normalize_data(self):
        all_data = torch.cat([d.unsqueeze(0) for d in self.data], dim=0)
        mean = all_data.mean()
        std = all_data.std()
        self.data = [(d - mean) / std for d in self.data]

    def augment_data(self, data):
        # Advanced augmentations: Gaussian noise, time shift, scaling
        noise = torch.randn_like(data, device=device) * 0.01
        shift = torch.roll(data, shifts=int(data.shape[1] * 0.1), dims=1)
        scale = data * (1 + 0.1 * torch.randn(1, device=device))
        return noise + shift + scale

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        data, label = self.data[idx], self.labels[idx]
        data = self.augment_data(data)  # Apply augmentation
        return data, label

# Define the EEGNet model
class EEGNet(nn.Module):
    def __init__(self, output_size):
        super(EEGNet, self).__init__()
        self.firstconv = nn.Sequential(
            nn.Conv2d(1, 16, (1, 51), padding=(0, 25)),
            nn.BatchNorm2d(16)
        )
        self.depthwiseConv = nn.Sequential(
            nn.Conv2d(16, 32, (65, 1), groups=16),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d((1, 4)),
            nn.Dropout(0.5)
        )
        self.separableConv = nn.Sequential(
            nn.Conv2d(32, 32, (1, 15), padding=(0, 7)),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.AvgPool2d((1, 8)),
            nn.Dropout(0.5)
        )
        self.classify = nn.Sequential(
            nn.Flatten(),
            nn.Linear(output_size, 2)
        )

    def forward(self, x):
        x = self.firstconv(x)
        x = self.depthwiseConv(x)
        x = self.separableConv(x)
        return self.classify(x)

# Function to determine the output size of the EEGNet model before the linear layer
def get_output_size(model, shape):
    with torch.no_grad():
        x = torch.zeros(shape, device=device)
        x = model.firstconv(x)
        x = model.depthwiseConv(x)
        x = model.separableConv(x)
        return x.view(x.size(0), -1).size(1)

# Load data
dataset = EEGDataset(DATA_DIR)

# Determine the correct input size for the linear layer
dummy_input_shape = (1, 1, 65, max([d.shape[1] for d in dataset.data]))  # (batch_size, channels, height, width)
output_size = get_output_size(EEGNet(output_size=0).to(device), dummy_input_shape)

# K-Fold Cross Validation
kf = KFold(n_splits=NUM_FOLDS, shuffle=True)

accuracies = []
precisions = []
recalls = []
f1s = []
aucs = []
val_losses = []  


for fold, (train_index, val_index) in enumerate(kf.split(dataset)):
    print(f'Fold {fold+1}')
    
    train_subset = Subset(dataset, train_index)
    val_subset = Subset(dataset, val_index)

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False)

    # Initialize model, loss function, and optimizer
    model = EEGNet(output_size=output_size).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

    best_val_accuracy = 0
    patience_counter = 0

    # Training loop
    for epoch in range(EPOCHS):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs.unsqueeze(1))  # Adding channel dimension
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        scheduler.step()

        # Intermediate validation
        model.eval()
        correct = 0
        total = 0
        all_labels = []
        all_predictions = []
        all_probs = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs.unsqueeze(1))  # Adding channel dimension
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                all_labels.extend(labels.cpu().numpy())
                all_predictions.extend(predicted.cpu().numpy())
                all_probs.extend(torch.softmax(outputs, dim=1)[:, 1].cpu().numpy())  # Get the probability of class 1

        val_accuracy = 100 * correct / total
        val_precision = precision_score(all_labels, all_predictions, average='macro')
        val_recall = recall_score(all_labels, all_predictions, average='macro')
        val_f1 = f1_score(all_labels, all_predictions, average='macro')
        val_auc = roc_auc_score(all_labels, all_probs)  # Calculate AUC score
        print(f"Epoch {epoch+1}/{EPOCHS}, Loss: {running_loss/len(train_loader)}, Validation Accuracy: {val_accuracy:.2f}%, AUC: {val_auc:.2f}")

        # Early stopping
        if val_accuracy > best_val_accuracy:
            best_val_accuracy = val_accuracy
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"Early stopping at epoch {epoch+1}")
                break

    # Final validation metrics for the fold
    accuracies.append(best_val_accuracy)
    precisions.append(val_precision)
    recalls.append(val_recall)
    f1s.append(val_f1)
    aucs.append(val_auc)
    print(f'Final Accuracy for fold {fold+1}: {best_val_accuracy:.2f}%')
    print(f'Final Precision for fold {fold+1}: {val_precision:.2f}')
    print(f'Final Recall for fold {fold+1}: {val_recall:.2f}')
    print(f'Final F1-Score for fold {fold+1}: {val_f1:.2f}')
    print(f'Final AUC for fold {fold+1}: {val_auc:.2f}\n')

# Report average performance across all folds
print(f'Average Accuracy: {np.mean(accuracies):.2f}%')
print(f'Average Precision: {np.mean(precisions):.2f}')
print(f'Average Recall: {np.mean(recalls):.2f}')
print(f'Average F1-Score: {np.mean(f1s):.2f}')
print(f'Average AUC: {np.mean(aucs):.2f}')
# Out:
# Using device: cuda
# Fold 1
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\torch\nn\init.py:452: UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/100, Loss: 0.6744152704874674, Validation Accuracy: 72.22%, AUC: 0.74
# Epoch 2/100, Loss: 0.4594620962937673, Validation Accuracy: 72.22%, AUC: 0.83
# Epoch 3/100, Loss: 0.4436541597048442, Validation Accuracy: 83.33%, AUC: 0.91
# Epoch 4/100, Loss: 0.38908137877782184, Validation Accuracy: 83.33%, AUC: 0.91
# Epoch 5/100, Loss: 0.34743183851242065, Validation Accuracy: 83.33%, AUC: 0.91
# Epoch 6/100, Loss: 0.28067376216252643, Validation Accuracy: 83.33%, AUC: 0.92
# Epoch 7/100, Loss: 0.30562196175257367, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 8/100, Loss: 0.25026997923851013, Validation Accuracy: 88.89%, AUC: 0.95
# Epoch 9/100, Loss: 0.22186829149723053, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 10/100, Loss: 0.17465272297461829, Validation Accuracy: 88.89%, AUC: 0.89
# Epoch 11/100, Loss: 0.19077128420273462, Validation Accuracy: 88.89%, AUC: 0.89
# Epoch 12/100, Loss: 0.21563167373339334, Validation Accuracy: 88.89%, AUC: 0.91
# Epoch 13/100, Loss: 0.20277093847592673, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 14/100, Loss: 0.17328467344244322, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 15/100, Loss: 0.18715203801790872, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 16/100, Loss: 0.2128156473239263, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 17/100, Loss: 0.15473374848564467, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 18/100, Loss: 0.2976902474959691, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 19/100, Loss: 0.27884170413017273, Validation Accuracy: 88.89%, AUC: 0.94
# Epoch 20/100, Loss: 0.1986722225944201, Validation Accuracy: 88.89%, AUC: 0.94
# Epoch 21/100, Loss: 0.19110380113124847, Validation Accuracy: 88.89%, AUC: 0.94
# Epoch 22/100, Loss: 0.1801904340585073, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 23/100, Loss: 0.27506276468435925, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 24/100, Loss: 0.26637834558884305, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 25/100, Loss: 0.25563425819079083, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 26/100, Loss: 0.3166845440864563, Validation Accuracy: 88.89%, AUC: 0.92
# Epoch 27/100, Loss: 0.15988162408272424, Validation Accuracy: 88.89%, AUC: 0.91
# Early stopping at epoch 27
# Final Accuracy for fold 1: 88.89%
# Final Precision for fold 1: 0.86
# Final Recall for fold 1: 0.92
# Final F1-Score for fold 1: 0.88
# Final AUC for fold 1: 0.91
#
# Fold 2
# Epoch 1/100, Loss: 0.9350544810295105, Validation Accuracy: 55.56%, AUC: 0.68
# Epoch 2/100, Loss: 0.6324437459309896, Validation Accuracy: 61.11%, AUC: 0.75
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/100, Loss: 0.513581246137619, Validation Accuracy: 66.67%, AUC: 0.75
# Epoch 4/100, Loss: 0.5097493330637614, Validation Accuracy: 66.67%, AUC: 0.79
# Epoch 5/100, Loss: 0.41088178753852844, Validation Accuracy: 66.67%, AUC: 0.81
# Epoch 6/100, Loss: 0.4296146631240845, Validation Accuracy: 66.67%, AUC: 0.85
# Epoch 7/100, Loss: 0.36825843652089435, Validation Accuracy: 66.67%, AUC: 0.86
# Epoch 8/100, Loss: 0.5310491025447845, Validation Accuracy: 72.22%, AUC: 0.84
# Epoch 9/100, Loss: 0.29357122381528217, Validation Accuracy: 77.78%, AUC: 0.84
# Epoch 10/100, Loss: 0.23295307904481888, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 11/100, Loss: 0.2349795401096344, Validation Accuracy: 83.33%, AUC: 0.82
# Epoch 12/100, Loss: 0.28323395550251007, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 13/100, Loss: 0.27462268869082135, Validation Accuracy: 83.33%, AUC: 0.82
# Epoch 14/100, Loss: 0.2075083131591479, Validation Accuracy: 83.33%, AUC: 0.88
# Epoch 15/100, Loss: 0.25038453936576843, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 16/100, Loss: 0.20693649848302206, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 17/100, Loss: 0.23144060870011648, Validation Accuracy: 83.33%, AUC: 0.88
# Epoch 18/100, Loss: 0.1994077612956365, Validation Accuracy: 83.33%, AUC: 0.86
# Epoch 19/100, Loss: 0.24104188879330954, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 20/100, Loss: 0.22013166546821594, Validation Accuracy: 83.33%, AUC: 0.86
# Epoch 21/100, Loss: 0.1898891900976499, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 22/100, Loss: 0.22785543898741403, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 23/100, Loss: 0.19807375967502594, Validation Accuracy: 83.33%, AUC: 0.88
# Epoch 24/100, Loss: 0.2102418690919876, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 25/100, Loss: 0.19997022052605948, Validation Accuracy: 83.33%, AUC: 0.89
# Epoch 26/100, Loss: 0.2564158837000529, Validation Accuracy: 83.33%, AUC: 0.89
# Epoch 27/100, Loss: 0.20470484594504038, Validation Accuracy: 83.33%, AUC: 0.88
# Epoch 28/100, Loss: 0.229539026816686, Validation Accuracy: 83.33%, AUC: 0.88
# Epoch 29/100, Loss: 0.20375398794809976, Validation Accuracy: 83.33%, AUC: 0.88
# Epoch 30/100, Loss: 0.37295596301555634, Validation Accuracy: 83.33%, AUC: 0.86
# Early stopping at epoch 30
# Final Accuracy for fold 2: 83.33%
# Final Precision for fold 2: 0.83
# Final Recall for fold 2: 0.84
# Final F1-Score for fold 2: 0.83
# Final AUC for fold 2: 0.86
#
# Fold 3
# Epoch 1/100, Loss: 0.7038735151290894, Validation Accuracy: 77.78%, AUC: 0.75
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 2/100, Loss: 0.6666170358657837, Validation Accuracy: 72.22%, AUC: 0.79
# Epoch 3/100, Loss: 0.5403389036655426, Validation Accuracy: 66.67%, AUC: 0.71
# Epoch 4/100, Loss: 0.5237603187561035, Validation Accuracy: 61.11%, AUC: 0.70
# Epoch 5/100, Loss: 0.48322075605392456, Validation Accuracy: 72.22%, AUC: 0.73
Validation Accuracy: 94.44%, AUC: 0.94
# Epoch 21/100, Loss: 0.1828693002462387, Validation Accuracy: 94.44%, AUC: 0.94
# Epoch 22/100, Loss: 0.2840632349252701, Validation Accuracy: 94.44%, AUC: 0.94
# Epoch 23/100, Loss: 0.20237135887145996, Validation Accuracy: 94.44%, AUC: 0.94
# Epoch 24/100, Loss: 0.24046913782755533, Validation Accuracy: 94.44%, AUC: 0.94
# Epoch 25/100, Loss: 0.2959696650505066, Validation Accuracy: 94.44%, AUC: 0.94
# Early stopping at epoch 25
# Final Accuracy for fold 4: 94.44%
# Final Precision for fold 4: 0.95
# Final Recall for fold 4: 0.94
# Final F1-Score for fold 4: 0.94
# Final AUC for fold 4: 0.94
#
# Fold 5
# Epoch 1/100, Loss: 0.6025283833344778, Validation Accuracy: 50.00%, AUC: 0.57
# Epoch 2/100, Loss: 0.5914727846781412, Validation Accuracy: 61.11%, AUC: 0.75
# Epoch 3/100, Loss: 0.44898146390914917, Validation Accuracy: 72.22%, AUC: 0.80
# Epoch 4/100, Loss: 0.4931448996067047, Validation Accuracy: 77.78%, AUC: 0.81
# C:\Users\User\anaconda3\envs\detectlie\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 5/100, Loss: 0.43718047936757404, Validation Accuracy: 77.78%, AUC: 0.84
# Epoch 6/100, Loss: 0.36498213807741803, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 7/100, Loss: 0.29980161786079407, Validation Accuracy: 83.33%, AUC: 0.88
# Epoch 8/100, Loss: 0.2782980004946391, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 9/100, Loss: 0.2890360901753108, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 10/100, Loss: 0.20307180285453796, Validation Accuracy: 77.78%, AUC: 0.84
# Epoch 11/100, Loss: 0.24831142028172812, Validation Accuracy: 77.78%, AUC: 0.85
# Epoch 12/100, Loss: 0.23667306204636893, Validation Accuracy: 83.33%, AUC: 0.85
# Epoch 13/100, Loss: 0.29390386243661243, Validation Accuracy: 88.89%, AUC: 0.85
# Epoch 14/100, Loss: 0.20129287242889404, Validation Accuracy: 88.89%, AUC: 0.85
# Epoch 15/100, Loss: 0.2330175886551539, Validation Accuracy: 88.89%, AUC: 0.85
# Epoch 16/100, Loss: 0.2821494738260905, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 17/100, Loss: 0.20633453130722046, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 18/100, Loss: 0.18605388204256693, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 19/100, Loss: 0.19998984535535178, Validation Accuracy: 88.89%, AUC: 0.83
# Epoch 20/100, Loss: 0.18588246405124664, Validation Accuracy: 88.89%, AUC: 0.83
# Epoch 21/100, Loss: 0.21149459729592004, Validation Accuracy: 88.89%, AUC: 0.83
# Epoch 22/100, Loss: 0.21548572182655334, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 23/100, Loss: 0.17909289399782816, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 24/100, Loss: 0.17077145477135977, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 25/100, Loss: 0.21791556725899378, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 26/100, Loss: 0.41936035950978595, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 27/100, Loss: 0.21533483763535818, Validation Accuracy: 88.89%, AUC: 0.85
# Epoch 28/100, Loss: 0.2011628101269404, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 29/100, Loss: 0.19200688724716505, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 30/100, Loss: 0.262665922443072, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 31/100, Loss: 0.2267713894446691, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 32/100, Loss: 0.18661379317442575, Validation Accuracy: 88.89%, AUC: 0.84
# Epoch 33/100, Loss: 0.15655920840799809, Validation Accuracy: 88.89%, AUC: 0.84
# Early stopping at epoch 33
# Final Accuracy for fold 5: 88.89%
# Final Precision for fold 5: 0.91
# Final Recall for fold 5: 0.89
# Final F1-Score for fold 5: 0.89
# Final AUC for fold 5: 0.84
#
# Average Accuracy: 87.78%
# Average Precision: 0.85
# Average Recall: 0.88
# Average F1-Score: 0.85
# Average AUC: 0.88
