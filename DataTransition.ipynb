# %%
import os
import pickle

# Path to the directory containing the combined poly data files
data_dir = r'C:\Users\User\Documents\Lie detect data\npy 데이터3-1'

# Ensure the output directory exists
output_dir = r'C:\Users\User\Documents\Lie detect data\TestData-1'
os.makedirs(output_dir, exist_ok=True)

# Initialize counters for naming
truth_counter = 1
lie_counter = 1

# Iterate through all files in the data directory
for file_name in os.listdir(data_dir):
    if file_name.endswith('.pkl'):
        file_path = os.path.join(data_dir, file_name)

        # Load the combined Poly data file
        with open(file_path, 'rb') as file:
            combined_data = pickle.load(file)

        # Debug: Print the file being processed
        print(f"Processing file: {file_name}, Number of epochs: {len(combined_data)}")

        # Determine if the file contains truth or lie data based on the filename
        if 'truth' in file_name and 'quer' in file_name and 'eeg' in file_name:
            label = 'truth'
            counter = truth_counter
        elif 'lie' in file_name and 'quer' in file_name and 'eeg' in file_name:
            label = 'lie'
            counter = lie_counter
        else:
            continue

        # Split and save individual epochs
        for i, epoch in enumerate(combined_data):
            individual_file_path = os.path.join(output_dir, f'eeg_quer_{label}_{counter}.pkl')
            with open(individual_file_path, 'wb') as individual_file:
                pickle.dump(epoch, individual_file)
                
            # Debug: Print each file being saved
            print(f"Saved {label} epoch {i+1} as {individual_file_path}")
            
            counter += 1

        # Update the respective counter
        if label == 'truth':
            truth_counter = counter
        elif label == 'lie':
            lie_counter = counter

print(f"Saved {truth_counter - 1} truth epochs and {lie_counter - 1} lie epochs.")
# Out:
# Processing file: eeg_ansc_3_01.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_02.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_03.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_04.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_05.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_06.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_07.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_08.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_09.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_10.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_11.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_12.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_13.pkl, Number of epochs: 6
# Processing file: eeg_ansc_3_14.pkl, Number of epochs: 6
# Processing file: eeg_ansg_3_01.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_02.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_03.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_04.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_05.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_06.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_07.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_08.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_09.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_10.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_11.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_12.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_13.pkl, Number of epochs: 4
# Processing file: eeg_ansg_3_14.pkl, Number of epochs: 4
# Processing file: eeg_ansr_lie_3_01.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_3_02.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_3_04.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_3_06.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_3_10.pkl, Number of epochs: 5
# Processing file: eeg_ansr_lie_3_13.pkl, Number of epochs: 5
# Processing file: eeg_ansr_truth_3_01.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_3_02.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_3_03.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_3_04.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_3_05.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_3_06.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_3_07.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_3_08.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_3_09.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_3_10.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_3_11.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_3_12.pkl, Number of epochs: 6
# Processing file: eeg_ansr_truth_3_13.pkl, Number of epochs: 1
# Processing file: eeg_ansr_truth_3_14.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_01.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_02.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_03.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_04.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_05.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_06.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_07.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_08.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_09.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_10.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_11.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_12.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_13.pkl, Number of epochs: 6
# Processing file: eeg_quec_3_14.pkl, Number of epochs: 6
# Processing file: eeg_queg_3_01.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_02.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_03.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_04.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_05.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_06.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_07.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_08.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_09.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_10.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_11.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_12.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_13.pkl, Number of epochs: 4
# Processing file: eeg_queg_3_14.pkl, Number of epochs: 4
# Processing file: eeg_quer_lie_3_01.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_1.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_2.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_3.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_4.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_5.pkl
# Processing file: eeg_quer_lie_3_02.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_6.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_7.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_8.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_9.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_10.pkl
# Processing file: eeg_quer_lie_3_04.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_11.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_12.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_13.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_14.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_15.pkl
# Processing file: eeg_quer_lie_3_06.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_16.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_17.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_18.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_19.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_20.pkl
# Processing file: eeg_quer_lie_3_10.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_21.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_22.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_23.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_24.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_25.pkl
# Processing file: eeg_quer_lie_3_13.pkl, Number of epochs: 5
# Saved lie epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_26.pkl
# Saved lie epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_27.pkl
# Saved lie epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_28.pkl
# Saved lie epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_29.pkl
# Saved lie epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_lie_30.pkl
# Processing file: eeg_quer_truth_3_01.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_1.pkl
# Processing file: eeg_quer_truth_3_02.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_2.pkl
# Processing file: eeg_quer_truth_3_03.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_3.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_4.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_5.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_6.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_7.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_8.pkl
# Processing file: eeg_quer_truth_3_04.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_9.pkl
# Processing file: eeg_quer_truth_3_05.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_10.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_11.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_12.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_13.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_14.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_15.pkl
# Processing file: eeg_quer_truth_3_06.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_16.pkl
# Processing file: eeg_quer_truth_3_07.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_17.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_18.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_19.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_20.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_21.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_22.pkl
# Processing file: eeg_quer_truth_3_08.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_23.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_24.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_25.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_26.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_27.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_28.pkl
# Processing file: eeg_quer_truth_3_09.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_29.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_30.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_31.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_32.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_33.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_34.pkl
# Processing file: eeg_quer_truth_3_10.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_35.pkl
# Processing file: eeg_quer_truth_3_11.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_36.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_37.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_38.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_39.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_40.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_41.pkl
# Processing file: eeg_quer_truth_3_12.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_42.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_43.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_44.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_45.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_46.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_47.pkl
# Processing file: eeg_quer_truth_3_13.pkl, Number of epochs: 1
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_48.pkl
# Processing file: eeg_quer_truth_3_14.pkl, Number of epochs: 6
# Saved truth epoch 1 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_49.pkl
# Saved truth epoch 2 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_50.pkl
# Saved truth epoch 3 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_51.pkl
# Saved truth epoch 4 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_52.pkl
# Saved truth epoch 5 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_53.pkl
# Saved truth epoch 6 as C:\Users\User\Documents\Lie detect data\TestData-1\eeg_quer_truth_54.pkl
# Processing file: poly_ansc_3_01.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_02.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_03.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_04.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_05.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_06.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_07.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_08.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_09.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_10.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_11.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_12.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_13.pkl, Number of epochs: 6
# Processing file: poly_ansc_3_14.pkl, Number of epochs: 6
# Processing file: poly_ansg_3_01.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_02.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_03.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_04.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_05.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_06.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_07.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_08.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_09.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_10.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_11.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_12.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_13.pkl, Number of epochs: 4
# Processing file: poly_ansg_3_14.pkl, Number of epochs: 4
# Processing file: poly_ansr_lie_3_01.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_3_02.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_3_04.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_3_06.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_3_10.pkl, Number of epochs: 5
# Processing file: poly_ansr_lie_3_13.pkl, Number of epochs: 5
# Processing file: poly_ansr_truth_3_01.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_3_02.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_3_03.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_3_04.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_3_05.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_3_06.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_3_07.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_3_08.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_3_09.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_3_10.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_3_11.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_3_12.pkl, Number of epochs: 6
# Processing file: poly_ansr_truth_3_13.pkl, Number of epochs: 1
# Processing file: poly_ansr_truth_3_14.pkl, Number of epochs: 6
# Processing file: poly_quec_3_01.pkl, Number of epochs: 6
# Processing file: poly_quec_3_02.pkl, Number of epochs: 6
# Processing file: poly_quec_3_03.pkl, Number of epochs: 6
# Processing file: poly_quec_3_04.pkl, Number of epochs: 6
# Processing file: poly_quec_3_05.pkl, Number of epochs: 6
# Processing file: poly_quec_3_06.pkl, Number of epochs: 6
# Processing file: poly_quec_3_07.pkl, Number of epochs: 6
# Processing file: poly_quec_3_08.pkl, Number of epochs: 6
# Processing file: poly_quec_3_09.pkl, Number of epochs: 6
# Processing file: poly_quec_3_10.pkl, Number of epochs: 6
# Processing file: poly_quec_3_11.pkl, Number of epochs: 6
# Processing file: poly_quec_3_12.pkl, Number of epochs: 6
# Processing file: poly_quec_3_13.pkl, Number of epochs: 6
# Processing file: poly_quec_3_14.pkl, Number of epochs: 6
# Processing file: poly_queg_3_01.pkl, Number of epochs: 4
# Processing file: poly_queg_3_02.pkl, Number of epochs: 4
# Processing file: poly_queg_3_03.pkl, Number of epochs: 4
# Processing file: poly_queg_3_04.pkl, Number of epochs: 4
# Processing file: poly_queg_3_05.pkl, Number of epochs: 4
# Processing file: poly_queg_3_06.pkl, Number of epochs: 4
# Processing file: poly_queg_3_07.pkl, Number of epochs: 4
# Processing file: poly_queg_3_08.pkl, Number of epochs: 4
# Processing file: poly_queg_3_09.pkl, Number of epochs: 4
# Processing file: poly_queg_3_10.pkl, Number of epochs: 4
# Processing file: poly_queg_3_11.pkl, Number of epochs: 4
# Processing file: poly_queg_3_12.pkl, Number of epochs: 4
# Processing file: poly_queg_3_13.pkl, Number of epochs: 4
# Processing file: poly_queg_3_14.pkl, Number of epochs: 4
# Processing file: poly_quer_lie_3_01.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_3_02.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_3_04.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_3_06.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_3_10.pkl, Number of epochs: 5
# Processing file: poly_quer_lie_3_13.pkl, Number of epochs: 5
# Processing file: poly_quer_truth_3_01.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_3_02.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_3_03.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_3_04.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_3_05.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_3_06.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_3_07.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_3_08.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_3_09.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_3_10.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_3_11.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_3_12.pkl, Number of epochs: 6
# Processing file: poly_quer_truth_3_13.pkl, Number of epochs: 1
# Processing file: poly_quer_truth_3_14.pkl, Number of epochs: 6
# Saved 54 truth epochs and 30 lie epochs.
